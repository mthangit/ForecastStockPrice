# %%
from re import X
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        # padding on the both ends of time series
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x


class series_decomp(nn.Module):
    """
    Series decomposition block
    """
    def __init__(self, kernel_size):
        super(series_decomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class Model(nn.Module):
    """
    DLinear
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len

        # Decompsition Kernel Size
        kernel_size = 25
        self.decompsition = series_decomp(kernel_size)
        self.individual = configs.individual
        self.channels = configs.enc_in

        if self.individual:
            self.Linear_Seasonal = nn.ModuleList()
            self.Linear_Trend = nn.ModuleList()
            self.Linear_Decoder = nn.ModuleList()
            for i in range(self.channels):
                self.Linear_Seasonal.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Seasonal[i].weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))
                self.Linear_Trend.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Trend[i].weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))
                self.Linear_Decoder.append(nn.Linear(self.seq_len,self.pred_len))
        else:
            self.Linear_Seasonal = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Trend = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Decoder = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Seasonal.weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))
            self.Linear_Trend.weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))

    def forward(self, x):
        # x: [Batch, Input length, Channel]
        seasonal_init, trend_init = self.decompsition(x)
        seasonal_init, trend_init = seasonal_init.permute(0,2,1), trend_init.permute(0,2,1)
        if self.individual:
            seasonal_output = torch.zeros([seasonal_init.size(0),seasonal_init.size(1),self.pred_len],dtype=seasonal_init.dtype).to(seasonal_init.device)
            trend_output = torch.zeros([trend_init.size(0),trend_init.size(1),self.pred_len],dtype=trend_init.dtype).to(trend_init.device)
            for i in range(self.channels):
                seasonal_output[:,i,:] = self.Linear_Seasonal[i](seasonal_init[:,i,:])
                trend_output[:,i,:] = self.Linear_Trend[i](trend_init[:,i,:])
        else:
            seasonal_output = self.Linear_Seasonal(seasonal_init)
            trend_output = self.Linear_Trend(trend_init)

        x = seasonal_output + trend_output
        return x.permute(0,2,1) # to [Batch, Output length, Channel]

# %%
import pandas as pd
import torch
from datetime import datetime, timedelta
# Đọc dữ liệu từ file CSV
df = pd.read_csv('KDH-Historical-Data.csv')

# %%
# # Chuyển dữ liệu thời gian
# df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')
# # Đảo ngược lại dữ liệu
# df = df.iloc[::-1].reset_index(drop=True)

# %%
# # Loại bỏ dấu phẩy từ cột "Price"
# df['Price'] = df['Price'].str.replace(',', '').astype(float)
# # Loại bỏ dấu phẩy từ cột "Open"
# df['Open'] = df['Open'].str.replace(',', '').astype(float)
# # Loại bỏ dấu phẩy từ cột "High"
# df['High'] = df['High'].str.replace(',', '').astype(float)
# # Loại bỏ dấu phẩy từ cột "Low"
# df['Low'] = df['Low'].str.replace(',', '').astype(float)

# %%
df
# Out:
#       Unnamed: 0        Date    Price
# 0              0  2017-01-03   9198.4
# 1              1  2017-01-04   9198.4
# 2              2  2017-01-05   8944.8
# 3              3  2017-01-06   9083.2
# 4              4  2017-01-07   9106.2
# ...          ...         ...      ...
# 2702        2702  2024-05-28  36250.0
# 2703        2703  2024-05-29  35700.0
# 2704        2704  2024-05-30  36050.0
# 2705        2705  2024-05-31  36200.0
# 2706        2706  2024-06-01  36000.0
#
# [2707 rows x 3 columns]

# %%
# Lấy ngày cuối cùng của dữ liệu
df['Date'] = pd.to_datetime(df['Date'])
last_date = df['Date'].max()

# %%
# Lấy dữ liệu Date cần phân tích để dự bảo DL trên tập test
time_series_Date = df['Date']

# Phân chia dữ liệu thành tập huấn luyện và tập kiểm tra - để lấy date
train_data_Date = time_series_Date[:int(0.7 * len(time_series_Date))]
test_data_Date = time_series_Date[int(0.7 * len(time_series_Date)):]
first_data_Date = test_data_Date.min()
print(first_data_Date)
# Out:
# 2022-03-12 00:00:00

# %%
# Lấy dữ liệu cần phân tích
time_series_price = df['Price']

# Phân chia dữ liệu thành tập huấn luyện và tập kiểm tra
train_data_price = time_series_price[:int(0.7 * len(time_series_price))]
test_data_price = time_series_price[int(0.7 * len(time_series_price)):]

# Chọn các cột dữ liệu số
# numeric_columns = ['Price', 'Open', 'High', 'Low']
numeric_columns = ['Price']

# Chuyển các giá trị số thành tensor
numeric_data = df[numeric_columns].values.astype(np.float32)

# Mở rộng chiều để phù hợp với đầu vào của mô hình
numeric_data = np.expand_dims(numeric_data, axis=0)

# Chia dữ liệu thành tensor
input_data_train = torch.tensor(numeric_data[:, :len(train_data_price), :])
input_data_test = torch.tensor(numeric_data[:, len(train_data_price):, :])
# Lấy dữ liệu 20 ngày gần nhất
recent_20_prices = time_series_price[-20:]

# Chuyển đổi dữ liệu 20 ngày gần nhất thành numpy array và mở rộng chiều
recent_20_prices_array = recent_20_prices.values.astype(np.float32)
recent_20_prices_array = np.expand_dims(recent_20_prices_array, axis=0)
recent_20_prices_array = np.expand_dims(recent_20_prices_array, axis=-1)

# Chuyển đổi thành tensor
input_data_20day = torch.tensor(recent_20_prices_array)

# In ra để kiểm tra kích thước của các tensor
print("Kích thước tập huấn luyện:", input_data_train.shape)
print("Kích thước tập kiểm tra:", input_data_test.shape)
# Out:
# Kích thước tập huấn luyện: torch.Size([1, 1894, 1])
# Kích thước tập kiểm tra: torch.Size([1, 813, 1])

# %%
# Khởi tạo cấu hình cho model
class Configs:
    def __init__(self):
        self.seq_len = 1894  # Độ dài chuỗi thời gian đầu vào(tập kiểm tra)
        self.pred_len = 1894  # Độ dài dự đoán
        self.individual = False  # Có sử dụng các kênh cá nhân hay không
        self.enc_in = 1  # Số lượng kênh đầu vào (tương ứng với số cột của dữ liệu)

configs = Configs()

# Khởi tạo model
model = Model(configs)

# %%
import torch.optim as optim

# Xác định hàm mất mát và trình tối ưu hóa
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Có thể điều chỉnh lr theo yêu cầu

# Huấn luyện mô hình
num_epochs = 100  # Số lượng epoch
for epoch in range(num_epochs):
    model.train()  # Chuyển sang chế độ huấn luyện
    optimizer.zero_grad()  # Đặt gradient về 0

    # Feedforward
    outputs = model(input_data_train)

    # Tính toán loss
    loss = criterion(outputs, input_data_train)  # So sánh đầu ra với đầu vào

    # Backpropagation
    loss.backward()  # Tính toán gradient
    optimizer.step()  # Cập nhật trọng số

    # In ra loss sau mỗi epoch
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/100], Loss: 86016352.0000
# Epoch [2/100], Loss: 1246721024.0000
# Epoch [3/100], Loss: 134680544.0000
# Epoch [4/100], Loss: 261767904.0000
# Epoch [5/100], Loss: 683068480.0000
# Epoch [6/100], Loss: 482676032.0000
# Epoch [7/100], Loss: 110441248.0000
# Epoch [8/100], Loss: 29127838.0000
# Epoch [9/100], Loss: 224324784.0000
# Epoch [10/100], Loss: 353031808.0000
# Epoch [11/100], Loss: 260349824.0000
# Epoch [12/100], Loss: 87482136.0000
# Epoch [13/100], Loss: 18658246.0000
# Epoch [14/100], Loss: 84404632.0000
# Epoch [15/100], Loss: 168924624.0000
# Epoch [16/100], Loss: 168150928.0000
# Epoch [17/100], Loss: 94862424.0000
# Epoch [18/100], Loss: 31492760.0000
# Epoch [19/100], Loss: 29026468.0000
# Epoch [20/100], Loss: 66825556.0000
# Epoch [21/100], Loss: 91311872.0000
# Epoch [22/100], Loss: 76475512.0000
# Epoch [23/100], Loss: 41552496.0000
# Epoch [24/100], Loss: 20039068.0000
# Epoch [25/100], Loss: 24824728.0000
# Epoch [26/100], Loss: 41467368.0000
# Epoch [27/100], Loss: 47764896.0000
# Epoch [28/100], Loss: 36516012.0000
# Epoch [29/100], Loss: 19436274.0000
# Epoch [30/100], Loss: 12144206.0000
# Epoch [31/100], Loss: 17880748.0000
# Epoch [32/100], Loss: 25978982.0000
# Epoch [33/100], Loss: 25185676.0000
# Epoch [34/100], Loss: 15998270.0000
# Epoch [35/100], Loss: 8277003.5000
# Epoch [36/100], Loss: 8692885.0000
# Epoch [37/100], Loss: 13684115.0000
# Epoch [38/100], Loss: 15302380.0000
# Epoch [39/100], Loss: 11162359.0000
# Epoch [40/100], Loss: 6082313.0000
# Epoch [41/100], Loss: 5043569.5000
# Epoch [42/100], Loss: 7410971.5000
# Epoch [43/100], Loss: 8858477.0000
# Epoch [44/100], Loss: 7136888.0000
# Epoch [45/100], Loss: 4220661.0000
# Epoch [46/100], Loss: 3142420.0000
# Epoch [47/100], Loss: 4225428.0000
# Epoch [48/100], Loss: 5191887.0000
# Epoch [49/100], Loss: 4367094.5000
# Epoch [50/100], Loss: 2651348.0000
# Epoch [51/100], Loss: 1968706.7500
# Epoch [52/100], Loss: 2614752.0000
# Epoch [53/100], Loss: 3124476.2500
# Epoch [54/100], Loss: 2520154.7500
# Epoch [55/100], Loss: 1542567.7500
# Epoch [56/100], Loss: 1312120.8750
# Epoch [57/100], Loss: 1716103.6250
# Epoch [58/100], Loss: 1831001.1250
# Epoch [59/100], Loss: 1374185.2500
# Epoch [60/100], Loss: 927857.3750
# Epoch [61/100], Loss: 920420.6250
# Epoch [62/100], Loss: 1089365.1250
# Epoch [63/100], Loss: 1026399.6250
# Epoch [64/100], Loss: 761132.1250
# Epoch [65/100], Loss: 594290.9375
# Epoch [66/100], Loss: 620697.6875
# Epoch [67/100], Loss: 659208.8125
# Epoch [68/100], Loss: 571203.6875
# Epoch [69/100], Loss: 438386.9375
# Epoch [70/100], Loss: 388783.9375
# Epoch [71/100], Loss: 401791.8438
# Epoch [72/100], Loss: 381733.2812
# Epoch [73/100], Loss: 319337.2812
# Epoch [74/100], Loss: 271558.8125
# Epoch [75/100], Loss: 252804.8438
# Epoch [76/100], Loss: 238101.1719
# Epoch [77/100], Loss: 219032.2500
# Epoch [78/100], Loss: 196338.2656
# Epoch [79/100], Loss: 167629.3438
# Epoch [80/100], Loss: 146716.4688
# Epoch [81/100], Loss: 144391.9688
# Epoch [82/100], Loss: 138647.1094
# Epoch [83/100], Loss: 113559.7891
# Epoch [84/100], Loss: 93466.5391
# Epoch [85/100], Loss: 94666.9766
# Epoch [86/100], Loss: 93639.9844
# Epoch [87/100], Loss: 76379.4688
# Epoch [88/100], Loss: 62795.5430
# Epoch [89/100], Loss: 62642.1172
# Epoch [90/100], Loss: 60599.2500
# Epoch [91/100], Loss: 50968.5625
# Epoch [92/100], Loss: 43829.4922
# Epoch [93/100], Loss: 41474.3047
# Epoch [94/100], Loss: 38379.4180
# Epoch [95/100], Loss: 34132.4023
# Epoch [96/100], Loss: 30594.2695
# Epoch [97/100], Loss: 27323.0742
# Epoch [98/100], Loss: 24582.8223
# Epoch [99/100], Loss: 22806.4941
# Epoch [100/100], Loss: 20806.0059

# %%
# Dự báo cho tập test
# # Chuyển sang chế độ đánh giá
model.eval()

# Không cần tính gradient trong quá trình dự báo
with torch.no_grad():
    input_data_future_test = input_data_train.clone()  # Tạo một bản sao của dữ liệu đầu vào để cập nhật dự báo
    predicted_test = []  # Danh sách dự báo cho các ngày tiếp theo
    for i in range(813):  # Dự báo cho tập test
        # Dự báo cho ngày hiện tại
        output = model(input_data_future_test)
        # Lưu dự báo của ngày hiện tại
        predicted_test.append(output[:, -1, :])  # Lấy dự báo cho ngày cuối cùng trong chuỗi thời gian
        # Cập nhật dữ liệu đầu vào cho ngày tiếp theo
        input_data_future_test = torch.cat([input_data_future_test[:, :, 1:], output], dim=2)

    # In ra dự báo cho tập test
    print("Predicted Output for data test:")
    for i in range(813):
        # In ra ngày tương ứng với dự báo
        print(f"Day {i+1}: {first_data_Date + pd.DateOffset(days=i+1)} - Predicted: {predicted_test[i][0]}")
# Out:
# Predicted Output for data test:
# Day 1: 2022-03-13 00:00:00 - Predicted: tensor([46391.5859])
# Day 2: 2022-03-14 00:00:00 - Predicted: tensor([46492.9844])
# Day 3: 2022-03-15 00:00:00 - Predicted: tensor([46590.2969])
# Day 4: 2022-03-16 00:00:00 - Predicted: tensor([46687.7188])
# Day 5: 2022-03-17 00:00:00 - Predicted: tensor([46785.3477])
# Day 6: 2022-03-18 00:00:00 - Predicted: tensor([46883.1836])
# Day 7: 2022-03-19 00:00:00 - Predicted: tensor([46981.2227])
# Day 8: 2022-03-20 00:00:00 - Predicted: tensor([47079.4609])
# Day 9: 2022-03-21 00:00:00 - Predicted: tensor([47177.9102])
# Day 10: 2022-03-22 00:00:00 - Predicted: tensor([47276.5703])
# Day 11: 2022-03-23 00:00:00 - Predicted: tensor([47375.4297])
# Day 12: 2022-03-24 00:00:00 - Predicted: tensor([47474.5000])
# Day 13: 2022-03-25 00:00:00 - Predicted: tensor([47573.7695])
# Day 14: 2022-03-26 00:00:00 - Predicted: tensor([47673.2539])
# Day 15: 2022-03-27 00:00:00 - Predicted: tensor([47772.9414])
# Day 16: 2022-03-28 00:00:00 - Predicted: tensor([47872.8398])
# Day 17: 2022-03-29 00:00:00 - Predicted: tensor([47972.9453])
# Day 18: 2022-03-30 00:00:00 - Predicted: tensor([48073.2695])
# Day 19: 2022-03-31 00:00:00 - Predicted: tensor([48173.7930])
# Day 20: 2022-04-01 00:00:00 - Predicted: tensor([48274.5312])
# Day 21: 2022-04-02 00:00:00 - Predicted: tensor([48375.4805])
# Day 22: 2022-04-03 00:00:00 - Predicted: tensor([48476.6367])
# Day 23: 2022-04-04 00:00:00 - Predicted: tensor([48578.0078])
# Day 24: 2022-04-05 00:00:00 - Predicted: tensor([48679.5898])
# Day 25: 2022-04-06 00:00:00 - Predicted: tensor([48781.3828])
# Day 26: 2022-04-07 00:00:00 - Predicted: tensor([48883.3906])
# Day 27: 2022-04-08 00:00:00 - Predicted: tensor([48985.6133])
# Day 28: 2022-04-09 00:00:00 - Predicted: tensor([49088.0547])
# Day 29: 2022-04-10 00:00:00 - Predicted: tensor([49190.6953])
# Day 30: 2022-04-11 00:00:00 - Predicted: tensor([49293.5625])
# Day 31: 2022-04-12 00:00:00 - Predicted: tensor([49396.6367])
# Day 32: 2022-04-13 00:00:00 - Predicted: tensor([49499.9336])
# Day 33: 2022-04-14 00:00:00 - Predicted: tensor([49603.4414])
# Day 34: 2022-04-15 00:00:00 - Predicted: tensor([49707.1641])
# Day 35: 2022-04-16 00:00:00 - Predicted: tensor([49811.1055])
# Day 36: 2022-04-17 00:00:00 - Predicted: tensor([49915.2695])
# Day 37: 2022-04-18 00:00:00 - Predicted: tensor([50019.6484])
# Day 38: 2022-04-19 00:00:00 - Predicted: tensor([50124.2500])
# Day 39: 2022-04-20 00:00:00 - Predicted: tensor([50229.0586])
# Day 40: 2022-04-21 00:00:00 - Predicted: tensor([50334.0977])
# Day 41: 2022-04-22 00:00:00 - Predicted: tensor([50439.3516])
# Day 42: 2022-04-23 00:00:00 - Predicted: tensor([50544.8320])
# Day 43: 2022-04-24 00:00:00 - Predicted: tensor([50650.5234])
# Day 44: 2022-04-25 00:00:00 - Predicted: tensor([50756.4414])
# Day 45: 2022-04-26 00:00:00 - Predicted: tensor([50862.5742])
# Day 46: 2022-04-27 00:00:00 - Predicted: tensor([50968.9375])
# Day 47: 2022-04-28 00:00:00 - Predicted: tensor([51075.5195])
# Day 48: 2022-04-29 00:00:00 - Predicted: tensor([51182.3203])
# Day 49: 2022-04-30 00:00:00 - Predicted: tensor([51289.3516])
# Day 50: 2022-05-01 00:00:00 - Predicted: tensor([51396.6055])
# Day 51: 2022-05-02 00:00:00 - Predicted: tensor([51504.0742])
# Day 52: 2022-05-03 00:00:00 - Predicted: tensor([51611.7812])
# Day 53: 2022-05-04 00:00:00 - Predicted: tensor([51719.7109])
# Day 54: 2022-05-05 00:00:00 - Predicted: tensor([51827.8594])
# Day 55: 2022-05-06 00:00:00 - Predicted: tensor([51936.2344])
# Day 56: 2022-05-07 00:00:00 - Predicted: tensor([52044.8359])
# Day 57: 2022-05-08 00:00:00 - Predicted: tensor([52153.6719])
# Day 58: 2022-05-09 00:00:00 - Predicted: tensor([52262.7305])
# Day 59: 2022-05-10 00:00:00 - Predicted: tensor([52372.0156])
# Day 60: 2022-05-11 00:00:00 - Predicted: tensor([52481.5312])
# Day 61: 2022-05-12 00:00:00 - Predicted: tensor([52591.2773])
# Day 62: 2022-05-13 00:00:00 - Predicted: tensor([52701.2539])
# Day 63: 2022-05-14 00:00:00 - Predicted: tensor([52811.4570])
# Day 64: 2022-05-15 00:00:00 - Predicted: tensor([52921.8906])
# Day 65: 2022-05-16 00:00:00 - Predicted: tensor([53032.5586])
# Day 66: 2022-05-17 00:00:00 - Predicted: tensor([53143.4570])
# Day 67: 2022-05-18 00:00:00 - Predicted: tensor([53254.5859])
# Day 68: 2022-05-19 00:00:00 - Predicted: tensor([53365.9453])
# Day 69: 2022-05-20 00:00:00 - Predicted: tensor([53477.5430])
# Day 70: 2022-05-21 00:00:00 - Predicted: tensor([53589.3711])
# Day 71: 2022-05-22 00:00:00 - Predicted: tensor([53701.4336])
# Day 72: 2022-05-23 00:00:00 - Predicted: tensor([53813.7305])
# Day 73: 2022-05-24 00:00:00 - Predicted: tensor([53926.2578])
# Day 74: 2022-05-25 00:00:00 - Predicted: tensor([54039.0234])
# Day 75: 2022-05-26 00:00:00 - Predicted: tensor([54152.0234])
# Day 76: 2022-05-27 00:00:00 - Predicted: tensor([54265.2656])
# Day 77: 2022-05-28 00:00:00 - Predicted: tensor([54378.7344])
# Day 78: 2022-05-29 00:00:00 - Predicted: tensor([54492.4492])
# Day 79: 2022-05-30 00:00:00 - Predicted: tensor([54606.4023])
# Day 80: 2022-05-31 00:00:00 - Predicted: tensor([54720.5898])
# Day 81: 2022-06-01 00:00:00 - Predicted: tensor([54835.0195])
# Day 82: 2022-06-02 00:00:00 - Predicted: tensor([54949.6836])
# Day 83: 2022-06-03 00:00:00 - Predicted: tensor([55064.5898])
# Day 84: 2022-06-04 00:00:00 - Predicted: tensor([55179.7383])
# Day 85: 2022-06-05 00:00:00 - Predicted: tensor([55295.1250])
# Day 86: 2022-06-06 00:00:00 - Predicted: tensor([55410.7539])
# Day 87: 2022-06-07 00:00:00 - Predicted: tensor([55526.6250])
# Day 88: 2022-06-08 00:00:00 - Predicted: tensor([55642.7344])
# Day 89: 2022-06-09 00:00:00 - Predicted: tensor([55759.0898])
# Day 90: 2022-06-10 00:00:00 - Predicted: tensor([55875.6836])
# Day 91: 2022-06-11 00:00:00 - Predicted: tensor([55992.5273])
# Day 92: 2022-06-12 00:00:00 - Predicted: tensor([56109.6211])
# Day 93: 2022-06-13 00:00:00 - Predicted: tensor([56226.9531])
# Day 94: 2022-06-14 00:00:00 - Predicted: tensor([56344.5312])
# Day 95: 2022-06-15 00:00:00 - Predicted: tensor([56462.3477])
# Day 96: 2022-06-16 00:00:00 - Predicted: tensor([56580.4180])
# Day 97: 2022-06-17 00:00:00 - Predicted: tensor([56698.7344])
# Day 98: 2022-06-18 00:00:00 - Predicted: tensor([56817.3047])
# Day 99: 2022-06-19 00:00:00 - Predicted: tensor([56936.1094])
# Day 100: 2022-06-20 00:00:00 - Predicted: tensor([57055.1758])
# Day 101: 2022-06-21 00:00:00 - Predicted: tensor([57174.4844])
# Day 102: 2022-06-22 00:00:00 - Predicted: tensor([57294.0430])
# Day 103: 2022-06-23 00:00:00 - Predicted: tensor([57413.8516])
# Day 104: 2022-06-24 00:00:00 - Predicted: tensor([57533.9102])
# Day 105: 2022-06-25 00:00:00 - Predicted: tensor([57654.2188])
# Day 106: 2022-06-26 00:00:00 - Predicted: tensor([57774.7812])
# Day 107: 2022-06-27 00:00:00 - Predicted: tensor([57895.5977])
# Day 108: 2022-06-28 00:00:00 - Predicted: tensor([58016.6602])
# Day 109: 2022-06-29 00:00:00 - Predicted: tensor([58137.9805])
# Day 110: 2022-06-30 00:00:00 - Predicted: tensor([58259.5547])
# Day 111: 2022-07-01 00:00:00 - Predicted: tensor([58381.3828])
# Day 112: 2022-07-02 00:00:00 - Predicted: tensor([58503.4688])
# Day 113: 2022-07-03 00:00:00 - Predicted: tensor([58625.8008])
# Day 114: 2022-07-04 00:00:00 - Predicted: tensor([58748.3984])
# Day 115: 2022-07-05 00:00:00 - Predicted: tensor([58871.2461])
# Day 116: 2022-07-06 00:00:00 - Predicted: tensor([58994.3516])
# Day 117: 2022-07-07 00:00:00 - Predicted: tensor([59117.7188])
# Day 118: 2022-07-08 00:00:00 - Predicted: tensor([59241.3359])
# Day 119: 2022-07-09 00:00:00 - Predicted: tensor([59365.2188])
# Day 120: 2022-07-10 00:00:00 - Predicted: tensor([59489.3594])
# Day 121: 2022-07-11 00:00:00 - Predicted: tensor([59613.7656])
# Day 122: 2022-07-12 00:00:00 - Predicted: tensor([59738.4180])
# Day 123: 2022-07-13 00:00:00 - Predicted: tensor([59863.3398])
# Day 124: 2022-07-14 00:00:00 - Predicted: tensor([59988.5195])
# Day 125: 2022-07-15 00:00:00 - Predicted: tensor([60113.9570])
# Day 126: 2022-07-16 00:00:00 - Predicted: tensor([60239.6641])
# Day 127: 2022-07-17 00:00:00 - Predicted: tensor([60365.6367])
# Day 128: 2022-07-18 00:00:00 - Predicted: tensor([60491.8789])
# Day 129: 2022-07-19 00:00:00 - Predicted: tensor([60618.3594])
# Day 130: 2022-07-20 00:00:00 - Predicted: tensor([60745.1211])
# Day 131: 2022-07-21 00:00:00 - Predicted: tensor([60872.1445])
# Day 132: 2022-07-22 00:00:00 - Predicted: tensor([60999.4414])
# Day 133: 2022-07-23 00:00:00 - Predicted: tensor([61126.9922])
# Day 134: 2022-07-24 00:00:00 - Predicted: tensor([61254.8203])
# Day 135: 2022-07-25 00:00:00 - Predicted: tensor([61382.9141])
# Day 136: 2022-07-26 00:00:00 - Predicted: tensor([61511.2812])
# Day 137: 2022-07-27 00:00:00 - Predicted: tensor([61639.9062])
# Day 138: 2022-07-28 00:00:00 - Predicted: tensor([61768.7891])
# Day 139: 2022-07-29 00:00:00 - Predicted: tensor([61897.9648])
# Day 140: 2022-07-30 00:00:00 - Predicted: tensor([62027.3945])
# Day 141: 2022-07-31 00:00:00 - Predicted: tensor([62157.1055])
# Day 142: 2022-08-01 00:00:00 - Predicted: tensor([62287.0820])
# Day 143: 2022-08-02 00:00:00 - Predicted: tensor([62417.3359])
# Day 144: 2022-08-03 00:00:00 - Predicted: tensor([62547.8516])
# Day 145: 2022-08-04 00:00:00 - Predicted: tensor([62678.6484])
# Day 146: 2022-08-05 00:00:00 - Predicted: tensor([62809.7188])
# Day 147: 2022-08-06 00:00:00 - Predicted: tensor([62941.0625])
# Day 148: 2022-08-07 00:00:00 - Predicted: tensor([63072.6836])
# Day 149: 2022-08-08 00:00:00 - Predicted: tensor([63204.5664])
# Day 150: 2022-08-09 00:00:00 - Predicted: tensor([63336.7383])
# Day 151: 2022-08-10 00:00:00 - Predicted: tensor([63469.1875])
# Day 152: 2022-08-11 00:00:00 - Predicted: tensor([63601.9062])
# Day 153: 2022-08-12 00:00:00 - Predicted: tensor([63734.9023])
# Day 154: 2022-08-13 00:00:00 - Predicted: tensor([63868.1836])
# Day 155: 2022-08-14 00:00:00 - Predicted: tensor([64001.7422])
# Day 156: 2022-08-15 00:00:00 - Predicted: tensor([64135.5742])
# Day 157: 2022-08-16 00:00:00 - Predicted: tensor([64269.6875])
# Day 158: 2022-08-17 00:00:00 - Predicted: tensor([64404.0820])
# Day 159: 2022-08-18 00:00:00 - Predicted: tensor([64538.7656])
# Day 160: 2022-08-19 00:00:00 - Predicted: tensor([64673.7188])
# Day 161: 2022-08-20 00:00:00 - Predicted: tensor([64808.9609])
# Day 162: 2022-08-21 00:00:00 - Predicted: tensor([64944.4805])
# Day 163: 2022-08-22 00:00:00 - Predicted: tensor([65080.2930])
# Day 164: 2022-08-23 00:00:00 - Predicted: tensor([65216.3789])
# Day 165: 2022-08-24 00:00:00 - Predicted: tensor([65352.7539])
# Day 166: 2022-08-25 00:00:00 - Predicted: tensor([65489.4180])
# Day 167: 2022-08-26 00:00:00 - Predicted: tensor([65626.3594])
# Day 168: 2022-08-27 00:00:00 - Predicted: tensor([65763.5938])
# Day 169: 2022-08-28 00:00:00 - Predicted: tensor([65901.1172])
# Day 170: 2022-08-29 00:00:00 - Predicted: tensor([66038.9297])
# Day 171: 2022-08-30 00:00:00 - Predicted: tensor([66177.0156])
# Day 172: 2022-08-31 00:00:00 - Predicted: tensor([66315.3984])
# Day 173: 2022-09-01 00:00:00 - Predicted: tensor([66454.0781])
# Day 174: 2022-09-02 00:00:00 - Predicted: tensor([66593.0312])
# Day 175: 2022-09-03 00:00:00 - Predicted: tensor([66732.2891])
# Day 176: 2022-09-04 00:00:00 - Predicted: tensor([66871.8359])
# Day 177: 2022-09-05 00:00:00 - Predicted: tensor([67011.6797])
# Day 178: 2022-09-06 00:00:00 - Predicted: tensor([67151.8047])
# Day 179: 2022-09-07 00:00:00 - Predicted: tensor([67292.2344])
# Day 180: 2022-09-08 00:00:00 - Predicted: tensor([67432.9453])
# Day 181: 2022-09-09 00:00:00 - Predicted: tensor([67573.9453])
# Day 182: 2022-09-10 00:00:00 - Predicted: tensor([67715.2656])
# Day 183: 2022-09-11 00:00:00 - Predicted: tensor([67856.8594])
# Day 184: 2022-09-12 00:00:00 - Predicted: tensor([67998.7500])
# Day 185: 2022-09-13 00:00:00 - Predicted: tensor([68140.9453])
# Day 186: 2022-09-14 00:00:00 - Predicted: tensor([68283.4375])
# Day 187: 2022-09-15 00:00:00 - Predicted: tensor([68426.2344])
# Day 188: 2022-09-16 00:00:00 - Predicted: tensor([68569.3047])
# Day 189: 2022-09-17 00:00:00 - Predicted: tensor([68712.7031])
# Day 190: 2022-09-18 00:00:00 - Predicted: tensor([68856.3828])
# Day 191: 2022-09-19 00:00:00 - Predicted: tensor([69000.3828])
# Day 192: 2022-09-20 00:00:00 - Predicted: tensor([69144.6641])
# Day 193: 2022-09-21 00:00:00 - Predicted: tensor([69289.2656])
# Day 194: 2022-09-22 00:00:00 - Predicted: tensor([69434.1484])
# Day 195: 2022-09-23 00:00:00 - Predicted: tensor([69579.3438])
# Day 196: 2022-09-24 00:00:00 - Predicted: tensor([69724.8438])
# Day 197: 2022-09-25 00:00:00 - Predicted: tensor([69870.6484])
# Day 198: 2022-09-26 00:00:00 - Predicted: tensor([70016.7500])
# Day 199: 2022-09-27 00:00:00 - Predicted: tensor([70163.1641])
# Day 200: 2022-09-28 00:00:00 - Predicted: tensor([70309.8828])
# Day 201: 2022-09-29 00:00:00 - Predicted: tensor([70456.9219])
# Day 202: 2022-09-30 00:00:00 - Predicted: tensor([70604.2422])
# Day 203: 2022-10-01 00:00:00 - Predicted: tensor([70751.8906])
# Day 204: 2022-10-02 00:00:00 - Predicted: tensor([70899.8359])
# Day 205: 2022-10-03 00:00:00 - Predicted: tensor([71048.1016])
# Day 206: 2022-10-04 00:00:00 - Predicted: tensor([71196.6719])
# Day 207: 2022-10-05 00:00:00 - Predicted: tensor([71345.5547])
# Day 208: 2022-10-06 00:00:00 - Predicted: tensor([71494.7422])
# Day 209: 2022-10-07 00:00:00 - Predicted: tensor([71644.2500])
# Day 210: 2022-10-08 00:00:00 - Predicted: tensor([71794.0625])
# Day 211: 2022-10-09 00:00:00 - Predicted: tensor([71944.1875])
# Day 212: 2022-10-10 00:00:00 - Predicted: tensor([72094.6328])
# Day 213: 2022-10-11 00:00:00 - Predicted: tensor([72245.4062])
# Day 214: 2022-10-12 00:00:00 - Predicted: tensor([72396.4688])
# Day 215: 2022-10-13 00:00:00 - Predicted: tensor([72547.8594])
# Day 216: 2022-10-14 00:00:00 - Predicted: tensor([72699.5703])
# Day 217: 2022-10-15 00:00:00 - Predicted: tensor([72851.5859])
# Day 218: 2022-10-16 00:00:00 - Predicted: tensor([73003.9297])
# Day 219: 2022-10-17 00:00:00 - Predicted: tensor([73156.5859])
# Day 220: 2022-10-18 00:00:00 - Predicted: tensor([73309.5703])
# Day 221: 2022-10-19 00:00:00 - Predicted: tensor([73462.8750])
# Day 222: 2022-10-20 00:00:00 - Predicted: tensor([73616.5000])
# Day 223: 2022-10-21 00:00:00 - Predicted: tensor([73770.4375])
# Day 224: 2022-10-22 00:00:00 - Predicted: tensor([73924.6875])
# Day 225: 2022-10-23 00:00:00 - Predicted: tensor([74079.2891])
# Day 226: 2022-10-24 00:00:00 - Predicted: tensor([74234.1875])
# Day 227: 2022-10-25 00:00:00 - Predicted: tensor([74389.4297])
# Day 228: 2022-10-26 00:00:00 - Predicted: tensor([74544.9844])
# Day 229: 2022-10-27 00:00:00 - Predicted: tensor([74700.8672])
# Day 230: 2022-10-28 00:00:00 - Predicted: tensor([74857.0703])
# Day 231: 2022-10-29 00:00:00 - Predicted: tensor([75013.6016])
# Day 232: 2022-10-30 00:00:00 - Predicted: tensor([75170.4766])
# Day 233: 2022-10-31 00:00:00 - Predicted: tensor([75327.6641])
# Day 234: 2022-11-01 00:00:00 - Predicted: tensor([75485.1797])
# Day 235: 2022-11-02 00:00:00 - Predicted: tensor([75643.0312])
# Day 236: 2022-11-03 00:00:00 - Predicted: tensor([75801.2188])
# Day 237: 2022-11-04 00:00:00 - Predicted: tensor([75959.7188])
# Day 238: 2022-11-05 00:00:00 - Predicted: tensor([76118.5625])
# Day 239: 2022-11-06 00:00:00 - Predicted: tensor([76277.7344])
# Day 240: 2022-11-07 00:00:00 - Predicted: tensor([76437.2500])
# Day 241: 2022-11-08 00:00:00 - Predicted: tensor([76597.0781])
# Day 242: 2022-11-09 00:00:00 - Predicted: tensor([76757.2656])
# Day 243: 2022-11-10 00:00:00 - Predicted: tensor([76917.7656])
# Day 244: 2022-11-11 00:00:00 - Predicted: tensor([77078.6016])
# Day 245: 2022-11-12 00:00:00 - Predicted: tensor([77239.7812])
# Day 246: 2022-11-13 00:00:00 - Predicted: tensor([77401.2969])
# Day 247: 2022-11-14 00:00:00 - Predicted: tensor([77563.1406])
# Day 248: 2022-11-15 00:00:00 - Predicted: tensor([77725.3516])
# Day 249: 2022-11-16 00:00:00 - Predicted: tensor([77887.8828])
# Day 250: 2022-11-17 00:00:00 - Predicted: tensor([78050.7656])
# Day 251: 2022-11-18 00:00:00 - Predicted: tensor([78213.9688])
# Day 252: 2022-11-19 00:00:00 - Predicted: tensor([78377.5312])
# Day 253: 2022-11-20 00:00:00 - Predicted: tensor([78541.4297])
# Day 254: 2022-11-21 00:00:00 - Predicted: tensor([78705.6641])
# Day 255: 2022-11-22 00:00:00 - Predicted: tensor([78870.2500])
# Day 256: 2022-11-23 00:00:00 - Predicted: tensor([79035.1719])
# Day 257: 2022-11-24 00:00:00 - Predicted: tensor([79200.4531])
# Day 258: 2022-11-25 00:00:00 - Predicted: tensor([79366.0547])
# Day 259: 2022-11-26 00:00:00 - Predicted: tensor([79532.0234])
# Day 260: 2022-11-27 00:00:00 - Predicted: tensor([79698.3438])
# Day 261: 2022-11-28 00:00:00 - Predicted: tensor([79865.])
# Day 262: 2022-11-29 00:00:00 - Predicted: tensor([80032.0156])
# Day 263: 2022-11-30 00:00:00 - Predicted: tensor([80199.3672])
# Day 264: 2022-12-01 00:00:00 - Predicted: tensor([80367.0703])
# Day 265: 2022-12-02 00:00:00 - Predicted: tensor([80535.1328])
# Day 266: 2022-12-03 00:00:00 - Predicted: tensor([80703.5391])
# Day 267: 2022-12-04 00:00:00 - Predicted: tensor([80872.2891])
# Day 268: 2022-12-05 00:00:00 - Predicted: tensor([81041.4141])
# Day 269: 2022-12-06 00:00:00 - Predicted: tensor([81210.8906])
# Day 270: 2022-12-07 00:00:00 - Predicted: tensor([81380.7031])
# Day 271: 2022-12-08 00:00:00 - Predicted: tensor([81550.8828])
# Day 272: 2022-12-09 00:00:00 - Predicted: tensor([81721.4141])
# Day 273: 2022-12-10 00:00:00 - Predicted: tensor([81892.3125])
# Day 274: 2022-12-11 00:00:00 - Predicted: tensor([82063.5547])
# Day 275: 2022-12-12 00:00:00 - Predicted: tensor([82235.1562])
# Day 276: 2022-12-13 00:00:00 - Predicted: tensor([82407.1250])
# Day 277: 2022-12-14 00:00:00 - Predicted: tensor([82579.4453])
# Day 278: 2022-12-15 00:00:00 - Predicted: tensor([82752.1250])
# Day 279: 2022-12-16 00:00:00 - Predicted: tensor([82925.1719])
# Day 280: 2022-12-17 00:00:00 - Predicted: tensor([83098.5781])
# Day 281: 2022-12-18 00:00:00 - Predicted: tensor([83272.3516])
# Day 282: 2022-12-19 00:00:00 - Predicted: tensor([83446.4844])
# Day 283: 2022-12-20 00:00:00 - Predicted: tensor([83620.9766])
# Day 284: 2022-12-21 00:00:00 - Predicted: tensor([83795.8438])
# Day 285: 2022-12-22 00:00:00 - Predicted: tensor([83971.0703])
# Day 286: 2022-12-23 00:00:00 - Predicted: tensor([84146.6562])
# Day 287: 2022-12-24 00:00:00 - Predicted: tensor([84322.6172])
# Day 288: 2022-12-25 00:00:00 - Predicted: tensor([84498.9531])
# Day 289: 2022-12-26 00:00:00 - Predicted: tensor([84675.6484])
# Day 290: 2022-12-27 00:00:00 - Predicted: tensor([84852.7188])
# Day 291: 2022-12-28 00:00:00 - Predicted: tensor([85030.1484])
# Day 292: 2022-12-29 00:00:00 - Predicted: tensor([85207.9609])
# Day 293: 2022-12-30 00:00:00 - Predicted: tensor([85386.1406])
# Day 294: 2022-12-31 00:00:00 - Predicted: tensor([85564.6953])
# Day 295: 2023-01-01 00:00:00 - Predicted: tensor([85743.6172])
# Day 296: 2023-01-02 00:00:00 - Predicted: tensor([85922.9297])
# Day 297: 2023-01-03 00:00:00 - Predicted: tensor([86102.5938])
# Day 298: 2023-01-04 00:00:00 - Predicted: tensor([86282.6484])
# Day 299: 2023-01-05 00:00:00 - Predicted: tensor([86463.0781])
# Day 300: 2023-01-06 00:00:00 - Predicted: tensor([86643.8906])
# Day 301: 2023-01-07 00:00:00 - Predicted: tensor([86825.0625])
# Day 302: 2023-01-08 00:00:00 - Predicted: tensor([87006.6328])
# Day 303: 2023-01-09 00:00:00 - Predicted: tensor([87188.5625])
# Day 304: 2023-01-10 00:00:00 - Predicted: tensor([87370.8984])
# Day 305: 2023-01-11 00:00:00 - Predicted: tensor([87553.5859])
# Day 306: 2023-01-12 00:00:00 - Predicted: tensor([87736.6797])
# Day 307: 2023-01-13 00:00:00 - Predicted: tensor([87920.1484])
# Day 308: 2023-01-14 00:00:00 - Predicted: tensor([88104.0078])
# Day 309: 2023-01-15 00:00:00 - Predicted: tensor([88288.2500])
# Day 310: 2023-01-16 00:00:00 - Predicted: tensor([88472.8516])
# Day 311: 2023-01-17 00:00:00 - Predicted: tensor([88657.8594])
# Day 312: 2023-01-18 00:00:00 - Predicted: tensor([88843.2578])
# Day 313: 2023-01-19 00:00:00 - Predicted: tensor([89029.0391])
# Day 314: 2023-01-20 00:00:00 - Predicted: tensor([89215.2109])
# Day 315: 2023-01-21 00:00:00 - Predicted: tensor([89401.7734])
# Day 316: 2023-01-22 00:00:00 - Predicted: tensor([89588.7266])
# Day 317: 2023-01-23 00:00:00 - Predicted: tensor([89776.0781])
# Day 318: 2023-01-24 00:00:00 - Predicted: tensor([89963.7969])
# Day 319: 2023-01-25 00:00:00 - Predicted: tensor([90151.9297])
# Day 320: 2023-01-26 00:00:00 - Predicted: tensor([90340.4375])
# Day 321: 2023-01-27 00:00:00 - Predicted: tensor([90529.3516])
# Day 322: 2023-01-28 00:00:00 - Predicted: tensor([90718.6641])
# Day 323: 2023-01-29 00:00:00 - Predicted: tensor([90908.3828])
# Day 324: 2023-01-30 00:00:00 - Predicted: tensor([91098.4609])
# Day 325: 2023-01-31 00:00:00 - Predicted: tensor([91288.9688])
# Day 326: 2023-02-01 00:00:00 - Predicted: tensor([91479.8672])
# Day 327: 2023-02-02 00:00:00 - Predicted: tensor([91671.1562])
# Day 328: 2023-02-03 00:00:00 - Predicted: tensor([91862.8516])
# Day 329: 2023-02-04 00:00:00 - Predicted: tensor([92054.9531])
# Day 330: 2023-02-05 00:00:00 - Predicted: tensor([92247.4609])
# Day 331: 2023-02-06 00:00:00 - Predicted: tensor([92440.3516])
# Day 332: 2023-02-07 00:00:00 - Predicted: tensor([92633.6562])
# Day 333: 2023-02-08 00:00:00 - Predicted: tensor([92827.3672])
# Day 334: 2023-02-09 00:00:00 - Predicted: tensor([93021.4688])
# Day 335: 2023-02-10 00:00:00 - Predicted: tensor([93216.])
# Day 336: 2023-02-11 00:00:00 - Predicted: tensor([93410.9219])
# Day 337: 2023-02-12 00:00:00 - Predicted: tensor([93606.2578])
# Day 338: 2023-02-13 00:00:00 - Predicted: tensor([93801.9922])
# Day 339: 2023-02-14 00:00:00 - Predicted: tensor([93998.1562])
# Day 340: 2023-02-15 00:00:00 - Predicted: tensor([94194.7109])
# Day 341: 2023-02-16 00:00:00 - Predicted: tensor([94391.6797])
# Day 342: 2023-02-17 00:00:00 - Predicted: tensor([94589.0781])
# Day 343: 2023-02-18 00:00:00 - Predicted: tensor([94786.8750])
# Day 344: 2023-02-19 00:00:00 - Predicted: tensor([94985.0859])
# Day 345: 2023-02-20 00:00:00 - Predicted: tensor([95183.7031])
# Day 346: 2023-02-21 00:00:00 - Predicted: tensor([95382.7422])
# Day 347: 2023-02-22 00:00:00 - Predicted: tensor([95582.1953])
# Day 348: 2023-02-23 00:00:00 - Predicted: tensor([95782.0781])
# Day 349: 2023-02-24 00:00:00 - Predicted: tensor([95982.3672])
# Day 350: 2023-02-25 00:00:00 - Predicted: tensor([96183.0781])
# Day 351: 2023-02-26 00:00:00 - Predicted: tensor([96384.2109])
# Day 352: 2023-02-27 00:00:00 - Predicted: tensor([96585.7578])
# Day 353: 2023-02-28 00:00:00 - Predicted: tensor([96787.7344])
# Day 354: 2023-03-01 00:00:00 - Predicted: tensor([96990.1328])
# Day 355: 2023-03-02 00:00:00 - Predicted: tensor([97192.9531])
# Day 356: 2023-03-03 00:00:00 - Predicted: tensor([97396.1953])
# Day 357: 2023-03-04 00:00:00 - Predicted: tensor([97599.8594])
# Day 358: 2023-03-05 00:00:00 - Predicted: tensor([97803.9531])
# Day 359: 2023-03-06 00:00:00 - Predicted: tensor([98008.4688])
# Day 360: 2023-03-07 00:00:00 - Predicted: tensor([98213.4375])
# Day 361: 2023-03-08 00:00:00 - Predicted: tensor([98418.8047])
# Day 362: 2023-03-09 00:00:00 - Predicted: tensor([98624.6094])
# Day 363: 2023-03-10 00:00:00 - Predicted: tensor([98830.8359])
# Day 364: 2023-03-11 00:00:00 - Predicted: tensor([99037.5078])
# Day 365: 2023-03-12 00:00:00 - Predicted: tensor([99244.6094])
# Day 366: 2023-03-13 00:00:00 - Predicted: tensor([99452.1406])
# Day 367: 2023-03-14 00:00:00 - Predicted: tensor([99660.1094])
# Day 368: 2023-03-15 00:00:00 - Predicted: tensor([99868.5156])
# Day 369: 2023-03-16 00:00:00 - Predicted: tensor([100077.3438])
# Day 370: 2023-03-17 00:00:00 - Predicted: tensor([100286.6250])
# Day 371: 2023-03-18 00:00:00 - Predicted: tensor([100496.3438])
# Day 372: 2023-03-19 00:00:00 - Predicted: tensor([100706.4766])
# Day 373: 2023-03-20 00:00:00 - Predicted: tensor([100917.0781])
# Day 374: 2023-03-21 00:00:00 - Predicted: tensor([101128.1094])
# Day 375: 2023-03-22 00:00:00 - Predicted: tensor([101339.5781])
# Day 376: 2023-03-23 00:00:00 - Predicted: tensor([101551.4922])
# Day 377: 2023-03-24 00:00:00 - Predicted: tensor([101763.8438])
# Day 378: 2023-03-25 00:00:00 - Predicted: tensor([101976.6562])
# Day 379: 2023-03-26 00:00:00 - Predicted: tensor([102189.8984])
# Day 380: 2023-03-27 00:00:00 - Predicted: tensor([102403.5938])
# Day 381: 2023-03-28 00:00:00 - Predicted: tensor([102617.7344])
# Day 382: 2023-03-29 00:00:00 - Predicted: tensor([102832.3203])
# Day 383: 2023-03-30 00:00:00 - Predicted: tensor([103047.3594])
# Day 384: 2023-03-31 00:00:00 - Predicted: tensor([103262.8438])
# Day 385: 2023-04-01 00:00:00 - Predicted: tensor([103478.7812])
# Day 386: 2023-04-02 00:00:00 - Predicted: tensor([103695.1484])
# Day 387: 2023-04-03 00:00:00 - Predicted: tensor([103912.])
# Day 388: 2023-04-04 00:00:00 - Predicted: tensor([104129.2891])
# Day 389: 2023-04-05 00:00:00 - Predicted: tensor([104347.0469])
# Day 390: 2023-04-06 00:00:00 - Predicted: tensor([104565.2500])
# Day 391: 2023-04-07 00:00:00 - Predicted: tensor([104783.9062])
# Day 392: 2023-04-08 00:00:00 - Predicted: tensor([105003.0156])
# Day 393: 2023-04-09 00:00:00 - Predicted: tensor([105222.5938])
# Day 394: 2023-04-10 00:00:00 - Predicted: tensor([105442.6250])
# Day 395: 2023-04-11 00:00:00 - Predicted: tensor([105663.1172])
# Day 396: 2023-04-12 00:00:00 - Predicted: tensor([105884.0781])
# Day 397: 2023-04-13 00:00:00 - Predicted: tensor([106105.5000])
# Day 398: 2023-04-14 00:00:00 - Predicted: tensor([106327.3750])
# Day 399: 2023-04-15 00:00:00 - Predicted: tensor([106549.7188])
# Day 400: 2023-04-16 00:00:00 - Predicted: tensor([106772.5312])
# Day 401: 2023-04-17 00:00:00 - Predicted: tensor([106995.7969])
# Day 402: 2023-04-18 00:00:00 - Predicted: tensor([107219.5391])
# Day 403: 2023-04-19 00:00:00 - Predicted: tensor([107443.7422])
# Day 404: 2023-04-20 00:00:00 - Predicted: tensor([107668.4375])
# Day 405: 2023-04-21 00:00:00 - Predicted: tensor([107893.5859])
# Day 406: 2023-04-22 00:00:00 - Predicted: tensor([108119.1953])
# Day 407: 2023-04-23 00:00:00 - Predicted: tensor([108345.2891])
# Day 408: 2023-04-24 00:00:00 - Predicted: tensor([108571.8594])
# Day 409: 2023-04-25 00:00:00 - Predicted: tensor([108798.8984])
# Day 410: 2023-04-26 00:00:00 - Predicted: tensor([109026.4062])
# Day 411: 2023-04-27 00:00:00 - Predicted: tensor([109254.3984])
# Day 412: 2023-04-28 00:00:00 - Predicted: tensor([109482.8516])
# Day 413: 2023-04-29 00:00:00 - Predicted: tensor([109711.7891])
# Day 414: 2023-04-30 00:00:00 - Predicted: tensor([109941.2188])
# Day 415: 2023-05-01 00:00:00 - Predicted: tensor([110171.1172])
# Day 416: 2023-05-02 00:00:00 - Predicted: tensor([110401.5000])
# Day 417: 2023-05-03 00:00:00 - Predicted: tensor([110632.3672])
# Day 418: 2023-05-04 00:00:00 - Predicted: tensor([110863.7031])
# Day 419: 2023-05-05 00:00:00 - Predicted: tensor([111095.5312])
# Day 420: 2023-05-06 00:00:00 - Predicted: tensor([111327.8516])
# Day 421: 2023-05-07 00:00:00 - Predicted: tensor([111560.6484])
# Day 422: 2023-05-08 00:00:00 - Predicted: tensor([111793.9453])
# Day 423: 2023-05-09 00:00:00 - Predicted: tensor([112027.7188])
# Day 424: 2023-05-10 00:00:00 - Predicted: tensor([112261.9844])
# Day 425: 2023-05-11 00:00:00 - Predicted: tensor([112496.7266])
# Day 426: 2023-05-12 00:00:00 - Predicted: tensor([112731.9766])
# Day 427: 2023-05-13 00:00:00 - Predicted: tensor([112967.7266])
# Day 428: 2023-05-14 00:00:00 - Predicted: tensor([113203.9453])
# Day 429: 2023-05-15 00:00:00 - Predicted: tensor([113440.6875])
# Day 430: 2023-05-16 00:00:00 - Predicted: tensor([113677.8906])
# Day 431: 2023-05-17 00:00:00 - Predicted: tensor([113915.6016])
# Day 432: 2023-05-18 00:00:00 - Predicted: tensor([114153.8047])
# Day 433: 2023-05-19 00:00:00 - Predicted: tensor([114392.5312])
# Day 434: 2023-05-20 00:00:00 - Predicted: tensor([114631.7344])
# Day 435: 2023-05-21 00:00:00 - Predicted: tensor([114871.4375])
# Day 436: 2023-05-22 00:00:00 - Predicted: tensor([115111.6562])
# Day 437: 2023-05-23 00:00:00 - Predicted: tensor([115352.3594])
# Day 438: 2023-05-24 00:00:00 - Predicted: tensor([115593.5938])
# Day 439: 2023-05-25 00:00:00 - Predicted: tensor([115835.3047])
# Day 440: 2023-05-26 00:00:00 - Predicted: tensor([116077.5312])
# Day 441: 2023-05-27 00:00:00 - Predicted: tensor([116320.2734])
# Day 442: 2023-05-28 00:00:00 - Predicted: tensor([116563.5078])
# Day 443: 2023-05-29 00:00:00 - Predicted: tensor([116807.2656])
# Day 444: 2023-05-30 00:00:00 - Predicted: tensor([117051.5234])
# Day 445: 2023-05-31 00:00:00 - Predicted: tensor([117296.2891])
# Day 446: 2023-06-01 00:00:00 - Predicted: tensor([117541.5703])
# Day 447: 2023-06-02 00:00:00 - Predicted: tensor([117787.3672])
# Day 448: 2023-06-03 00:00:00 - Predicted: tensor([118033.6797])
# Day 449: 2023-06-04 00:00:00 - Predicted: tensor([118280.4844])
# Day 450: 2023-06-05 00:00:00 - Predicted: tensor([118527.8281])
# Day 451: 2023-06-06 00:00:00 - Predicted: tensor([118775.6875])
# Day 452: 2023-06-07 00:00:00 - Predicted: tensor([119024.0547])
# Day 453: 2023-06-08 00:00:00 - Predicted: tensor([119272.9609])
# Day 454: 2023-06-09 00:00:00 - Predicted: tensor([119522.3828])
# Day 455: 2023-06-10 00:00:00 - Predicted: tensor([119772.3125])
# Day 456: 2023-06-11 00:00:00 - Predicted: tensor([120022.7734])
# Day 457: 2023-06-12 00:00:00 - Predicted: tensor([120273.7500])
# Day 458: 2023-06-13 00:00:00 - Predicted: tensor([120525.2656])
# Day 459: 2023-06-14 00:00:00 - Predicted: tensor([120777.2969])
# Day 460: 2023-06-15 00:00:00 - Predicted: tensor([121029.8594])
# Day 461: 2023-06-16 00:00:00 - Predicted: tensor([121282.9531])
# Day 462: 2023-06-17 00:00:00 - Predicted: tensor([121536.5625])
# Day 463: 2023-06-18 00:00:00 - Predicted: tensor([121790.7109])
# Day 464: 2023-06-19 00:00:00 - Predicted: tensor([122045.3984])
# Day 465: 2023-06-20 00:00:00 - Predicted: tensor([122300.6016])
# Day 466: 2023-06-21 00:00:00 - Predicted: tensor([122556.3438])
# Day 467: 2023-06-22 00:00:00 - Predicted: tensor([122812.6250])
# Day 468: 2023-06-23 00:00:00 - Predicted: tensor([123069.4609])
# Day 469: 2023-06-24 00:00:00 - Predicted: tensor([123326.8047])
# Day 470: 2023-06-25 00:00:00 - Predicted: tensor([123584.6953])
# Day 471: 2023-06-26 00:00:00 - Predicted: tensor([123843.1250])
# Day 472: 2023-06-27 00:00:00 - Predicted: tensor([124102.0938])
# Day 473: 2023-06-28 00:00:00 - Predicted: tensor([124361.6094])
# Day 474: 2023-06-29 00:00:00 - Predicted: tensor([124621.6719])
# Day 475: 2023-06-30 00:00:00 - Predicted: tensor([124882.2734])
# Day 476: 2023-07-01 00:00:00 - Predicted: tensor([125143.4219])
# Day 477: 2023-07-02 00:00:00 - Predicted: tensor([125405.1094])
# Day 478: 2023-07-03 00:00:00 - Predicted: tensor([125667.3359])
# Day 479: 2023-07-04 00:00:00 - Predicted: tensor([125930.1328])
# Day 480: 2023-07-05 00:00:00 - Predicted: tensor([126193.4609])
# Day 481: 2023-07-06 00:00:00 - Predicted: tensor([126457.3594])
# Day 482: 2023-07-07 00:00:00 - Predicted: tensor([126721.7891])
# Day 483: 2023-07-08 00:00:00 - Predicted: tensor([126986.7734])
# Day 484: 2023-07-09 00:00:00 - Predicted: tensor([127252.3281])
# Day 485: 2023-07-10 00:00:00 - Predicted: tensor([127518.4219])
# Day 486: 2023-07-11 00:00:00 - Predicted: tensor([127785.0781])
# Day 487: 2023-07-12 00:00:00 - Predicted: tensor([128052.3047])
# Day 488: 2023-07-13 00:00:00 - Predicted: tensor([128320.0859])
# Day 489: 2023-07-14 00:00:00 - Predicted: tensor([128588.4141])
# Day 490: 2023-07-15 00:00:00 - Predicted: tensor([128857.3125])
# Day 491: 2023-07-16 00:00:00 - Predicted: tensor([129126.7734])
# Day 492: 2023-07-17 00:00:00 - Predicted: tensor([129396.7891])
# Day 493: 2023-07-18 00:00:00 - Predicted: tensor([129667.3594])
# Day 494: 2023-07-19 00:00:00 - Predicted: tensor([129938.5234])
# Day 495: 2023-07-20 00:00:00 - Predicted: tensor([130210.2344])
# Day 496: 2023-07-21 00:00:00 - Predicted: tensor([130482.5312])
# Day 497: 2023-07-22 00:00:00 - Predicted: tensor([130755.3906])
# Day 498: 2023-07-23 00:00:00 - Predicted: tensor([131028.8125])
# Day 499: 2023-07-24 00:00:00 - Predicted: tensor([131302.7969])
# Day 500: 2023-07-25 00:00:00 - Predicted: tensor([131577.3750])
# Day 501: 2023-07-26 00:00:00 - Predicted: tensor([131852.5312])
# Day 502: 2023-07-27 00:00:00 - Predicted: tensor([132128.2344])
# Day 503: 2023-07-28 00:00:00 - Predicted: tensor([132404.5312])
# Day 504: 2023-07-29 00:00:00 - Predicted: tensor([132681.4375])
# Day 505: 2023-07-30 00:00:00 - Predicted: tensor([132958.8750])
# Day 506: 2023-07-31 00:00:00 - Predicted: tensor([133236.9062])
# Day 507: 2023-08-01 00:00:00 - Predicted: tensor([133515.5312])
# Day 508: 2023-08-02 00:00:00 - Predicted: tensor([133794.7188])
# Day 509: 2023-08-03 00:00:00 - Predicted: tensor([134074.5000])
# Day 510: 2023-08-04 00:00:00 - Predicted: tensor([134354.8750])
# Day 511: 2023-08-05 00:00:00 - Predicted: tensor([134635.8438])
# Day 512: 2023-08-06 00:00:00 - Predicted: tensor([134917.3594])
# Day 513: 2023-08-07 00:00:00 - Predicted: tensor([135199.5000])
# Day 514: 2023-08-08 00:00:00 - Predicted: tensor([135482.2188])
# Day 515: 2023-08-09 00:00:00 - Predicted: tensor([135765.5312])
# Day 516: 2023-08-10 00:00:00 - Predicted: tensor([136049.4375])
# Day 517: 2023-08-11 00:00:00 - Predicted: tensor([136333.9219])
# Day 518: 2023-08-12 00:00:00 - Predicted: tensor([136619.0156])
# Day 519: 2023-08-13 00:00:00 - Predicted: tensor([136904.7031])
# Day 520: 2023-08-14 00:00:00 - Predicted: tensor([137191.])
# Day 521: 2023-08-15 00:00:00 - Predicted: tensor([137477.8594])
# Day 522: 2023-08-16 00:00:00 - Predicted: tensor([137765.3438])
# Day 523: 2023-08-17 00:00:00 - Predicted: tensor([138053.4531])
# Day 524: 2023-08-18 00:00:00 - Predicted: tensor([138342.1406])
# Day 525: 2023-08-19 00:00:00 - Predicted: tensor([138631.4375])
# Day 526: 2023-08-20 00:00:00 - Predicted: tensor([138921.3281])
# Day 527: 2023-08-21 00:00:00 - Predicted: tensor([139211.8281])
# Day 528: 2023-08-22 00:00:00 - Predicted: tensor([139502.9375])
# Day 529: 2023-08-23 00:00:00 - Predicted: tensor([139794.6406])
# Day 530: 2023-08-24 00:00:00 - Predicted: tensor([140086.9844])
# Day 531: 2023-08-25 00:00:00 - Predicted: tensor([140379.9062])
# Day 532: 2023-08-26 00:00:00 - Predicted: tensor([140673.4688])
# Day 533: 2023-08-27 00:00:00 - Predicted: tensor([140967.6250])
# Day 534: 2023-08-28 00:00:00 - Predicted: tensor([141262.4219])
# Day 535: 2023-08-29 00:00:00 - Predicted: tensor([141557.8281])
# Day 536: 2023-08-30 00:00:00 - Predicted: tensor([141853.8281])
# Day 537: 2023-08-31 00:00:00 - Predicted: tensor([142150.4688])
# Day 538: 2023-09-01 00:00:00 - Predicted: tensor([142447.7344])
# Day 539: 2023-09-02 00:00:00 - Predicted: tensor([142745.5938])
# Day 540: 2023-09-03 00:00:00 - Predicted: tensor([143044.1094])
# Day 541: 2023-09-04 00:00:00 - Predicted: tensor([143343.2188])
# Day 542: 2023-09-05 00:00:00 - Predicted: tensor([143642.9688])
# Day 543: 2023-09-06 00:00:00 - Predicted: tensor([143943.3438])
# Day 544: 2023-09-07 00:00:00 - Predicted: tensor([144244.3594])
# Day 545: 2023-09-08 00:00:00 - Predicted: tensor([144546.])
# Day 546: 2023-09-09 00:00:00 - Predicted: tensor([144848.2500])
# Day 547: 2023-09-10 00:00:00 - Predicted: tensor([145151.1562])
# Day 548: 2023-09-11 00:00:00 - Predicted: tensor([145454.6875])
# Day 549: 2023-09-12 00:00:00 - Predicted: tensor([145758.8594])
# Day 550: 2023-09-13 00:00:00 - Predicted: tensor([146063.6562])
# Day 551: 2023-09-14 00:00:00 - Predicted: tensor([146369.0781])
# Day 552: 2023-09-15 00:00:00 - Predicted: tensor([146675.1719])
# Day 553: 2023-09-16 00:00:00 - Predicted: tensor([146981.8750])
# Day 554: 2023-09-17 00:00:00 - Predicted: tensor([147289.2344])
# Day 555: 2023-09-18 00:00:00 - Predicted: tensor([147597.2656])
# Day 556: 2023-09-19 00:00:00 - Predicted: tensor([147905.8906])
# Day 557: 2023-09-20 00:00:00 - Predicted: tensor([148215.1875])
# Day 558: 2023-09-21 00:00:00 - Predicted: tensor([148525.1094])
# Day 559: 2023-09-22 00:00:00 - Predicted: tensor([148835.7031])
# Day 560: 2023-09-23 00:00:00 - Predicted: tensor([149146.9219])
# Day 561: 2023-09-24 00:00:00 - Predicted: tensor([149458.8125])
# Day 562: 2023-09-25 00:00:00 - Predicted: tensor([149771.3594])
# Day 563: 2023-09-26 00:00:00 - Predicted: tensor([150084.5469])
# Day 564: 2023-09-27 00:00:00 - Predicted: tensor([150398.3906])
# Day 565: 2023-09-28 00:00:00 - Predicted: tensor([150712.9062])
# Day 566: 2023-09-29 00:00:00 - Predicted: tensor([151028.0469])
# Day 567: 2023-09-30 00:00:00 - Predicted: tensor([151343.8750])
# Day 568: 2023-10-01 00:00:00 - Predicted: tensor([151660.3750])
# Day 569: 2023-10-02 00:00:00 - Predicted: tensor([151977.5000])
# Day 570: 2023-10-03 00:00:00 - Predicted: tensor([152295.2969])
# Day 571: 2023-10-04 00:00:00 - Predicted: tensor([152613.7812])
# Day 572: 2023-10-05 00:00:00 - Predicted: tensor([152932.8906])
# Day 573: 2023-10-06 00:00:00 - Predicted: tensor([153252.7031])
# Day 574: 2023-10-07 00:00:00 - Predicted: tensor([153573.1875])
# Day 575: 2023-10-08 00:00:00 - Predicted: tensor([153894.3281])
# Day 576: 2023-10-09 00:00:00 - Predicted: tensor([154216.1406])
# Day 577: 2023-10-10 00:00:00 - Predicted: tensor([154538.6250])
# Day 578: 2023-10-11 00:00:00 - Predicted: tensor([154861.7969])
# Day 579: 2023-10-12 00:00:00 - Predicted: tensor([155185.6250])
# Day 580: 2023-10-13 00:00:00 - Predicted: tensor([155510.1250])
# Day 581: 2023-10-14 00:00:00 - Predicted: tensor([155835.3281])
# Day 582: 2023-10-15 00:00:00 - Predicted: tensor([156161.2031])
# Day 583: 2023-10-16 00:00:00 - Predicted: tensor([156487.7656])
# Day 584: 2023-10-17 00:00:00 - Predicted: tensor([156815.])
# Day 585: 2023-10-18 00:00:00 - Predicted: tensor([157142.9219])
# Day 586: 2023-10-19 00:00:00 - Predicted: tensor([157471.5156])
# Day 587: 2023-10-20 00:00:00 - Predicted: tensor([157800.7969])
# Day 588: 2023-10-21 00:00:00 - Predicted: tensor([158130.7969])
# Day 589: 2023-10-22 00:00:00 - Predicted: tensor([158461.4531])
# Day 590: 2023-10-23 00:00:00 - Predicted: tensor([158792.7969])
# Day 591: 2023-10-24 00:00:00 - Predicted: tensor([159124.8750])
# Day 592: 2023-10-25 00:00:00 - Predicted: tensor([159457.6406])
# Day 593: 2023-10-26 00:00:00 - Predicted: tensor([159791.0938])
# Day 594: 2023-10-27 00:00:00 - Predicted: tensor([160125.2344])
# Day 595: 2023-10-28 00:00:00 - Predicted: tensor([160460.0625])
# Day 596: 2023-10-29 00:00:00 - Predicted: tensor([160795.6250])
# Day 597: 2023-10-30 00:00:00 - Predicted: tensor([161131.8594])
# Day 598: 2023-10-31 00:00:00 - Predicted: tensor([161468.8125])
# Day 599: 2023-11-01 00:00:00 - Predicted: tensor([161806.4688])
# Day 600: 2023-11-02 00:00:00 - Predicted: tensor([162144.7969])
# Day 601: 2023-11-03 00:00:00 - Predicted: tensor([162483.8750])
# Day 602: 2023-11-04 00:00:00 - Predicted: tensor([162823.6562])
# Day 603: 2023-11-05 00:00:00 - Predicted: tensor([163164.1406])
# Day 604: 2023-11-06 00:00:00 - Predicted: tensor([163505.3438])
# Day 605: 2023-11-07 00:00:00 - Predicted: tensor([163847.2344])
# Day 606: 2023-11-08 00:00:00 - Predicted: tensor([164189.8750])
# Day 607: 2023-11-09 00:00:00 - Predicted: tensor([164533.2188])
# Day 608: 2023-11-10 00:00:00 - Predicted: tensor([164877.2812])
# Day 609: 2023-11-11 00:00:00 - Predicted: tensor([165222.0781])
# Day 610: 2023-11-12 00:00:00 - Predicted: tensor([165567.5312])
# Day 611: 2023-11-13 00:00:00 - Predicted: tensor([165913.7656])
# Day 612: 2023-11-14 00:00:00 - Predicted: tensor([166260.7031])
# Day 613: 2023-11-15 00:00:00 - Predicted: tensor([166608.4062])
# Day 614: 2023-11-16 00:00:00 - Predicted: tensor([166956.7969])
# Day 615: 2023-11-17 00:00:00 - Predicted: tensor([167305.9375])
# Day 616: 2023-11-18 00:00:00 - Predicted: tensor([167655.7969])
# Day 617: 2023-11-19 00:00:00 - Predicted: tensor([168006.3750])
# Day 618: 2023-11-20 00:00:00 - Predicted: tensor([168357.7031])
# Day 619: 2023-11-21 00:00:00 - Predicted: tensor([168709.7500])
# Day 620: 2023-11-22 00:00:00 - Predicted: tensor([169062.5625])
# Day 621: 2023-11-23 00:00:00 - Predicted: tensor([169416.0938])
# Day 622: 2023-11-24 00:00:00 - Predicted: tensor([169770.3438])
# Day 623: 2023-11-25 00:00:00 - Predicted: tensor([170125.3594])
# Day 624: 2023-11-26 00:00:00 - Predicted: tensor([170481.1250])
# Day 625: 2023-11-27 00:00:00 - Predicted: tensor([170837.6094])
# Day 626: 2023-11-28 00:00:00 - Predicted: tensor([171194.8750])
# Day 627: 2023-11-29 00:00:00 - Predicted: tensor([171552.8438])
# Day 628: 2023-11-30 00:00:00 - Predicted: tensor([171911.5938])
# Day 629: 2023-12-01 00:00:00 - Predicted: tensor([172271.0781])
# Day 630: 2023-12-02 00:00:00 - Predicted: tensor([172631.3438])
# Day 631: 2023-12-03 00:00:00 - Predicted: tensor([172992.3281])
# Day 632: 2023-12-04 00:00:00 - Predicted: tensor([173354.0625])
# Day 633: 2023-12-05 00:00:00 - Predicted: tensor([173716.5781])
# Day 634: 2023-12-06 00:00:00 - Predicted: tensor([174079.8594])
# Day 635: 2023-12-07 00:00:00 - Predicted: tensor([174443.8438])
# Day 636: 2023-12-08 00:00:00 - Predicted: tensor([174808.6562])
# Day 637: 2023-12-09 00:00:00 - Predicted: tensor([175174.2344])
# Day 638: 2023-12-10 00:00:00 - Predicted: tensor([175540.5156])
# Day 639: 2023-12-11 00:00:00 - Predicted: tensor([175907.6094])
# Day 640: 2023-12-12 00:00:00 - Predicted: tensor([176275.4375])
# Day 641: 2023-12-13 00:00:00 - Predicted: tensor([176644.0625])
# Day 642: 2023-12-14 00:00:00 - Predicted: tensor([177013.4375])
# Day 643: 2023-12-15 00:00:00 - Predicted: tensor([177383.5938])
# Day 644: 2023-12-16 00:00:00 - Predicted: tensor([177754.5156])
# Day 645: 2023-12-17 00:00:00 - Predicted: tensor([178126.2500])
# Day 646: 2023-12-18 00:00:00 - Predicted: tensor([178498.7188])
# Day 647: 2023-12-19 00:00:00 - Predicted: tensor([178872.])
# Day 648: 2023-12-20 00:00:00 - Predicted: tensor([179246.0469])
# Day 649: 2023-12-21 00:00:00 - Predicted: tensor([179620.8438])
# Day 650: 2023-12-22 00:00:00 - Predicted: tensor([179996.4844])
# Day 651: 2023-12-23 00:00:00 - Predicted: tensor([180372.8750])
# Day 652: 2023-12-24 00:00:00 - Predicted: tensor([180750.0469])
# Day 653: 2023-12-25 00:00:00 - Predicted: tensor([181128.0312])
# Day 654: 2023-12-26 00:00:00 - Predicted: tensor([181506.7812])
# Day 655: 2023-12-27 00:00:00 - Predicted: tensor([181886.3438])
# Day 656: 2023-12-28 00:00:00 - Predicted: tensor([182266.6719])
# Day 657: 2023-12-29 00:00:00 - Predicted: tensor([182647.8594])
# Day 658: 2023-12-30 00:00:00 - Predicted: tensor([183029.7812])
# Day 659: 2023-12-31 00:00:00 - Predicted: tensor([183412.5156])
# Day 660: 2024-01-01 00:00:00 - Predicted: tensor([183796.0625])
# Day 661: 2024-01-02 00:00:00 - Predicted: tensor([184180.4062])
# Day 662: 2024-01-03 00:00:00 - Predicted: tensor([184565.5469])
# Day 663: 2024-01-04 00:00:00 - Predicted: tensor([184951.4844])
# Day 664: 2024-01-05 00:00:00 - Predicted: tensor([185338.2500])
# Day 665: 2024-01-06 00:00:00 - Predicted: tensor([185725.8281])
# Day 666: 2024-01-07 00:00:00 - Predicted: tensor([186114.2031])
# Day 667: 2024-01-08 00:00:00 - Predicted: tensor([186503.3750])
# Day 668: 2024-01-09 00:00:00 - Predicted: tensor([186893.3750])
# Day 669: 2024-01-10 00:00:00 - Predicted: tensor([187284.2188])
# Day 670: 2024-01-11 00:00:00 - Predicted: tensor([187675.8594])
# Day 671: 2024-01-12 00:00:00 - Predicted: tensor([188068.2812])
# Day 672: 2024-01-13 00:00:00 - Predicted: tensor([188461.5625])
# Day 673: 2024-01-14 00:00:00 - Predicted: tensor([188855.6719])
# Day 674: 2024-01-15 00:00:00 - Predicted: tensor([189250.5781])
# Day 675: 2024-01-16 00:00:00 - Predicted: tensor([189646.3438])
# Day 676: 2024-01-17 00:00:00 - Predicted: tensor([190042.9062])
# Day 677: 2024-01-18 00:00:00 - Predicted: tensor([190440.3281])
# Day 678: 2024-01-19 00:00:00 - Predicted: tensor([190838.5625])
# Day 679: 2024-01-20 00:00:00 - Predicted: tensor([191237.6562])
# Day 680: 2024-01-21 00:00:00 - Predicted: tensor([191637.5312])
# Day 681: 2024-01-22 00:00:00 - Predicted: tensor([192038.2656])
# Day 682: 2024-01-23 00:00:00 - Predicted: tensor([192439.8594])
# Day 683: 2024-01-24 00:00:00 - Predicted: tensor([192842.2500])
# Day 684: 2024-01-25 00:00:00 - Predicted: tensor([193245.5156])
# Day 685: 2024-01-26 00:00:00 - Predicted: tensor([193649.6250])
# Day 686: 2024-01-27 00:00:00 - Predicted: tensor([194054.5625])
# Day 687: 2024-01-28 00:00:00 - Predicted: tensor([194460.3438])
# Day 688: 2024-01-29 00:00:00 - Predicted: tensor([194866.9844])
# Day 689: 2024-01-30 00:00:00 - Predicted: tensor([195274.5000])
# Day 690: 2024-01-31 00:00:00 - Predicted: tensor([195682.8281])
# Day 691: 2024-02-01 00:00:00 - Predicted: tensor([196092.0625])
# Day 692: 2024-02-02 00:00:00 - Predicted: tensor([196502.0938])
# Day 693: 2024-02-03 00:00:00 - Predicted: tensor([196913.0156])
# Day 694: 2024-02-04 00:00:00 - Predicted: tensor([197324.7812])
# Day 695: 2024-02-05 00:00:00 - Predicted: tensor([197737.4062])
# Day 696: 2024-02-06 00:00:00 - Predicted: tensor([198150.8906])
# Day 697: 2024-02-07 00:00:00 - Predicted: tensor([198565.2812])
# Day 698: 2024-02-08 00:00:00 - Predicted: tensor([198980.4844])
# Day 699: 2024-02-09 00:00:00 - Predicted: tensor([199396.5781])
# Day 700: 2024-02-10 00:00:00 - Predicted: tensor([199813.5469])
# Day 701: 2024-02-11 00:00:00 - Predicted: tensor([200231.3750])
# Day 702: 2024-02-12 00:00:00 - Predicted: tensor([200650.1094])
# Day 703: 2024-02-13 00:00:00 - Predicted: tensor([201069.6719])
# Day 704: 2024-02-14 00:00:00 - Predicted: tensor([201490.1250])
# Day 705: 2024-02-15 00:00:00 - Predicted: tensor([201911.4844])
# Day 706: 2024-02-16 00:00:00 - Predicted: tensor([202333.7188])
# Day 707: 2024-02-17 00:00:00 - Predicted: tensor([202756.7969])
# Day 708: 2024-02-18 00:00:00 - Predicted: tensor([203180.8125])
# Day 709: 2024-02-19 00:00:00 - Predicted: tensor([203605.7031])
# Day 710: 2024-02-20 00:00:00 - Predicted: tensor([204031.4688])
# Day 711: 2024-02-21 00:00:00 - Predicted: tensor([204458.0938])
# Day 712: 2024-02-22 00:00:00 - Predicted: tensor([204885.6562])
# Day 713: 2024-02-23 00:00:00 - Predicted: tensor([205314.0938])
# Day 714: 2024-02-24 00:00:00 - Predicted: tensor([205743.4531])
# Day 715: 2024-02-25 00:00:00 - Predicted: tensor([206173.6719])
# Day 716: 2024-02-26 00:00:00 - Predicted: tensor([206604.7812])
# Day 717: 2024-02-27 00:00:00 - Predicted: tensor([207036.8281])
# Day 718: 2024-02-28 00:00:00 - Predicted: tensor([207469.7812])
# Day 719: 2024-02-29 00:00:00 - Predicted: tensor([207903.6562])
# Day 720: 2024-03-01 00:00:00 - Predicted: tensor([208338.3750])
# Day 721: 2024-03-02 00:00:00 - Predicted: tensor([208774.0469])
# Day 722: 2024-03-03 00:00:00 - Predicted: tensor([209210.6250])
# Day 723: 2024-03-04 00:00:00 - Predicted: tensor([209648.1094])
# Day 724: 2024-03-05 00:00:00 - Predicted: tensor([210086.5312])
# Day 725: 2024-03-06 00:00:00 - Predicted: tensor([210525.8438])
# Day 726: 2024-03-07 00:00:00 - Predicted: tensor([210966.0625])
# Day 727: 2024-03-08 00:00:00 - Predicted: tensor([211407.2344])
# Day 728: 2024-03-09 00:00:00 - Predicted: tensor([211849.3281])
# Day 729: 2024-03-10 00:00:00 - Predicted: tensor([212292.3281])
# Day 730: 2024-03-11 00:00:00 - Predicted: tensor([212736.2500])
# Day 731: 2024-03-12 00:00:00 - Predicted: tensor([213181.1250])
# Day 732: 2024-03-13 00:00:00 - Predicted: tensor([213626.8750])
# Day 733: 2024-03-14 00:00:00 - Predicted: tensor([214073.6094])
# Day 734: 2024-03-15 00:00:00 - Predicted: tensor([214521.2656])
# Day 735: 2024-03-16 00:00:00 - Predicted: tensor([214969.8750])
# Day 736: 2024-03-17 00:00:00 - Predicted: tensor([215419.4062])
# Day 737: 2024-03-18 00:00:00 - Predicted: tensor([215869.8594])
# Day 738: 2024-03-19 00:00:00 - Predicted: tensor([216321.2812])
# Day 739: 2024-03-20 00:00:00 - Predicted: tensor([216773.6562])
# Day 740: 2024-03-21 00:00:00 - Predicted: tensor([217226.9219])
# Day 741: 2024-03-22 00:00:00 - Predicted: tensor([217681.1875])
# Day 742: 2024-03-23 00:00:00 - Predicted: tensor([218136.3750])
# Day 743: 2024-03-24 00:00:00 - Predicted: tensor([218592.5469])
# Day 744: 2024-03-25 00:00:00 - Predicted: tensor([219049.6250])
# Day 745: 2024-03-26 00:00:00 - Predicted: tensor([219507.7031])
# Day 746: 2024-03-27 00:00:00 - Predicted: tensor([219966.7500])
# Day 747: 2024-03-28 00:00:00 - Predicted: tensor([220426.7188])
# Day 748: 2024-03-29 00:00:00 - Predicted: tensor([220887.6562])
# Day 749: 2024-03-30 00:00:00 - Predicted: tensor([221349.5625])
# Day 750: 2024-03-31 00:00:00 - Predicted: tensor([221812.4219])
# Day 751: 2024-04-01 00:00:00 - Predicted: tensor([222276.2344])
# Day 752: 2024-04-02 00:00:00 - Predicted: tensor([222741.0625])
# Day 753: 2024-04-03 00:00:00 - Predicted: tensor([223206.8594])
# Day 754: 2024-04-04 00:00:00 - Predicted: tensor([223673.6094])
# Day 755: 2024-04-05 00:00:00 - Predicted: tensor([224141.3438])
# Day 756: 2024-04-06 00:00:00 - Predicted: tensor([224610.0312])
# Day 757: 2024-04-07 00:00:00 - Predicted: tensor([225079.7500])
# Day 758: 2024-04-08 00:00:00 - Predicted: tensor([225550.4219])
# Day 759: 2024-04-09 00:00:00 - Predicted: tensor([226022.0469])
# Day 760: 2024-04-10 00:00:00 - Predicted: tensor([226494.7031])
# Day 761: 2024-04-11 00:00:00 - Predicted: tensor([226968.3750])
# Day 762: 2024-04-12 00:00:00 - Predicted: tensor([227442.9844])
# Day 763: 2024-04-13 00:00:00 - Predicted: tensor([227918.5625])
# Day 764: 2024-04-14 00:00:00 - Predicted: tensor([228395.1719])
# Day 765: 2024-04-15 00:00:00 - Predicted: tensor([228872.7969])
# Day 766: 2024-04-16 00:00:00 - Predicted: tensor([229351.4219])
# Day 767: 2024-04-17 00:00:00 - Predicted: tensor([229831.0156])
# Day 768: 2024-04-18 00:00:00 - Predicted: tensor([230311.5938])
# Day 769: 2024-04-19 00:00:00 - Predicted: tensor([230793.2188])
# Day 770: 2024-04-20 00:00:00 - Predicted: tensor([231275.8438])
# Day 771: 2024-04-21 00:00:00 - Predicted: tensor([231759.4531])
# Day 772: 2024-04-22 00:00:00 - Predicted: tensor([232244.0781])
# Day 773: 2024-04-23 00:00:00 - Predicted: tensor([232729.7656])
# Day 774: 2024-04-24 00:00:00 - Predicted: tensor([233216.4375])
# Day 775: 2024-04-25 00:00:00 - Predicted: tensor([233704.1094])
# Day 776: 2024-04-26 00:00:00 - Predicted: tensor([234192.8438])
# Day 777: 2024-04-27 00:00:00 - Predicted: tensor([234682.5625])
# Day 778: 2024-04-28 00:00:00 - Predicted: tensor([235173.3125])
# Day 779: 2024-04-29 00:00:00 - Predicted: tensor([235665.0781])
# Day 780: 2024-04-30 00:00:00 - Predicted: tensor([236157.8906])
# Day 781: 2024-05-01 00:00:00 - Predicted: tensor([236651.7344])
# Day 782: 2024-05-02 00:00:00 - Predicted: tensor([237146.5781])
# Day 783: 2024-05-03 00:00:00 - Predicted: tensor([237642.5000])
# Day 784: 2024-05-04 00:00:00 - Predicted: tensor([238139.4531])
# Day 785: 2024-05-05 00:00:00 - Predicted: tensor([238637.4219])
# Day 786: 2024-05-06 00:00:00 - Predicted: tensor([239136.4219])
# Day 787: 2024-05-07 00:00:00 - Predicted: tensor([239636.5000])
# Day 788: 2024-05-08 00:00:00 - Predicted: tensor([240137.5938])
# Day 789: 2024-05-09 00:00:00 - Predicted: tensor([240639.7812])
# Day 790: 2024-05-10 00:00:00 - Predicted: tensor([241143.])
# Day 791: 2024-05-11 00:00:00 - Predicted: tensor([241647.2500])
# Day 792: 2024-05-12 00:00:00 - Predicted: tensor([242152.5938])
# Day 793: 2024-05-13 00:00:00 - Predicted: tensor([242658.9531])
# Day 794: 2024-05-14 00:00:00 - Predicted: tensor([243166.4219])
# Day 795: 2024-05-15 00:00:00 - Predicted: tensor([243674.8750])
# Day 796: 2024-05-16 00:00:00 - Predicted: tensor([244184.4531])
# Day 797: 2024-05-17 00:00:00 - Predicted: tensor([244695.0312])
# Day 798: 2024-05-18 00:00:00 - Predicted: tensor([245206.7188])
# Day 799: 2024-05-19 00:00:00 - Predicted: tensor([245719.4844])
# Day 800: 2024-05-20 00:00:00 - Predicted: tensor([246233.3438])
# Day 801: 2024-05-21 00:00:00 - Predicted: tensor([246748.2500])
# Day 802: 2024-05-22 00:00:00 - Predicted: tensor([247264.2344])
# Day 803: 2024-05-23 00:00:00 - Predicted: tensor([247781.2812])
# Day 804: 2024-05-24 00:00:00 - Predicted: tensor([248299.4375])
# Day 805: 2024-05-25 00:00:00 - Predicted: tensor([248818.6562])
# Day 806: 2024-05-26 00:00:00 - Predicted: tensor([249338.9688])
# Day 807: 2024-05-27 00:00:00 - Predicted: tensor([249860.3906])
# Day 808: 2024-05-28 00:00:00 - Predicted: tensor([250382.8750])
# Day 809: 2024-05-29 00:00:00 - Predicted: tensor([250906.4375])
# Day 810: 2024-05-30 00:00:00 - Predicted: tensor([251431.1094])
# Day 811: 2024-05-31 00:00:00 - Predicted: tensor([251956.8750])
# Day 812: 2024-06-01 00:00:00 - Predicted: tensor([252483.7812])
# Day 813: 2024-06-02 00:00:00 - Predicted: tensor([253011.7188])

# %%
# Khởi tạo cấu hình cho model
class Configs:
    def __init__(self):
        self.seq_len = 20  # Độ dài chuỗi thời gian đầu vào(tập kiểm tra)
        self.pred_len = 20  # Độ dài dự đoán
        self.individual = False  # Có sử dụng các kênh cá nhân hay không
        self.enc_in = 1  # Số lượng kênh đầu vào (tương ứng với số cột của dữ liệu)

configs = Configs()

# Khởi tạo model
model = Model(configs)

# %%
import torch.optim as optim

# Xác định hàm mất mát và trình tối ưu hóa
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Có thể điều chỉnh lr theo yêu cầu

# Huấn luyện mô hình
num_epochs = 100  # Số lượng epoch
for epoch in range(num_epochs):
    model.train()  # Chuyển sang chế độ huấn luyện
    optimizer.zero_grad()  # Đặt gradient về 0

    # Feedforward
    outputs = model(input_data_20day)

    # Tính toán loss
    loss = criterion(outputs, input_data_20day)  # So sánh đầu ra với đầu vào

    # Backpropagation
    loss.backward()  # Tính toán gradient
    optimizer.step()  # Cập nhật trọng số

    # In ra loss sau mỗi epoch
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/100], Loss: 4.2976
# Epoch [2/100], Loss: 532912.8750
# Epoch [3/100], Loss: 34838.4609
# Epoch [4/100], Loss: 112984.0000
# Epoch [5/100], Loss: 306630.4688
# Epoch [6/100], Loss: 233992.7188
# Epoch [7/100], Loss: 68667.3750
# Epoch [8/100], Loss: 144.0531
# Epoch [9/100], Loss: 62326.3242
# Epoch [10/100], Loss: 143452.4531
# Epoch [11/100], Loss: 143032.7031
# Epoch [12/100], Loss: 74630.9219
# Epoch [13/100], Loss: 11470.7803
# Epoch [14/100], Loss: 5044.2891
# Epoch [15/100], Loss: 45150.1328
# Epoch [16/100], Loss: 79454.3984
# Epoch [17/100], Loss: 72326.8359
# Epoch [18/100], Loss: 35037.6172
# Epoch [19/100], Loss: 4192.0425
# Epoch [20/100], Loss: 4035.0769
# Epoch [21/100], Loss: 26603.1934
# Epoch [22/100], Loss: 43915.5469
# Epoch [23/100], Loss: 38187.2578
# Epoch [24/100], Loss: 16993.3105
# Epoch [25/100], Loss: 1312.0026
# Epoch [26/100], Loss: 3536.3464
# Epoch [27/100], Loss: 16921.5566
# Epoch [28/100], Loss: 24954.9277
# Epoch [29/100], Loss: 19319.7207
# Epoch [30/100], Loss: 6817.9307
# Epoch [31/100], Loss: 61.5824
# Epoch [32/100], Loss: 3941.2922
# Epoch [33/100], Loss: 11783.1377
# Epoch [34/100], Loss: 13958.7529
# Epoch [35/100], Loss: 8416.1465
# Epoch [36/100], Loss: 1616.4208
# Epoch [37/100], Loss: 361.3118
# Epoch [38/100], Loss: 4485.6904
# Epoch [39/100], Loss: 8071.8999
# Epoch [40/100], Loss: 6800.8447
# Epoch [41/100], Loss: 2467.4741
# Epoch [42/100], Loss: 17.2986
# Epoch [43/100], Loss: 1517.1274
# Epoch [44/100], Loss: 4251.8457
# Epoch [45/100], Loss: 4564.8330
# Epoch [46/100], Loss: 2228.6372
# Epoch [47/100], Loss: 165.6457
# Epoch [48/100], Loss: 520.9036
# Epoch [49/100], Loss: 2242.2124
# Epoch [50/100], Loss: 2835.3091
# Epoch [51/100], Loss: 1599.6145
# Epoch [52/100], Loss: 192.3390
# Epoch [53/100], Loss: 221.6682
# Epoch [54/100], Loss: 1266.0111
# Epoch [55/100], Loss: 1721.0879
# Epoch [56/100], Loss: 1003.1516
# Epoch [57/100], Loss: 123.1309
# Epoch [58/100], Loss: 139.0746
# Epoch [59/100], Loss: 788.0753
# Epoch [60/100], Loss: 1038.8225
# Epoch [61/100], Loss: 561.9037
# Epoch [62/100], Loss: 47.1998
# Epoch [63/100], Loss: 124.3514
# Epoch [64/100], Loss: 532.1961
# Epoch [65/100], Loss: 614.7393
# Epoch [66/100], Loss: 272.5745
# Epoch [67/100], Loss: 6.0473
# Epoch [68/100], Loss: 130.2966
# Epoch [69/100], Loss: 370.7240
# Epoch [70/100], Loss: 341.5501
# Epoch [71/100], Loss: 103.2763
# Epoch [72/100], Loss: 2.9311
# Epoch [73/100], Loss: 135.0088
# Epoch [74/100], Loss: 248.7108
# Epoch [75/100], Loss: 164.9049
# Epoch [76/100], Loss: 22.2421
# Epoch [77/100], Loss: 22.3832
# Epoch [78/100], Loss: 125.2007
# Epoch [79/100], Loss: 148.2189
# Epoch [80/100], Loss: 59.6811
# Epoch [81/100], Loss: 0.2357
# Epoch [82/100], Loss: 43.6214
# Epoch [83/100], Loss: 97.2651
# Epoch [84/100], Loss: 70.1552
# Epoch [85/100], Loss: 10.5355
# Epoch [86/100], Loss: 8.5303
# Epoch [87/100], Loss: 50.7554
# Epoch [88/100], Loss: 58.5841
# Epoch [89/100], Loss: 21.0139
# Epoch [90/100], Loss: 0.2027
# Epoch [91/100], Loss: 21.5609
# Epoch [92/100], Loss: 40.1023
# Epoch [93/100], Loss: 23.5913
# Epoch [94/100], Loss: 1.4898
# Epoch [95/100], Loss: 7.2825
# Epoch [96/100], Loss: 24.0664
# Epoch [97/100], Loss: 20.5054
# Epoch [98/100], Loss: 3.9190
# Epoch [99/100], Loss: 1.7585
# Epoch [100/100], Loss: 13.1997

# %%
# Dự báo cho 90 ngày kế tiếp
# # Chuyển sang chế độ đánh giá
model.eval()

# Không cần tính gradient trong quá trình dự báo
with torch.no_grad():
    input_data_future = input_data_20day.clone()  # Tạo một bản sao của dữ liệu đầu vào để cập nhật dự báo
    predicted = []  # Danh sách dự báo cho các ngày tiếp theo
    for i in range(30):  # Dự báo cho 90 ngày tiếp theo
        # Dự báo cho ngày hiện tại
        output = model(input_data_future)
        # Lưu dự báo của ngày hiện tại
        predicted.append(output[:, -1, :])  # Lấy dự báo cho ngày cuối cùng trong chuỗi thời gian
        # Cập nhật dữ liệu đầu vào cho ngày tiếp theo
        input_data_future = torch.cat([input_data_future[:, :, 1:], output], dim=2)

    # In ra dự báo cho 30 ngày tiếp theo
    print("Predicted Output for the next 90 days:")
    for i in range(30):
        # In ra ngày tương ứng với dự báo
        print(f"Day {i+1}: {last_date + pd.DateOffset(days=i+1)} - Predicted: {predicted[i][0]}")
# Out:
# Predicted Output for the next 90 days:
# Day 1: 2024-06-02 00:00:00 - Predicted: tensor([36003.9570])
# Day 2: 2024-06-03 00:00:00 - Predicted: tensor([36004.7617])
# Day 3: 2024-06-04 00:00:00 - Predicted: tensor([36005.5547])
# Day 4: 2024-06-05 00:00:00 - Predicted: tensor([36006.3516])
# Day 5: 2024-06-06 00:00:00 - Predicted: tensor([36007.1445])
# Day 6: 2024-06-07 00:00:00 - Predicted: tensor([36007.9453])
# Day 7: 2024-06-08 00:00:00 - Predicted: tensor([36008.7383])
# Day 8: 2024-06-09 00:00:00 - Predicted: tensor([36009.5352])
# Day 9: 2024-06-10 00:00:00 - Predicted: tensor([36010.3320])
# Day 10: 2024-06-11 00:00:00 - Predicted: tensor([36011.1289])
# Day 11: 2024-06-12 00:00:00 - Predicted: tensor([36011.9258])
# Day 12: 2024-06-13 00:00:00 - Predicted: tensor([36012.7188])
# Day 13: 2024-06-14 00:00:00 - Predicted: tensor([36013.5156])
# Day 14: 2024-06-15 00:00:00 - Predicted: tensor([36014.3164])
# Day 15: 2024-06-16 00:00:00 - Predicted: tensor([36015.1094])
# Day 16: 2024-06-17 00:00:00 - Predicted: tensor([36015.9062])
# Day 17: 2024-06-18 00:00:00 - Predicted: tensor([36016.7031])
# Day 18: 2024-06-19 00:00:00 - Predicted: tensor([36017.5000])
# Day 19: 2024-06-20 00:00:00 - Predicted: tensor([36018.2969])
# Day 20: 2024-06-21 00:00:00 - Predicted: tensor([36019.0898])
# Day 21: 2024-06-22 00:00:00 - Predicted: tensor([36019.8867])
# Day 22: 2024-06-23 00:00:00 - Predicted: tensor([36020.6875])
# Day 23: 2024-06-24 00:00:00 - Predicted: tensor([36021.4844])
# Day 24: 2024-06-25 00:00:00 - Predicted: tensor([36022.2773])
# Day 25: 2024-06-26 00:00:00 - Predicted: tensor([36023.0742])
# Day 26: 2024-06-27 00:00:00 - Predicted: tensor([36023.8750])
# Day 27: 2024-06-28 00:00:00 - Predicted: tensor([36024.6680])
# Day 28: 2024-06-29 00:00:00 - Predicted: tensor([36025.4688])
# Day 29: 2024-06-30 00:00:00 - Predicted: tensor([36026.2617])
# Day 30: 2024-07-01 00:00:00 - Predicted: tensor([36027.0586])

# %%
# Chuyển dữ liệu từ Series pandas thành numpy array để vẽ biểu đồ
predicted_values_test = [pred[0].numpy() for pred in predicted_test]
# Chuyển dữ liệu dự báo từ tensor về numpy array
predicted_values = [pred[0].numpy() for pred in predicted]
# Tạo mảng chứa ngày của train_data_price
train_dates = df['Date'].values[:len(train_data_price)]
# Tạo mảng chứa ngày của test_data_price
test_dates = df['Date'].values[len(train_data_price):len(train_data_price)+len(test_data_price)]
# Tạo mảng chứa ngày dự đoán
predicted_dates = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=len(predicted_values))

split_size = len(predicted_values) // 3

predicted_values_30day = predicted_values[:split_size]
predicted_values_60day = predicted_values[split_size:2*split_size]
predicted_values_90day = predicted_values[2*split_size:]
# Tính toán các khoảng thời gian cho mỗi phần
predicted_dates_30day = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=split_size)
predicted_dates_60day = pd.date_range(start=predicted_dates_30day[-1] + pd.DateOffset(days=1), periods=split_size)
predicted_dates_90day = pd.date_range(start=predicted_dates_60day[-1] + pd.DateOffset(days=1), periods=split_size)

# %%
import matplotlib.pyplot as plt


# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(train_dates, train_data_price, label='Training Data')
plt.plot(test_dates, test_data_price, label='Actual Data')
plt.plot(test_dates, predicted_values_test, label='Predicted')
plt.plot(predicted_dates_30day, predicted_values_30day, label='Predicted 30 Day', color='red')
plt.plot(predicted_dates_60day, predicted_values_60day, label='Predicted 60 Day', color='green')
plt.plot(predicted_dates_90day, predicted_values_90day, label='Predicted 90 Day', color='blue')
plt.title('DLinear - KDH Stock Price - 7:3')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt


# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(test_dates, test_data_price, label='Actual Data')
plt.plot(predicted_dates_30day, predicted_values_30day, label='Predicted 30 Day', color='red')
plt.plot(predicted_dates_60day, predicted_values_60day, label='Predicted 60 Day', color='green')
plt.plot(predicted_dates_90day, predicted_values_90day, label='Predicted 90 Day', color='blue')

plt.title('DLinear - KDH Stock Price - 7:3')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
outputs_test = np.array(predicted_values_test)
outputs_test = outputs_test.flatten()

# %%
# Mean Absolute Error (MAE) và Mean Absolute Percentage Error (MAPE)
mae_test = np.mean(np.abs(test_data_price - outputs_test))
mape_test = np.mean(np.abs((test_data_price - outputs_test) / test_data_price)) * 100
rmse_test = np.sqrt(np.mean((test_data_price - outputs_test) ** 2))

print("MAE:", mae_test)
print("MAPE:", mape_test)
print("RMSE:", rmse_test)
# Out:
# MAE: 91226.91429568983
# MAPE: 303.2499514218596
# RMSE: 108031.55438948827
