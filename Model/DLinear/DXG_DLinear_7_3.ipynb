# %%
from re import X
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        # padding on the both ends of time series
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x


class series_decomp(nn.Module):
    """
    Series decomposition block
    """
    def __init__(self, kernel_size):
        super(series_decomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class Model(nn.Module):
    """
    DLinear
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len

        # Decompsition Kernel Size
        kernel_size = 25
        self.decompsition = series_decomp(kernel_size)
        self.individual = configs.individual
        self.channels = configs.enc_in

        if self.individual:
            self.Linear_Seasonal = nn.ModuleList()
            self.Linear_Trend = nn.ModuleList()
            self.Linear_Decoder = nn.ModuleList()
            for i in range(self.channels):
                self.Linear_Seasonal.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Seasonal[i].weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))
                self.Linear_Trend.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Trend[i].weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))
                self.Linear_Decoder.append(nn.Linear(self.seq_len,self.pred_len))
        else:
            self.Linear_Seasonal = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Trend = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Decoder = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Seasonal.weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))
            self.Linear_Trend.weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))

    def forward(self, x):
        # x: [Batch, Input length, Channel]
        seasonal_init, trend_init = self.decompsition(x)
        seasonal_init, trend_init = seasonal_init.permute(0,2,1), trend_init.permute(0,2,1)
        if self.individual:
            seasonal_output = torch.zeros([seasonal_init.size(0),seasonal_init.size(1),self.pred_len],dtype=seasonal_init.dtype).to(seasonal_init.device)
            trend_output = torch.zeros([trend_init.size(0),trend_init.size(1),self.pred_len],dtype=trend_init.dtype).to(trend_init.device)
            for i in range(self.channels):
                seasonal_output[:,i,:] = self.Linear_Seasonal[i](seasonal_init[:,i,:])
                trend_output[:,i,:] = self.Linear_Trend[i](trend_init[:,i,:])
        else:
            seasonal_output = self.Linear_Seasonal(seasonal_init)
            trend_output = self.Linear_Trend(trend_init)

        x = seasonal_output + trend_output
        return x.permute(0,2,1) # to [Batch, Output length, Channel]

# %%
import pandas as pd
import torch
from datetime import datetime, timedelta
# Đọc dữ liệu từ file CSV
df = pd.read_csv('DXG-Historical-Data.csv')

# %%
# # Chuyển dữ liệu thời gian
# df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')
# # Đảo ngược lại dữ liệu
# df = df.iloc[::-1].reset_index(drop=True)

# %%
# # Loại bỏ dấu phẩy từ cột "Price"
# df['Price'] = df['Price'].str.replace(',', '').astype(float)
# # Loại bỏ dấu phẩy từ cột "Open"
# df['Open'] = df['Open'].str.replace(',', '').astype(float)
# # Loại bỏ dấu phẩy từ cột "High"
# df['High'] = df['High'].str.replace(',', '').astype(float)
# # Loại bỏ dấu phẩy từ cột "Low"
# df['Low'] = df['Low'].str.replace(',', '').astype(float)

# %%
df
# Out:
#       Unnamed: 0        Date     Price
# 0              0  2017-01-03   6066.50
# 1              1  2017-01-04   6166.40
# 2              2  2017-01-05   6091.50
# 3              3  2017-01-06   6141.40
# 4              4  2017-01-07   6116.45
# ...          ...         ...       ...
# 2702        2702  2024-05-28  16800.00
# 2703        2703  2024-05-29  16850.00
# 2704        2704  2024-05-30  16850.00
# 2705        2705  2024-05-31  16800.00
# 2706        2706  2024-06-01  16770.00
#
# [2707 rows x 3 columns]

# %%
# Lấy ngày cuối cùng của dữ liệu
df['Date'] = pd.to_datetime(df['Date'])
last_date = df['Date'].max()

# %%
# Lấy dữ liệu Date cần phân tích để dự bảo DL trên tập test
time_series_Date = df['Date']

# Phân chia dữ liệu thành tập huấn luyện và tập kiểm tra - để lấy date
train_data_Date = time_series_Date[:int(0.7 * len(time_series_Date))]
test_data_Date = time_series_Date[int(0.7 * len(time_series_Date)):]
first_data_Date = test_data_Date.min()
print(first_data_Date)
# Out:
# 2022-03-12 00:00:00

# %%
# Lấy dữ liệu cần phân tích
time_series_price = df['Price']

# Phân chia dữ liệu thành tập huấn luyện và tập kiểm tra
train_data_price = time_series_price[:int(0.7 * len(time_series_price))]
test_data_price = time_series_price[int(0.7 * len(time_series_price)):]

# Chọn các cột dữ liệu số
# numeric_columns = ['Price', 'Open', 'High', 'Low']
numeric_columns = ['Price']

# Chuyển các giá trị số thành tensor
numeric_data = df[numeric_columns].values.astype(np.float32)

# Mở rộng chiều để phù hợp với đầu vào của mô hình
numeric_data = np.expand_dims(numeric_data, axis=0)

# Chia dữ liệu thành tensor
input_data_train = torch.tensor(numeric_data[:, :len(train_data_price), :])
input_data_test = torch.tensor(numeric_data[:, len(train_data_price):, :])
# Lấy dữ liệu 20 ngày gần nhất
recent_20_prices = time_series_price[-20:]

# Chuyển đổi dữ liệu 20 ngày gần nhất thành numpy array và mở rộng chiều
recent_20_prices_array = recent_20_prices.values.astype(np.float32)
recent_20_prices_array = np.expand_dims(recent_20_prices_array, axis=0)
recent_20_prices_array = np.expand_dims(recent_20_prices_array, axis=-1)

# Chuyển đổi thành tensor
input_data_20day = torch.tensor(recent_20_prices_array)

# In ra để kiểm tra kích thước của các tensor
print("Kích thước tập huấn luyện:", input_data_train.shape)
print("Kích thước tập kiểm tra:", input_data_test.shape)
# Out:
# Kích thước tập huấn luyện: torch.Size([1, 1894, 1])
# Kích thước tập kiểm tra: torch.Size([1, 813, 1])

# %%
# Khởi tạo cấu hình cho model
class Configs:
    def __init__(self):
        self.seq_len = 1894  # Độ dài chuỗi thời gian đầu vào(tập kiểm tra)
        self.pred_len = 1894  # Độ dài dự đoán
        self.individual = False  # Có sử dụng các kênh cá nhân hay không
        self.enc_in = 1  # Số lượng kênh đầu vào (tương ứng với số cột của dữ liệu)

configs = Configs()

# Khởi tạo model
model = Model(configs)

# %%
import torch.optim as optim

# Xác định hàm mất mát và trình tối ưu hóa
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Có thể điều chỉnh lr theo yêu cầu

# Huấn luyện mô hình
num_epochs = 100  # Số lượng epoch
for epoch in range(num_epochs):
    model.train()  # Chuyển sang chế độ huấn luyện
    optimizer.zero_grad()  # Đặt gradient về 0

    # Feedforward
    outputs = model(input_data_train)

    # Tính toán loss
    loss = criterion(outputs, input_data_train)  # So sánh đầu ra với đầu vào

    # Backpropagation
    loss.backward()  # Tính toán gradient
    optimizer.step()  # Cập nhật trọng số

    # In ra loss sau mỗi epoch
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/100], Loss: 45013608.0000
# Epoch [2/100], Loss: 680163200.0000
# Epoch [3/100], Loss: 69914904.0000
# Epoch [4/100], Loss: 147012608.0000
# Epoch [5/100], Loss: 372723904.0000
# Epoch [6/100], Loss: 252873936.0000
# Epoch [7/100], Loss: 53094980.0000
# Epoch [8/100], Loss: 21363758.0000
# Epoch [9/100], Loss: 131761704.0000
# Epoch [10/100], Loss: 191898768.0000
# Epoch [11/100], Loss: 131875232.0000
# Epoch [12/100], Loss: 39476828.0000
# Epoch [13/100], Loss: 12221516.0000
# Epoch [14/100], Loss: 55038972.0000
# Epoch [15/100], Loss: 96926560.0000
# Epoch [16/100], Loss: 86802152.0000
# Epoch [17/100], Loss: 42683088.0000
# Epoch [18/100], Loss: 13596066.0000
# Epoch [19/100], Loss: 21072424.0000
# Epoch [20/100], Loss: 43795064.0000
# Epoch [21/100], Loss: 50508092.0000
# Epoch [22/100], Loss: 35203936.0000
# Epoch [23/100], Loss: 16589090.0000
# Epoch [24/100], Loss: 11967366.0000
# Epoch [25/100], Loss: 19665474.0000
# Epoch [26/100], Loss: 25995342.0000
# Epoch [27/100], Loss: 22850706.0000
# Epoch [28/100], Loss: 14498053.0000
# Epoch [29/100], Loss: 9478455.0000
# Epoch [30/100], Loss: 10426313.0000
# Epoch [31/100], Loss: 13128214.0000
# Epoch [32/100], Loss: 13036645.0000
# Epoch [33/100], Loss: 10077831.0000
# Epoch [34/100], Loss: 7262169.0000
# Epoch [35/100], Loss: 6534324.5000
# Epoch [36/100], Loss: 7100874.5000
# Epoch [37/100], Loss: 7187609.5000
# Epoch [38/100], Loss: 6222796.0000
# Epoch [39/100], Loss: 4992330.5000
# Epoch [40/100], Loss: 4312721.5000
# Epoch [41/100], Loss: 4160179.2500
# Epoch [42/100], Loss: 4029394.7500
# Epoch [43/100], Loss: 3664174.0000
# Epoch [44/100], Loss: 3198502.0000
# Epoch [45/100], Loss: 2813751.7500
# Epoch [46/100], Loss: 2532971.5000
# Epoch [47/100], Loss: 2315281.2500
# Epoch [48/100], Loss: 2146692.2500
# Epoch [49/100], Loss: 1990785.1250
# Epoch [50/100], Loss: 1785618.8750
# Epoch [51/100], Loss: 1543064.0000
# Epoch [52/100], Loss: 1358955.7500
# Epoch [53/100], Loss: 1278490.5000
# Epoch [54/100], Loss: 1223261.6250
# Epoch [55/100], Loss: 1101814.8750
# Epoch [56/100], Loss: 934434.9375
# Epoch [57/100], Loss: 812531.5625
# Epoch [58/100], Loss: 769339.8750
# Epoch [59/100], Loss: 744647.5000
# Epoch [60/100], Loss: 672511.6250
# Epoch [61/100], Loss: 563992.6250
# Epoch [62/100], Loss: 484897.2812
# Epoch [63/100], Loss: 464891.8750
# Epoch [64/100], Loss: 457859.2500
# Epoch [65/100], Loss: 408422.9688
# Epoch [66/100], Loss: 331842.7188
# Epoch [67/100], Loss: 288218.1875
# Epoch [68/100], Loss: 289340.5000
# Epoch [69/100], Loss: 283588.6562
# Epoch [70/100], Loss: 239471.5781
# Epoch [71/100], Loss: 191068.7344
# Epoch [72/100], Loss: 177969.8438
# Epoch [73/100], Loss: 184180.0938
# Epoch [74/100], Loss: 170045.6250
# Epoch [75/100], Loss: 135326.9844
# Epoch [76/100], Loss: 113096.2500
# Epoch [77/100], Loss: 114481.6953
# Epoch [78/100], Loss: 115121.2500
# Epoch [79/100], Loss: 97347.9531
# Epoch [80/100], Loss: 76041.1641
# Epoch [81/100], Loss: 70839.4766
# Epoch [82/100], Loss: 74677.2578
# Epoch [83/100], Loss: 68473.2500
# Epoch [84/100], Loss: 53075.4844
# Epoch [85/100], Loss: 45002.9375
# Epoch [86/100], Loss: 47353.5547
# Epoch [87/100], Loss: 46642.1602
# Epoch [88/100], Loss: 37311.2344
# Epoch [89/100], Loss: 29572.6074
# Epoch [90/100], Loss: 29964.4062
# Epoch [91/100], Loss: 31005.4746
# Epoch [92/100], Loss: 25910.4473
# Epoch [93/100], Loss: 19859.5645
# Epoch [94/100], Loss: 19211.3047
# Epoch [95/100], Loss: 20375.2715
# Epoch [96/100], Loss: 17631.2480
# Epoch [97/100], Loss: 13420.7393
# Epoch [98/100], Loss: 12588.9502
# Epoch [99/100], Loss: 13356.1191
# Epoch [100/100], Loss: 11736.7275

# %%
# Dự báo cho tập test
# # Chuyển sang chế độ đánh giá
model.eval()

# Không cần tính gradient trong quá trình dự báo
with torch.no_grad():
    input_data_future_test = input_data_train.clone()  # Tạo một bản sao của dữ liệu đầu vào để cập nhật dự báo
    predicted_test = []  # Danh sách dự báo cho các ngày tiếp theo
    for i in range(813):  # Dự báo cho tập test
        # Dự báo cho ngày hiện tại
        output = model(input_data_future_test)
        # Lưu dự báo của ngày hiện tại
        predicted_test.append(output[:, -1, :])  # Lấy dự báo cho ngày cuối cùng trong chuỗi thời gian
        # Cập nhật dữ liệu đầu vào cho ngày tiếp theo
        input_data_future_test = torch.cat([input_data_future_test[:, :, 1:], output], dim=2)

    # In ra dự báo cho tập test
    print("Predicted Output for data test:")
    for i in range(813):
        # In ra ngày tương ứng với dự báo
        print(f"Day  Predicted: {predicted_test[i][0]}")
# Out:
# Predicted Output for data test:
# Day  Predicted: tensor([40627.7070])
# Day  Predicted: tensor([40628.3086])
# Day  Predicted: tensor([40626.7578])
# Day  Predicted: tensor([40625.1406])
# Day  Predicted: tensor([40623.5234])
# Day  Predicted: tensor([40621.9062])
# Day  Predicted: tensor([40620.2891])
# Day  Predicted: tensor([40618.6641])
# Day  Predicted: tensor([40617.0469])
# Day  Predicted: tensor([40615.4336])
# Day  Predicted: tensor([40613.8125])
# Day  Predicted: tensor([40612.1953])
# Day  Predicted: tensor([40610.5703])
# Day  Predicted: tensor([40608.9531])
# Day  Predicted: tensor([40607.3320])
# Day  Predicted: tensor([40605.7148])
# Day  Predicted: tensor([40604.0977])
# Day  Predicted: tensor([40602.4844])
# Day  Predicted: tensor([40600.8633])
# Day  Predicted: tensor([40599.2461])
# Day  Predicted: tensor([40597.6289])
# Day  Predicted: tensor([40596.0156])
# Day  Predicted: tensor([40594.3945])
# Day  Predicted: tensor([40592.7812])
# Day  Predicted: tensor([40591.1602])
# Day  Predicted: tensor([40589.5391])
# Day  Predicted: tensor([40587.9219])
# Day  Predicted: tensor([40586.3086])
# Day  Predicted: tensor([40584.6875])
# Day  Predicted: tensor([40583.0703])
# Day  Predicted: tensor([40581.4531])
# Day  Predicted: tensor([40579.8359])
# Day  Predicted: tensor([40578.2188])
# Day  Predicted: tensor([40576.6016])
# Day  Predicted: tensor([40574.9883])
# Day  Predicted: tensor([40573.3711])
# Day  Predicted: tensor([40571.7539])
# Day  Predicted: tensor([40570.1367])
# Day  Predicted: tensor([40568.5195])
# Day  Predicted: tensor([40566.9062])
# Day  Predicted: tensor([40565.2773])
# Day  Predicted: tensor([40563.6680])
# Day  Predicted: tensor([40562.0508])
# Day  Predicted: tensor([40560.4336])
# Day  Predicted: tensor([40558.8164])
# Day  Predicted: tensor([40557.2070])
# Day  Predicted: tensor([40555.5859])
# Day  Predicted: tensor([40553.9688])
# Day  Predicted: tensor([40552.3555])
# Day  Predicted: tensor([40550.7383])
# Day  Predicted: tensor([40549.1250])
# Day  Predicted: tensor([40547.5117])
# Day  Predicted: tensor([40545.8867])
# Day  Predicted: tensor([40544.2734])
# Day  Predicted: tensor([40542.6562])
# Day  Predicted: tensor([40541.0391])
# Day  Predicted: tensor([40539.4297])
# Day  Predicted: tensor([40537.8086])
# Day  Predicted: tensor([40536.1953])
# Day  Predicted: tensor([40534.5820])
# Day  Predicted: tensor([40532.9648])
# Day  Predicted: tensor([40531.3516])
# Day  Predicted: tensor([40529.7344])
# Day  Predicted: tensor([40528.1250])
# Day  Predicted: tensor([40526.5078])
# Day  Predicted: tensor([40524.8906])
# Day  Predicted: tensor([40523.2734])
# Day  Predicted: tensor([40521.6641])
# Day  Predicted: tensor([40520.0469])
# Day  Predicted: tensor([40518.4258])
# Day  Predicted: tensor([40516.8164])
# Day  Predicted: tensor([40515.1992])
# Day  Predicted: tensor([40513.5898])
# Day  Predicted: tensor([40511.9727])
# Day  Predicted: tensor([40510.3555])
# Day  Predicted: tensor([40508.7461])
# Day  Predicted: tensor([40507.1289])
# Day  Predicted: tensor([40505.5195])
# Day  Predicted: tensor([40503.9023])
# Day  Predicted: tensor([40502.2852])
# Day  Predicted: tensor([40500.6758])
# Day  Predicted: tensor([40499.0586])
# Day  Predicted: tensor([40497.4453])
# Day  Predicted: tensor([40495.8359])
# Day  Predicted: tensor([40494.2188])
# Day  Predicted: tensor([40492.6016])
# Day  Predicted: tensor([40490.9844])
# Day  Predicted: tensor([40489.3711])
# Day  Predicted: tensor([40487.7578])
# Day  Predicted: tensor([40486.1445])
# Day  Predicted: tensor([40484.5391])
# Day  Predicted: tensor([40482.9258])
# Day  Predicted: tensor([40481.3047])
# Day  Predicted: tensor([40479.6992])
# Day  Predicted: tensor([40478.0859])
# Day  Predicted: tensor([40476.4688])
# Day  Predicted: tensor([40474.8594])
# Day  Predicted: tensor([40473.2422])
# Day  Predicted: tensor([40471.6328])
# Day  Predicted: tensor([40470.0156])
# Day  Predicted: tensor([40468.4062])
# Day  Predicted: tensor([40466.7930])
# Day  Predicted: tensor([40465.1758])
# Day  Predicted: tensor([40463.5703])
# Day  Predicted: tensor([40461.9531])
# Day  Predicted: tensor([40460.3398])
# Day  Predicted: tensor([40458.7305])
# Day  Predicted: tensor([40457.1133])
# Day  Predicted: tensor([40455.5039])
# Day  Predicted: tensor([40453.8906])
# Day  Predicted: tensor([40452.2812])
# Day  Predicted: tensor([40450.6758])
# Day  Predicted: tensor([40449.0586])
# Day  Predicted: tensor([40447.4414])
# Day  Predicted: tensor([40445.8320])
# Day  Predicted: tensor([40444.2227])
# Day  Predicted: tensor([40442.6133])
# Day  Predicted: tensor([40441.0039])
# Day  Predicted: tensor([40439.3906])
# Day  Predicted: tensor([40437.7773])
# Day  Predicted: tensor([40436.1602])
# Day  Predicted: tensor([40434.5547])
# Day  Predicted: tensor([40432.9414])
# Day  Predicted: tensor([40431.3281])
# Day  Predicted: tensor([40429.7227])
# Day  Predicted: tensor([40428.1094])
# Day  Predicted: tensor([40426.5000])
# Day  Predicted: tensor([40424.8906])
# Day  Predicted: tensor([40423.2734])
# Day  Predicted: tensor([40421.6602])
# Day  Predicted: tensor([40420.0508])
# Day  Predicted: tensor([40418.4453])
# Day  Predicted: tensor([40416.8320])
# Day  Predicted: tensor([40415.2188])
# Day  Predicted: tensor([40413.6094])
# Day  Predicted: tensor([40411.9961])
# Day  Predicted: tensor([40410.3906])
# Day  Predicted: tensor([40408.7773])
# Day  Predicted: tensor([40407.1719])
# Day  Predicted: tensor([40405.5547])
# Day  Predicted: tensor([40403.9531])
# Day  Predicted: tensor([40402.3359])
# Day  Predicted: tensor([40400.7266])
# Day  Predicted: tensor([40399.1172])
# Day  Predicted: tensor([40397.5078])
# Day  Predicted: tensor([40395.8984])
# Day  Predicted: tensor([40394.2812])
# Day  Predicted: tensor([40392.6797])
# Day  Predicted: tensor([40391.0625])
# Day  Predicted: tensor([40389.4492])
# Day  Predicted: tensor([40387.8477])
# Day  Predicted: tensor([40386.2344])
# Day  Predicted: tensor([40384.6289])
# Day  Predicted: tensor([40383.0195])
# Day  Predicted: tensor([40381.4102])
# Day  Predicted: tensor([40379.8008])
# Day  Predicted: tensor([40378.1953])
# Day  Predicted: tensor([40376.5820])
# Day  Predicted: tensor([40374.9727])
# Day  Predicted: tensor([40373.3633])
# Day  Predicted: tensor([40371.7539])
# Day  Predicted: tensor([40370.1484])
# Day  Predicted: tensor([40368.5391])
# Day  Predicted: tensor([40366.9258])
# Day  Predicted: tensor([40365.3242])
# Day  Predicted: tensor([40363.7109])
# Day  Predicted: tensor([40362.1055])
# Day  Predicted: tensor([40360.4961])
# Day  Predicted: tensor([40358.8867])
# Day  Predicted: tensor([40357.2852])
# Day  Predicted: tensor([40355.6719])
# Day  Predicted: tensor([40354.0664])
# Day  Predicted: tensor([40352.4570])
# Day  Predicted: tensor([40350.8516])
# Day  Predicted: tensor([40349.2383])
# Day  Predicted: tensor([40347.6367])
# Day  Predicted: tensor([40346.0234])
# Day  Predicted: tensor([40344.4102])
# Day  Predicted: tensor([40342.8047])
# Day  Predicted: tensor([40341.1953])
# Day  Predicted: tensor([40339.5898])
# Day  Predicted: tensor([40337.9805])
# Day  Predicted: tensor([40336.3750])
# Day  Predicted: tensor([40334.7695])
# Day  Predicted: tensor([40333.1641])
# Day  Predicted: tensor([40331.5547])
# Day  Predicted: tensor([40329.9453])
# Day  Predicted: tensor([40328.3398])
# Day  Predicted: tensor([40326.7305])
# Day  Predicted: tensor([40325.1250])
# Day  Predicted: tensor([40323.5195])
# Day  Predicted: tensor([40321.9141])
# Day  Predicted: tensor([40320.3047])
# Day  Predicted: tensor([40318.7031])
# Day  Predicted: tensor([40317.0938])
# Day  Predicted: tensor([40315.4844])
# Day  Predicted: tensor([40313.8750])
# Day  Predicted: tensor([40312.2656])
# Day  Predicted: tensor([40310.6641])
# Day  Predicted: tensor([40309.0625])
# Day  Predicted: tensor([40307.4531])
# Day  Predicted: tensor([40305.8477])
# Day  Predicted: tensor([40304.2422])
# Day  Predicted: tensor([40302.6367])
# Day  Predicted: tensor([40301.0312])
# Day  Predicted: tensor([40299.4219])
# Day  Predicted: tensor([40297.8164])
# Day  Predicted: tensor([40296.2109])
# Day  Predicted: tensor([40294.6055])
# Day  Predicted: tensor([40293.])
# Day  Predicted: tensor([40291.3945])
# Day  Predicted: tensor([40289.7891])
# Day  Predicted: tensor([40288.1836])
# Day  Predicted: tensor([40286.5742])
# Day  Predicted: tensor([40284.9688])
# Day  Predicted: tensor([40283.3633])
# Day  Predicted: tensor([40281.7617])
# Day  Predicted: tensor([40280.1562])
# Day  Predicted: tensor([40278.5469])
# Day  Predicted: tensor([40276.9453])
# Day  Predicted: tensor([40275.3398])
# Day  Predicted: tensor([40273.7383])
# Day  Predicted: tensor([40272.1289])
# Day  Predicted: tensor([40270.5234])
# Day  Predicted: tensor([40268.9180])
# Day  Predicted: tensor([40267.3086])
# Day  Predicted: tensor([40265.7188])
# Day  Predicted: tensor([40264.1055])
# Day  Predicted: tensor([40262.5000])
# Day  Predicted: tensor([40260.8945])
# Day  Predicted: tensor([40259.2930])
# Day  Predicted: tensor([40257.6836])
# Day  Predicted: tensor([40256.0820])
# Day  Predicted: tensor([40254.4805])
# Day  Predicted: tensor([40252.8711])
# Day  Predicted: tensor([40251.2695])
# Day  Predicted: tensor([40249.6680])
# Day  Predicted: tensor([40248.0625])
# Day  Predicted: tensor([40246.4609])
# Day  Predicted: tensor([40244.8516])
# Day  Predicted: tensor([40243.2461])
# Day  Predicted: tensor([40241.6445])
# Day  Predicted: tensor([40240.0430])
# Day  Predicted: tensor([40238.4375])
# Day  Predicted: tensor([40236.8359])
# Day  Predicted: tensor([40235.2305])
# Day  Predicted: tensor([40233.6289])
# Day  Predicted: tensor([40232.0234])
# Day  Predicted: tensor([40230.4180])
# Day  Predicted: tensor([40228.8242])
# Day  Predicted: tensor([40227.2227])
# Day  Predicted: tensor([40225.6133])
# Day  Predicted: tensor([40224.0078])
# Day  Predicted: tensor([40222.4062])
# Day  Predicted: tensor([40220.8008])
# Day  Predicted: tensor([40219.1992])
# Day  Predicted: tensor([40217.5977])
# Day  Predicted: tensor([40215.9961])
# Day  Predicted: tensor([40214.3945])
# Day  Predicted: tensor([40212.7891])
# Day  Predicted: tensor([40211.1836])
# Day  Predicted: tensor([40209.5859])
# Day  Predicted: tensor([40207.9883])
# Day  Predicted: tensor([40206.3789])
# Day  Predicted: tensor([40204.7773])
# Day  Predicted: tensor([40203.1719])
# Day  Predicted: tensor([40201.5742])
# Day  Predicted: tensor([40199.9688])
# Day  Predicted: tensor([40198.3711])
# Day  Predicted: tensor([40196.7656])
# Day  Predicted: tensor([40195.1641])
# Day  Predicted: tensor([40193.5625])
# Day  Predicted: tensor([40191.9648])
# Day  Predicted: tensor([40190.3594])
# Day  Predicted: tensor([40188.7578])
# Day  Predicted: tensor([40187.1562])
# Day  Predicted: tensor([40185.5508])
# Day  Predicted: tensor([40183.9531])
# Day  Predicted: tensor([40182.3477])
# Day  Predicted: tensor([40180.7539])
# Day  Predicted: tensor([40179.1523])
# Day  Predicted: tensor([40177.5430])
# Day  Predicted: tensor([40175.9453])
# Day  Predicted: tensor([40174.3477])
# Day  Predicted: tensor([40172.7461])
# Day  Predicted: tensor([40171.1406])
# Day  Predicted: tensor([40169.5430])
# Day  Predicted: tensor([40167.9414])
# Day  Predicted: tensor([40166.3477])
# Day  Predicted: tensor([40164.7383])
# Day  Predicted: tensor([40163.1367])
# Day  Predicted: tensor([40161.5430])
# Day  Predicted: tensor([40159.9414])
# Day  Predicted: tensor([40158.3359])
# Day  Predicted: tensor([40156.7383])
# Day  Predicted: tensor([40155.1367])
# Day  Predicted: tensor([40153.5430])
# Day  Predicted: tensor([40151.9336])
# Day  Predicted: tensor([40150.3398])
# Day  Predicted: tensor([40148.7344])
# Day  Predicted: tensor([40147.1367])
# Day  Predicted: tensor([40145.5352])
# Day  Predicted: tensor([40143.9336])
# Day  Predicted: tensor([40142.3398])
# Day  Predicted: tensor([40140.7422])
# Day  Predicted: tensor([40139.1367])
# Day  Predicted: tensor([40137.5391])
# Day  Predicted: tensor([40135.9414])
# Day  Predicted: tensor([40134.3398])
# Day  Predicted: tensor([40132.7422])
# Day  Predicted: tensor([40131.1445])
# Day  Predicted: tensor([40129.5469])
# Day  Predicted: tensor([40127.9453])
# Day  Predicted: tensor([40126.3438])
# Day  Predicted: tensor([40124.7500])
# Day  Predicted: tensor([40123.1484])
# Day  Predicted: tensor([40121.5469])
# Day  Predicted: tensor([40119.9531])
# Day  Predicted: tensor([40118.3516])
# Day  Predicted: tensor([40116.7578])
# Day  Predicted: tensor([40115.1484])
# Day  Predicted: tensor([40113.5547])
# Day  Predicted: tensor([40111.9570])
# Day  Predicted: tensor([40110.3594])
# Day  Predicted: tensor([40108.7617])
# Day  Predicted: tensor([40107.1641])
# Day  Predicted: tensor([40105.5625])
# Day  Predicted: tensor([40103.9688])
# Day  Predicted: tensor([40102.3672])
# Day  Predicted: tensor([40100.7656])
# Day  Predicted: tensor([40099.1719])
# Day  Predicted: tensor([40097.5742])
# Day  Predicted: tensor([40095.9766])
# Day  Predicted: tensor([40094.3789])
# Day  Predicted: tensor([40092.7773])
# Day  Predicted: tensor([40091.1797])
# Day  Predicted: tensor([40089.5859])
# Day  Predicted: tensor([40087.9844])
# Day  Predicted: tensor([40086.3867])
# Day  Predicted: tensor([40084.7891])
# Day  Predicted: tensor([40083.1953])
# Day  Predicted: tensor([40081.5938])
# Day  Predicted: tensor([40079.9961])
# Day  Predicted: tensor([40078.4062])
# Day  Predicted: tensor([40076.8047])
# Day  Predicted: tensor([40075.2070])
# Day  Predicted: tensor([40073.6094])
# Day  Predicted: tensor([40072.0078])
# Day  Predicted: tensor([40070.4141])
# Day  Predicted: tensor([40068.8203])
# Day  Predicted: tensor([40067.2227])
# Day  Predicted: tensor([40065.6211])
# Day  Predicted: tensor([40064.0312])
# Day  Predicted: tensor([40062.4297])
# Day  Predicted: tensor([40060.8320])
# Day  Predicted: tensor([40059.2383])
# Day  Predicted: tensor([40057.6445])
# Day  Predicted: tensor([40056.0469])
# Day  Predicted: tensor([40054.4531])
# Day  Predicted: tensor([40052.8555])
# Day  Predicted: tensor([40051.2617])
# Day  Predicted: tensor([40049.6602])
# Day  Predicted: tensor([40048.0664])
# Day  Predicted: tensor([40046.4727])
# Day  Predicted: tensor([40044.8750])
# Day  Predicted: tensor([40043.2812])
# Day  Predicted: tensor([40041.6836])
# Day  Predicted: tensor([40040.0898])
# Day  Predicted: tensor([40038.4961])
# Day  Predicted: tensor([40036.8945])
# Day  Predicted: tensor([40035.2969])
# Day  Predicted: tensor([40033.7070])
# Day  Predicted: tensor([40032.1133])
# Day  Predicted: tensor([40030.5117])
# Day  Predicted: tensor([40028.9180])
# Day  Predicted: tensor([40027.3242])
# Day  Predicted: tensor([40025.7305])
# Day  Predicted: tensor([40024.1328])
# Day  Predicted: tensor([40022.5391])
# Day  Predicted: tensor([40020.9414])
# Day  Predicted: tensor([40019.3477])
# Day  Predicted: tensor([40017.7539])
# Day  Predicted: tensor([40016.1602])
# Day  Predicted: tensor([40014.5586])
# Day  Predicted: tensor([40012.9688])
# Day  Predicted: tensor([40011.3711])
# Day  Predicted: tensor([40009.7891])
# Day  Predicted: tensor([40008.1875])
# Day  Predicted: tensor([40006.5938])
# Day  Predicted: tensor([40005.])
# Day  Predicted: tensor([40003.4023])
# Day  Predicted: tensor([40001.8125])
# Day  Predicted: tensor([40000.2109])
# Day  Predicted: tensor([39998.6172])
# Day  Predicted: tensor([39997.0312])
# Day  Predicted: tensor([39995.4336])
# Day  Predicted: tensor([39993.8398])
# Day  Predicted: tensor([39992.2422])
# Day  Predicted: tensor([39990.6523])
# Day  Predicted: tensor([39989.0586])
# Day  Predicted: tensor([39987.4688])
# Day  Predicted: tensor([39985.8750])
# Day  Predicted: tensor([39984.2695])
# Day  Predicted: tensor([39982.6797])
# Day  Predicted: tensor([39981.0859])
# Day  Predicted: tensor([39979.4922])
# Day  Predicted: tensor([39977.9023])
# Day  Predicted: tensor([39976.3086])
# Day  Predicted: tensor([39974.7148])
# Day  Predicted: tensor([39973.1172])
# Day  Predicted: tensor([39971.5352])
# Day  Predicted: tensor([39969.9375])
# Day  Predicted: tensor([39968.3477])
# Day  Predicted: tensor([39966.7539])
# Day  Predicted: tensor([39965.1562])
# Day  Predicted: tensor([39963.5703])
# Day  Predicted: tensor([39961.9727])
# Day  Predicted: tensor([39960.3867])
# Day  Predicted: tensor([39958.7930])
# Day  Predicted: tensor([39957.1953])
# Day  Predicted: tensor([39955.6055])
# Day  Predicted: tensor([39954.0078])
# Day  Predicted: tensor([39952.4180])
# Day  Predicted: tensor([39950.8242])
# Day  Predicted: tensor([39949.2305])
# Day  Predicted: tensor([39947.6445])
# Day  Predicted: tensor([39946.0469])
# Day  Predicted: tensor([39944.4570])
# Day  Predicted: tensor([39942.8633])
# Day  Predicted: tensor([39941.2734])
# Day  Predicted: tensor([39939.6875])
# Day  Predicted: tensor([39938.0898])
# Day  Predicted: tensor([39936.5000])
# Day  Predicted: tensor([39934.9141])
# Day  Predicted: tensor([39933.3164])
# Day  Predicted: tensor([39931.7266])
# Day  Predicted: tensor([39930.1367])
# Day  Predicted: tensor([39928.5430])
# Day  Predicted: tensor([39926.9492])
# Day  Predicted: tensor([39925.3594])
# Day  Predicted: tensor([39923.7695])
# Day  Predicted: tensor([39922.1797])
# Day  Predicted: tensor([39920.5898])
# Day  Predicted: tensor([39918.9922])
# Day  Predicted: tensor([39917.4062])
# Day  Predicted: tensor([39915.8125])
# Day  Predicted: tensor([39914.2266])
# Day  Predicted: tensor([39912.6289])
# Day  Predicted: tensor([39911.0391])
# Day  Predicted: tensor([39909.4453])
# Day  Predicted: tensor([39907.8594])
# Day  Predicted: tensor([39906.2695])
# Day  Predicted: tensor([39904.6836])
# Day  Predicted: tensor([39903.0898])
# Day  Predicted: tensor([39901.5039])
# Day  Predicted: tensor([39899.9102])
# Day  Predicted: tensor([39898.3203])
# Day  Predicted: tensor([39896.7305])
# Day  Predicted: tensor([39895.1445])
# Day  Predicted: tensor([39893.5469])
# Day  Predicted: tensor([39891.9648])
# Day  Predicted: tensor([39890.3672])
# Day  Predicted: tensor([39888.7852])
# Day  Predicted: tensor([39887.1953])
# Day  Predicted: tensor([39885.5977])
# Day  Predicted: tensor([39884.0117])
# Day  Predicted: tensor([39882.4258])
# Day  Predicted: tensor([39880.8359])
# Day  Predicted: tensor([39879.2422])
# Day  Predicted: tensor([39877.6562])
# Day  Predicted: tensor([39876.0664])
# Day  Predicted: tensor([39874.4727])
# Day  Predicted: tensor([39872.8828])
# Day  Predicted: tensor([39871.3008])
# Day  Predicted: tensor([39869.7109])
# Day  Predicted: tensor([39868.1211])
# Day  Predicted: tensor([39866.5352])
# Day  Predicted: tensor([39864.9453])
# Day  Predicted: tensor([39863.3594])
# Day  Predicted: tensor([39861.7656])
# Day  Predicted: tensor([39860.1797])
# Day  Predicted: tensor([39858.5898])
# Day  Predicted: tensor([39857.0039])
# Day  Predicted: tensor([39855.4141])
# Day  Predicted: tensor([39853.8242])
# Day  Predicted: tensor([39852.2383])
# Day  Predicted: tensor([39850.6484])
# Day  Predicted: tensor([39849.0586])
# Day  Predicted: tensor([39847.4727])
# Day  Predicted: tensor([39845.8828])
# Day  Predicted: tensor([39844.2969])
# Day  Predicted: tensor([39842.7070])
# Day  Predicted: tensor([39841.1211])
# Day  Predicted: tensor([39839.5312])
# Day  Predicted: tensor([39837.9414])
# Day  Predicted: tensor([39836.3594])
# Day  Predicted: tensor([39834.7695])
# Day  Predicted: tensor([39833.1875])
# Day  Predicted: tensor([39831.5938])
# Day  Predicted: tensor([39830.0078])
# Day  Predicted: tensor([39828.4219])
# Day  Predicted: tensor([39826.8359])
# Day  Predicted: tensor([39825.2461])
# Day  Predicted: tensor([39823.6641])
# Day  Predicted: tensor([39822.0703])
# Day  Predicted: tensor([39820.4844])
# Day  Predicted: tensor([39818.8945])
# Day  Predicted: tensor([39817.3047])
# Day  Predicted: tensor([39815.7188])
# Day  Predicted: tensor([39814.1406])
# Day  Predicted: tensor([39812.5508])
# Day  Predicted: tensor([39810.9688])
# Day  Predicted: tensor([39809.3789])
# Day  Predicted: tensor([39807.7852])
# Day  Predicted: tensor([39806.2031])
# Day  Predicted: tensor([39804.6172])
# Day  Predicted: tensor([39803.0352])
# Day  Predicted: tensor([39801.4453])
# Day  Predicted: tensor([39799.8594])
# Day  Predicted: tensor([39798.2695])
# Day  Predicted: tensor([39796.6836])
# Day  Predicted: tensor([39795.1016])
# Day  Predicted: tensor([39793.5156])
# Day  Predicted: tensor([39791.9336])
# Day  Predicted: tensor([39790.3438])
# Day  Predicted: tensor([39788.7578])
# Day  Predicted: tensor([39787.1719])
# Day  Predicted: tensor([39785.5898])
# Day  Predicted: tensor([39784.])
# Day  Predicted: tensor([39782.4141])
# Day  Predicted: tensor([39780.8359])
# Day  Predicted: tensor([39779.2422])
# Day  Predicted: tensor([39777.6562])
# Day  Predicted: tensor([39776.0742])
# Day  Predicted: tensor([39774.4883])
# Day  Predicted: tensor([39772.9023])
# Day  Predicted: tensor([39771.3242])
# Day  Predicted: tensor([39769.7383])
# Day  Predicted: tensor([39768.1523])
# Day  Predicted: tensor([39766.5664])
# Day  Predicted: tensor([39764.9805])
# Day  Predicted: tensor([39763.3945])
# Day  Predicted: tensor([39761.8086])
# Day  Predicted: tensor([39760.2266])
# Day  Predicted: tensor([39758.6367])
# Day  Predicted: tensor([39757.0547])
# Day  Predicted: tensor([39755.4766])
# Day  Predicted: tensor([39753.8906])
# Day  Predicted: tensor([39752.3047])
# Day  Predicted: tensor([39750.7188])
# Day  Predicted: tensor([39749.1367])
# Day  Predicted: tensor([39747.5547])
# Day  Predicted: tensor([39745.9688])
# Day  Predicted: tensor([39744.3828])
# Day  Predicted: tensor([39742.7969])
# Day  Predicted: tensor([39741.2109])
# Day  Predicted: tensor([39739.6328])
# Day  Predicted: tensor([39738.0508])
# Day  Predicted: tensor([39736.4648])
# Day  Predicted: tensor([39734.8867])
# Day  Predicted: tensor([39733.3008])
# Day  Predicted: tensor([39731.7148])
# Day  Predicted: tensor([39730.1328])
# Day  Predicted: tensor([39728.5508])
# Day  Predicted: tensor([39726.9648])
# Day  Predicted: tensor([39725.3789])
# Day  Predicted: tensor([39723.7969])
# Day  Predicted: tensor([39722.2188])
# Day  Predicted: tensor([39720.6328])
# Day  Predicted: tensor([39719.0508])
# Day  Predicted: tensor([39717.4688])
# Day  Predicted: tensor([39715.8867])
# Day  Predicted: tensor([39714.3047])
# Day  Predicted: tensor([39712.7188])
# Day  Predicted: tensor([39711.1328])
# Day  Predicted: tensor([39709.5547])
# Day  Predicted: tensor([39707.9688])
# Day  Predicted: tensor([39706.3906])
# Day  Predicted: tensor([39704.8164])
# Day  Predicted: tensor([39703.2266])
# Day  Predicted: tensor([39701.6445])
# Day  Predicted: tensor([39700.0586])
# Day  Predicted: tensor([39698.4805])
# Day  Predicted: tensor([39696.8945])
# Day  Predicted: tensor([39695.3164])
# Day  Predicted: tensor([39693.7305])
# Day  Predicted: tensor([39692.1523])
# Day  Predicted: tensor([39690.5703])
# Day  Predicted: tensor([39688.9844])
# Day  Predicted: tensor([39687.4062])
# Day  Predicted: tensor([39685.8281])
# Day  Predicted: tensor([39684.2422])
# Day  Predicted: tensor([39682.6641])
# Day  Predicted: tensor([39681.0781])
# Day  Predicted: tensor([39679.4922])
# Day  Predicted: tensor([39677.9141])
# Day  Predicted: tensor([39676.3359])
# Day  Predicted: tensor([39674.7539])
# Day  Predicted: tensor([39673.1758])
# Day  Predicted: tensor([39671.5977])
# Day  Predicted: tensor([39670.0117])
# Day  Predicted: tensor([39668.4336])
# Day  Predicted: tensor([39666.8438])
# Day  Predicted: tensor([39665.2656])
# Day  Predicted: tensor([39663.6875])
# Day  Predicted: tensor([39662.1055])
# Day  Predicted: tensor([39660.5312])
# Day  Predicted: tensor([39658.9453])
# Day  Predicted: tensor([39657.3672])
# Day  Predicted: tensor([39655.7812])
# Day  Predicted: tensor([39654.2031])
# Day  Predicted: tensor([39652.6250])
# Day  Predicted: tensor([39651.0469])
# Day  Predicted: tensor([39649.4648])
# Day  Predicted: tensor([39647.8828])
# Day  Predicted: tensor([39646.3047])
# Day  Predicted: tensor([39644.7305])
# Day  Predicted: tensor([39643.1445])
# Day  Predicted: tensor([39641.5703])
# Day  Predicted: tensor([39639.9844])
# Day  Predicted: tensor([39638.4102])
# Day  Predicted: tensor([39636.8242])
# Day  Predicted: tensor([39635.2461])
# Day  Predicted: tensor([39633.6680])
# Day  Predicted: tensor([39632.0859])
# Day  Predicted: tensor([39630.5078])
# Day  Predicted: tensor([39628.9297])
# Day  Predicted: tensor([39627.3516])
# Day  Predicted: tensor([39625.7656])
# Day  Predicted: tensor([39624.1875])
# Day  Predicted: tensor([39622.6133])
# Day  Predicted: tensor([39621.0312])
# Day  Predicted: tensor([39619.4531])
# Day  Predicted: tensor([39617.8711])
# Day  Predicted: tensor([39616.2969])
# Day  Predicted: tensor([39614.7148])
# Day  Predicted: tensor([39613.1406])
# Day  Predicted: tensor([39611.5625])
# Day  Predicted: tensor([39609.9805])
# Day  Predicted: tensor([39608.4023])
# Day  Predicted: tensor([39606.8242])
# Day  Predicted: tensor([39605.2461])
# Day  Predicted: tensor([39603.6680])
# Day  Predicted: tensor([39602.0859])
# Day  Predicted: tensor([39600.5117])
# Day  Predicted: tensor([39598.9375])
# Day  Predicted: tensor([39597.3594])
# Day  Predicted: tensor([39595.7734])
# Day  Predicted: tensor([39594.1992])
# Day  Predicted: tensor([39592.6211])
# Day  Predicted: tensor([39591.0469])
# Day  Predicted: tensor([39589.4648])
# Day  Predicted: tensor([39587.8867])
# Day  Predicted: tensor([39586.3086])
# Day  Predicted: tensor([39584.7305])
# Day  Predicted: tensor([39583.1602])
# Day  Predicted: tensor([39581.5742])
# Day  Predicted: tensor([39580.])
# Day  Predicted: tensor([39578.4219])
# Day  Predicted: tensor([39576.8516])
# Day  Predicted: tensor([39575.2695])
# Day  Predicted: tensor([39573.6914])
# Day  Predicted: tensor([39572.1133])
# Day  Predicted: tensor([39570.5391])
# Day  Predicted: tensor([39568.9570])
# Day  Predicted: tensor([39567.3828])
# Day  Predicted: tensor([39565.7969])
# Day  Predicted: tensor([39564.2305])
# Day  Predicted: tensor([39562.6484])
# Day  Predicted: tensor([39561.0781])
# Day  Predicted: tensor([39559.5039])
# Day  Predicted: tensor([39557.9258])
# Day  Predicted: tensor([39556.3438])
# Day  Predicted: tensor([39554.7773])
# Day  Predicted: tensor([39553.1914])
# Day  Predicted: tensor([39551.6172])
# Day  Predicted: tensor([39550.0391])
# Day  Predicted: tensor([39548.4648])
# Day  Predicted: tensor([39546.8906])
# Day  Predicted: tensor([39545.3125])
# Day  Predicted: tensor([39543.7383])
# Day  Predicted: tensor([39542.1602])
# Day  Predicted: tensor([39540.5859])
# Day  Predicted: tensor([39539.0156])
# Day  Predicted: tensor([39537.4336])
# Day  Predicted: tensor([39535.8633])
# Day  Predicted: tensor([39534.2852])
# Day  Predicted: tensor([39532.7031])
# Day  Predicted: tensor([39531.1289])
# Day  Predicted: tensor([39529.5586])
# Day  Predicted: tensor([39527.9844])
# Day  Predicted: tensor([39526.4062])
# Day  Predicted: tensor([39524.8281])
# Day  Predicted: tensor([39523.2578])
# Day  Predicted: tensor([39521.6797])
# Day  Predicted: tensor([39520.1055])
# Day  Predicted: tensor([39518.5312])
# Day  Predicted: tensor([39516.9570])
# Day  Predicted: tensor([39515.3867])
# Day  Predicted: tensor([39513.8047])
# Day  Predicted: tensor([39512.2305])
# Day  Predicted: tensor([39510.6562])
# Day  Predicted: tensor([39509.0781])
# Day  Predicted: tensor([39507.5078])
# Day  Predicted: tensor([39505.9336])
# Day  Predicted: tensor([39504.3633])
# Day  Predicted: tensor([39502.7852])
# Day  Predicted: tensor([39501.2109])
# Day  Predicted: tensor([39499.6367])
# Day  Predicted: tensor([39498.0625])
# Day  Predicted: tensor([39496.4844])
# Day  Predicted: tensor([39494.9180])
# Day  Predicted: tensor([39493.3398])
# Day  Predicted: tensor([39491.7617])
# Day  Predicted: tensor([39490.1914])
# Day  Predicted: tensor([39488.6211])
# Day  Predicted: tensor([39487.0430])
# Day  Predicted: tensor([39485.4688])
# Day  Predicted: tensor([39483.8984])
# Day  Predicted: tensor([39482.3203])
# Day  Predicted: tensor([39480.7500])
# Day  Predicted: tensor([39479.1758])
# Day  Predicted: tensor([39477.6016])
# Day  Predicted: tensor([39476.0312])
# Day  Predicted: tensor([39474.4570])
# Day  Predicted: tensor([39472.8867])
# Day  Predicted: tensor([39471.3125])
# Day  Predicted: tensor([39469.7383])
# Day  Predicted: tensor([39468.1680])
# Day  Predicted: tensor([39466.5898])
# Day  Predicted: tensor([39465.0195])
# Day  Predicted: tensor([39463.4492])
# Day  Predicted: tensor([39461.8750])
# Day  Predicted: tensor([39460.3047])
# Day  Predicted: tensor([39458.7266])
# Day  Predicted: tensor([39457.1602])
# Day  Predicted: tensor([39455.5820])
# Day  Predicted: tensor([39454.0078])
# Day  Predicted: tensor([39452.4375])
# Day  Predicted: tensor([39450.8672])
# Day  Predicted: tensor([39449.2969])
# Day  Predicted: tensor([39447.7227])
# Day  Predicted: tensor([39446.1523])
# Day  Predicted: tensor([39444.5742])
# Day  Predicted: tensor([39443.0039])
# Day  Predicted: tensor([39441.4336])
# Day  Predicted: tensor([39439.8633])
# Day  Predicted: tensor([39438.2891])
# Day  Predicted: tensor([39436.7188])
# Day  Predicted: tensor([39435.1445])
# Day  Predicted: tensor([39433.5781])
# Day  Predicted: tensor([39432.0039])
# Day  Predicted: tensor([39430.4297])
# Day  Predicted: tensor([39428.8633])
# Day  Predicted: tensor([39427.2930])
# Day  Predicted: tensor([39425.7188])
# Day  Predicted: tensor([39424.1484])
# Day  Predicted: tensor([39422.5781])
# Day  Predicted: tensor([39421.0039])
# Day  Predicted: tensor([39419.4336])
# Day  Predicted: tensor([39417.8633])
# Day  Predicted: tensor([39416.2930])
# Day  Predicted: tensor([39414.7188])
# Day  Predicted: tensor([39413.1484])
# Day  Predicted: tensor([39411.5820])
# Day  Predicted: tensor([39410.0078])
# Day  Predicted: tensor([39408.4414])
# Day  Predicted: tensor([39406.8672])
# Day  Predicted: tensor([39405.2969])
# Day  Predicted: tensor([39403.7305])
# Day  Predicted: tensor([39402.1562])
# Day  Predicted: tensor([39400.5859])
# Day  Predicted: tensor([39399.0156])
# Day  Predicted: tensor([39397.4453])
# Day  Predicted: tensor([39395.8750])
# Day  Predicted: tensor([39394.3086])
# Day  Predicted: tensor([39392.7344])
# Day  Predicted: tensor([39391.1680])
# Day  Predicted: tensor([39389.5938])
# Day  Predicted: tensor([39388.0195])
# Day  Predicted: tensor([39386.4570])
# Day  Predicted: tensor([39384.8828])
# Day  Predicted: tensor([39383.3164])
# Day  Predicted: tensor([39381.7461])
# Day  Predicted: tensor([39380.1797])
# Day  Predicted: tensor([39378.6094])
# Day  Predicted: tensor([39377.0391])
# Day  Predicted: tensor([39375.4727])
# Day  Predicted: tensor([39373.9023])
# Day  Predicted: tensor([39372.3320])
# Day  Predicted: tensor([39370.7617])
# Day  Predicted: tensor([39369.1992])
# Day  Predicted: tensor([39367.6289])
# Day  Predicted: tensor([39366.0586])
# Day  Predicted: tensor([39364.4805])
# Day  Predicted: tensor([39362.9180])
# Day  Predicted: tensor([39361.3555])
# Day  Predicted: tensor([39359.7812])
# Day  Predicted: tensor([39358.2109])
# Day  Predicted: tensor([39356.6445])
# Day  Predicted: tensor([39355.0781])
# Day  Predicted: tensor([39353.5039])
# Day  Predicted: tensor([39351.9414])
# Day  Predicted: tensor([39350.3711])
# Day  Predicted: tensor([39348.8008])
# Day  Predicted: tensor([39347.2305])
# Day  Predicted: tensor([39345.6641])
# Day  Predicted: tensor([39344.0977])
# Day  Predicted: tensor([39342.5312])
# Day  Predicted: tensor([39340.9648])
# Day  Predicted: tensor([39339.3984])
# Day  Predicted: tensor([39337.8281])
# Day  Predicted: tensor([39336.2617])

# %%
# Khởi tạo cấu hình cho model
class Configs:
    def __init__(self):
        self.seq_len = 20  # Độ dài chuỗi thời gian đầu vào(tập kiểm tra)
        self.pred_len = 20  # Độ dài dự đoán
        self.individual = False  # Có sử dụng các kênh cá nhân hay không
        self.enc_in = 1  # Số lượng kênh đầu vào (tương ứng với số cột của dữ liệu)

configs = Configs()

# Khởi tạo model
model = Model(configs)

# %%
import torch.optim as optim

# Xác định hàm mất mát và trình tối ưu hóa
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Có thể điều chỉnh lr theo yêu cầu

# Huấn luyện mô hình
num_epochs = 100  # Số lượng epoch
for epoch in range(num_epochs):
    model.train()  # Chuyển sang chế độ huấn luyện
    optimizer.zero_grad()  # Đặt gradient về 0

    # Feedforward
    outputs = model(input_data_20day)

    # Tính toán loss
    loss = criterion(outputs, input_data_20day)  # So sánh đầu ra với đầu vào

    # Backpropagation
    loss.backward()  # Tính toán gradient
    optimizer.step()  # Cập nhật trọng số

    # In ra loss sau mỗi epoch
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/100], Loss: 72061.6250
# Epoch [2/100], Loss: 27433.7539
# Epoch [3/100], Loss: 33798.1172
# Epoch [4/100], Loss: 32974.3359
# Epoch [5/100], Loss: 26444.7344
# Epoch [6/100], Loss: 18223.2266
# Epoch [7/100], Loss: 12470.6250
# Epoch [8/100], Loss: 11757.9072
# Epoch [9/100], Loss: 14537.9668
# Epoch [10/100], Loss: 15454.7578
# Epoch [11/100], Loss: 11975.3330
# Epoch [12/100], Loss: 7408.8735
# Epoch [13/100], Loss: 5933.2461
# Epoch [14/100], Loss: 7485.0181
# Epoch [15/100], Loss: 8502.9238
# Epoch [16/100], Loss: 6957.2471
# Epoch [17/100], Loss: 4511.1699
# Epoch [18/100], Loss: 3697.5300
# Epoch [19/100], Loss: 4623.6211
# Epoch [20/100], Loss: 5231.5225
# Epoch [21/100], Loss: 4250.9341
# Epoch [22/100], Loss: 2638.7043
# Epoch [23/100], Loss: 1993.3248
# Epoch [24/100], Loss: 2511.9138
# Epoch [25/100], Loss: 3063.1716
# Epoch [26/100], Loss: 2793.9800
# Epoch [27/100], Loss: 1993.9473
# Epoch [28/100], Loss: 1414.9508
# Epoch [29/100], Loss: 1322.8846
# Epoch [30/100], Loss: 1454.4933
# Epoch [31/100], Loss: 1512.5195
# Epoch [32/100], Loss: 1411.0048
# Epoch [33/100], Loss: 1180.3353
# Epoch [34/100], Loss: 905.6820
# Epoch [35/100], Loss: 731.0206
# Epoch [36/100], Loss: 740.8287
# Epoch [37/100], Loss: 825.9647
# Epoch [38/100], Loss: 794.9965
# Epoch [39/100], Loss: 622.5674
# Epoch [40/100], Loss: 465.5555
# Epoch [41/100], Loss: 437.4000
# Epoch [42/100], Loss: 475.3180
# Epoch [43/100], Loss: 460.2795
# Epoch [44/100], Loss: 373.7078
# Epoch [45/100], Loss: 291.9622
# Epoch [46/100], Loss: 276.1090
# Epoch [47/100], Loss: 302.5854
# Epoch [48/100], Loss: 293.8874
# Epoch [49/100], Loss: 217.2047
# Epoch [50/100], Loss: 141.7995
# Epoch [51/100], Loss: 153.6094
# Epoch [52/100], Loss: 217.2766
# Epoch [53/100], Loss: 210.3952
# Epoch [54/100], Loss: 113.6370
# Epoch [55/100], Loss: 52.4855
# Epoch [56/100], Loss: 99.0642
# Epoch [57/100], Loss: 156.4699
# Epoch [58/100], Loss: 122.6063
# Epoch [59/100], Loss: 50.4720
# Epoch [60/100], Loss: 41.0157
# Epoch [61/100], Loss: 78.0753
# Epoch [62/100], Loss: 82.9100
# Epoch [63/100], Loss: 53.0984
# Epoch [64/100], Loss: 39.6222
# Epoch [65/100], Loss: 46.4424
# Epoch [66/100], Loss: 43.3185
# Epoch [67/100], Loss: 32.0760
# Epoch [68/100], Loss: 31.6236
# Epoch [69/100], Loss: 35.4341
# Epoch [70/100], Loss: 29.8109
# Epoch [71/100], Loss: 21.0444
# Epoch [72/100], Loss: 18.5262
# Epoch [73/100], Loss: 19.6033
# Epoch [74/100], Loss: 20.5139
# Epoch [75/100], Loss: 19.7840
# Epoch [76/100], Loss: 14.5208
# Epoch [77/100], Loss: 8.4790
# Epoch [78/100], Loss: 10.0210
# Epoch [79/100], Loss: 15.1929
# Epoch [80/100], Loss: 12.9000
# Epoch [81/100], Loss: 5.9717
# Epoch [82/100], Loss: 5.0748
# Epoch [83/100], Loss: 8.5476
# Epoch [84/100], Loss: 8.4377
# Epoch [85/100], Loss: 5.7289
# Epoch [86/100], Loss: 4.6325
# Epoch [87/100], Loss: 4.3486
# Epoch [88/100], Loss: 4.0949
# Epoch [89/100], Loss: 4.6346
# Epoch [90/100], Loss: 4.2556
# Epoch [91/100], Loss: 2.4200
# Epoch [92/100], Loss: 2.1414
# Epoch [93/100], Loss: 3.4021
# Epoch [94/100], Loss: 2.8939
# Epoch [95/100], Loss: 1.3329
# Epoch [96/100], Loss: 1.6536
# Epoch [97/100], Loss: 2.4984
# Epoch [98/100], Loss: 1.6220
# Epoch [99/100], Loss: 0.7218
# Epoch [100/100], Loss: 1.3150

# %%
# Dự báo cho 90 ngày kế tiếp
# # Chuyển sang chế độ đánh giá
model.eval()

# Không cần tính gradient trong quá trình dự báo
with torch.no_grad():
    input_data_future = input_data_20day.clone()  # Tạo một bản sao của dữ liệu đầu vào để cập nhật dự báo
    predicted = []  # Danh sách dự báo cho các ngày tiếp theo
    for i in range(90):  # Dự báo cho 90 ngày tiếp theo
        # Dự báo cho ngày hiện tại
        output = model(input_data_future)
        # Lưu dự báo của ngày hiện tại
        predicted.append(output[:, -1, :])  # Lấy dự báo cho ngày cuối cùng trong chuỗi thời gian
        # Cập nhật dữ liệu đầu vào cho ngày tiếp theo
        input_data_future = torch.cat([input_data_future[:, :, 1:], output], dim=2)

    # In ra dự báo cho 30 ngày tiếp theo
    print("Predicted Output for the next 90 days:")
    for i in range(90):
        # In ra ngày tương ứng với dự báo
        print(f"Day  Predicted: {predicted[i][0]}")
# Out:
# Predicted Output for the next 90 days:
# Day  Predicted: tensor([16771.4434])
# Day  Predicted: tensor([16771.0762])
# Day  Predicted: tensor([16770.7168])
# Day  Predicted: tensor([16770.3613])
# Day  Predicted: tensor([16770.0039])
# Day  Predicted: tensor([16769.6465])
# Day  Predicted: tensor([16769.2891])
# Day  Predicted: tensor([16768.9316])
# Day  Predicted: tensor([16768.5742])
# Day  Predicted: tensor([16768.2188])
# Day  Predicted: tensor([16767.8613])
# Day  Predicted: tensor([16767.5039])
# Day  Predicted: tensor([16767.1465])
# Day  Predicted: tensor([16766.7910])
# Day  Predicted: tensor([16766.4336])
# Day  Predicted: tensor([16766.0781])
# Day  Predicted: tensor([16765.7207])
# Day  Predicted: tensor([16765.3633])
# Day  Predicted: tensor([16765.0059])
# Day  Predicted: tensor([16764.6523])
# Day  Predicted: tensor([16764.2930])
# Day  Predicted: tensor([16763.9375])
# Day  Predicted: tensor([16763.5781])
# Day  Predicted: tensor([16763.2227])
# Day  Predicted: tensor([16762.8672])
# Day  Predicted: tensor([16762.5098])
# Day  Predicted: tensor([16762.1543])
# Day  Predicted: tensor([16761.7969])
# Day  Predicted: tensor([16761.4395])
# Day  Predicted: tensor([16761.0840])
# Day  Predicted: tensor([16760.7285])
# Day  Predicted: tensor([16760.3691])
# Day  Predicted: tensor([16760.0117])
# Day  Predicted: tensor([16759.6582])
# Day  Predicted: tensor([16759.2988])
# Day  Predicted: tensor([16758.9414])
# Day  Predicted: tensor([16758.5879])
# Day  Predicted: tensor([16758.2324])
# Day  Predicted: tensor([16757.8730])
# Day  Predicted: tensor([16757.5156])
# Day  Predicted: tensor([16757.1602])
# Day  Predicted: tensor([16756.8008])
# Day  Predicted: tensor([16756.4453])
# Day  Predicted: tensor([16756.0898])
# Day  Predicted: tensor([16755.7324])
# Day  Predicted: tensor([16755.3770])
# Day  Predicted: tensor([16755.0195])
# Day  Predicted: tensor([16754.6621])
# Day  Predicted: tensor([16754.3066])
# Day  Predicted: tensor([16753.9492])
# Day  Predicted: tensor([16753.5918])
# Day  Predicted: tensor([16753.2344])
# Day  Predicted: tensor([16752.8789])
# Day  Predicted: tensor([16752.5215])
# Day  Predicted: tensor([16752.1660])
# Day  Predicted: tensor([16751.8086])
# Day  Predicted: tensor([16751.4531])
# Day  Predicted: tensor([16751.0938])
# Day  Predicted: tensor([16750.7402])
# Day  Predicted: tensor([16750.3809])
# Day  Predicted: tensor([16750.0273])
# Day  Predicted: tensor([16749.6699])
# Day  Predicted: tensor([16749.3125])
# Day  Predicted: tensor([16748.9551])
# Day  Predicted: tensor([16748.5996])
# Day  Predicted: tensor([16748.2441])
# Day  Predicted: tensor([16747.8887])
# Day  Predicted: tensor([16747.5293])
# Day  Predicted: tensor([16747.1719])
# Day  Predicted: tensor([16746.8164])
# Day  Predicted: tensor([16746.4629])
# Day  Predicted: tensor([16746.1035])
# Day  Predicted: tensor([16745.7500])
# Day  Predicted: tensor([16745.3906])
# Day  Predicted: tensor([16745.0352])
# Day  Predicted: tensor([16744.6797])
# Day  Predicted: tensor([16744.3223])
# Day  Predicted: tensor([16743.9668])
# Day  Predicted: tensor([16743.6074])
# Day  Predicted: tensor([16743.2539])
# Day  Predicted: tensor([16742.8965])
# Day  Predicted: tensor([16742.5391])
# Day  Predicted: tensor([16742.1836])
# Day  Predicted: tensor([16741.8262])
# Day  Predicted: tensor([16741.4707])
# Day  Predicted: tensor([16741.1133])
# Day  Predicted: tensor([16740.7598])
# Day  Predicted: tensor([16740.4004])
# Day  Predicted: tensor([16740.0469])
# Day  Predicted: tensor([16739.6895])

# %%
# Chuyển dữ liệu từ Series pandas thành numpy array để vẽ biểu đồ
predicted_values_test = [pred[0].numpy() for pred in predicted_test]
# Chuyển dữ liệu dự báo từ tensor về numpy array
predicted_values = [pred[0].numpy() for pred in predicted]
# Tạo mảng chứa ngày của train_data_price
train_dates = df['Date'].values[:len(train_data_price)]
# Tạo mảng chứa ngày của test_data_price
test_dates = df['Date'].values[len(train_data_price):len(train_data_price)+len(test_data_price)]
# Tạo mảng chứa ngày dự đoán
predicted_dates = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=len(predicted_values))

split_size = len(predicted_values) // 3

predicted_values_30day = predicted_values[:split_size]
predicted_values_60day = predicted_values[split_size:2*split_size]
predicted_values_90day = predicted_values[2*split_size:]
# Tính toán các khoảng thời gian cho mỗi phần
predicted_dates_30day = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=split_size)
predicted_dates_60day = pd.date_range(start=predicted_dates_30day[-1] + pd.DateOffset(days=1), periods=split_size)
predicted_dates_90day = pd.date_range(start=predicted_dates_60day[-1] + pd.DateOffset(days=1), periods=split_size)

# %%
import matplotlib.pyplot as plt

# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(train_dates, train_data_price, label='Training Data')
plt.plot(test_dates, test_data_price, label='Actual Data')
plt.plot(test_dates, predicted_values_test, label='Predicted')
plt.plot(predicted_dates_30day, predicted_values_30day, label='Predicted 30 Day', color='red')
plt.plot(predicted_dates_60day, predicted_values_60day, label='Predicted 60 Day', color='green')
plt.plot(predicted_dates_90day, predicted_values_90day, label='Predicted 90 Day', color='blue')

plt.title('DLinear - DXG Stock Price - 7:3')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt


# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(test_dates, test_data_price, label='Actual Data')
plt.plot(predicted_dates_30day, predicted_values_30day, label='Predicted 30 Day', color='red')
plt.plot(predicted_dates_60day, predicted_values_60day, label='Predicted 60 Day', color='green')
plt.plot(predicted_dates_90day, predicted_values_90day, label='Predicted 90 Day', color='blue')

plt.title('DLinear - DXG Stock Price - 7:3')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
outputs_test = np.array(predicted_values_test)
outputs_test = outputs_test.flatten()

# %%
# Mean Absolute Error (MAE) và Mean Absolute Percentage Error (MAPE)
mae_test = np.mean(np.abs(test_data_price - outputs_test))
mape_test = np.mean(np.abs((test_data_price - outputs_test) / test_data_price)) * 100
rmse_test = np.sqrt(np.mean((test_data_price - outputs_test) ** 2))

print("MAE:", mae_test)
print("MAPE:", mape_test)
print("RMSE:", rmse_test)
# Out:
# MAE: 21506.28629913643
# MAPE: 140.128150867899
# RMSE: 22437.80183742448
