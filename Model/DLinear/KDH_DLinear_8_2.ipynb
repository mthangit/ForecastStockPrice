# %%
from re import X
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        # padding on the both ends of time series
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x


class series_decomp(nn.Module):
    """
    Series decomposition block
    """
    def __init__(self, kernel_size):
        super(series_decomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class Model(nn.Module):
    """
    DLinear
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len

        # Decompsition Kernel Size
        kernel_size = 25
        self.decompsition = series_decomp(kernel_size)
        self.individual = configs.individual
        self.channels = configs.enc_in

        if self.individual:
            self.Linear_Seasonal = nn.ModuleList()
            self.Linear_Trend = nn.ModuleList()
            self.Linear_Decoder = nn.ModuleList()
            for i in range(self.channels):
                self.Linear_Seasonal.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Seasonal[i].weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))
                self.Linear_Trend.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Trend[i].weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))
                self.Linear_Decoder.append(nn.Linear(self.seq_len,self.pred_len))
        else:
            self.Linear_Seasonal = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Trend = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Decoder = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Seasonal.weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))
            self.Linear_Trend.weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))

    def forward(self, x):
        # x: [Batch, Input length, Channel]
        seasonal_init, trend_init = self.decompsition(x)
        seasonal_init, trend_init = seasonal_init.permute(0,2,1), trend_init.permute(0,2,1)
        if self.individual:
            seasonal_output = torch.zeros([seasonal_init.size(0),seasonal_init.size(1),self.pred_len],dtype=seasonal_init.dtype).to(seasonal_init.device)
            trend_output = torch.zeros([trend_init.size(0),trend_init.size(1),self.pred_len],dtype=trend_init.dtype).to(trend_init.device)
            for i in range(self.channels):
                seasonal_output[:,i,:] = self.Linear_Seasonal[i](seasonal_init[:,i,:])
                trend_output[:,i,:] = self.Linear_Trend[i](trend_init[:,i,:])
        else:
            seasonal_output = self.Linear_Seasonal(seasonal_init)
            trend_output = self.Linear_Trend(trend_init)

        x = seasonal_output + trend_output
        return x.permute(0,2,1) # to [Batch, Output length, Channel]

# %%
import pandas as pd
import torch
from datetime import datetime, timedelta
# Đọc dữ liệu từ file CSV
df = pd.read_csv('KDH-Historical-Data.csv')

# %%
# # Chuyển dữ liệu thời gian
# df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')
# # Đảo ngược lại dữ liệu
# df = df.iloc[::-1].reset_index(drop=True)

# %%
# # Loại bỏ dấu phẩy từ cột "Price"
# df['Price'] = df['Price'].str.replace(',', '').astype(float)
# # Loại bỏ dấu phẩy từ cột "Open"
# df['Open'] = df['Open'].str.replace(',', '').astype(float)
# # Loại bỏ dấu phẩy từ cột "High"
# df['High'] = df['High'].str.replace(',', '').astype(float)
# # Loại bỏ dấu phẩy từ cột "Low"
# df['Low'] = df['Low'].str.replace(',', '').astype(float)

# %%
df
# Out:
#       Unnamed: 0        Date    Price
# 0              0  2017-01-03   9198.4
# 1              1  2017-01-04   9198.4
# 2              2  2017-01-05   8944.8
# 3              3  2017-01-06   9083.2
# 4              4  2017-01-07   9106.2
# ...          ...         ...      ...
# 2702        2702  2024-05-28  36250.0
# 2703        2703  2024-05-29  35700.0
# 2704        2704  2024-05-30  36050.0
# 2705        2705  2024-05-31  36200.0
# 2706        2706  2024-06-01  36000.0
#
# [2707 rows x 3 columns]

# %%
# Lấy ngày cuối cùng của dữ liệu
df['Date'] = pd.to_datetime(df['Date'])
last_date = df['Date'].max()

# %%
# Lấy dữ liệu Date cần phân tích để dự bảo DL trên tập test
time_series_Date = df['Date']

# Phân chia dữ liệu thành tập huấn luyện và tập kiểm tra - để lấy date
train_data_Date = time_series_Date[:int(0.8 * len(time_series_Date))]
test_data_Date = time_series_Date[int(0.8 * len(time_series_Date)):]
first_data_Date = test_data_Date.min()
print(first_data_Date)
# Out:
# 2022-12-08 00:00:00

# %%
# Lấy dữ liệu cần phân tích
time_series_price = df['Price']

# Phân chia dữ liệu thành tập huấn luyện và tập kiểm tra
train_data_price = time_series_price[:int(0.8 * len(time_series_price))]
test_data_price = time_series_price[int(0.8 * len(time_series_price)):]

# Chọn các cột dữ liệu số
# numeric_columns = ['Price', 'Open', 'High', 'Low']
numeric_columns = ['Price']

# Chuyển các giá trị số thành tensor
numeric_data = df[numeric_columns].values.astype(np.float32)

# Mở rộng chiều để phù hợp với đầu vào của mô hình
numeric_data = np.expand_dims(numeric_data, axis=0)

# Chia dữ liệu thành tensor
input_data_train = torch.tensor(numeric_data[:, :len(train_data_price), :])
input_data_test = torch.tensor(numeric_data[:, len(train_data_price):, :])
# Lấy dữ liệu 20 ngày gần nhất
recent_20_prices = time_series_price[-20:]

# Chuyển đổi dữ liệu 20 ngày gần nhất thành numpy array và mở rộng chiều
recent_20_prices_array = recent_20_prices.values.astype(np.float32)
recent_20_prices_array = np.expand_dims(recent_20_prices_array, axis=0)
recent_20_prices_array = np.expand_dims(recent_20_prices_array, axis=-1)

# Chuyển đổi thành tensor
input_data_20day = torch.tensor(recent_20_prices_array)
# In ra để kiểm tra kích thước của các tensor
print("Kích thước tập huấn luyện:", input_data_train.shape)
print("Kích thước tập kiểm tra:", input_data_test.shape)
# Out:
# Kích thước tập huấn luyện: torch.Size([1, 2165, 1])
# Kích thước tập kiểm tra: torch.Size([1, 542, 1])

# %%
# Khởi tạo cấu hình cho model
class Configs:
    def __init__(self):
        self.seq_len = 2165  # Độ dài chuỗi thời gian đầu vào(tập kiểm tra)
        self.pred_len = 2165  # Độ dài dự đoán
        self.individual = False  # Có sử dụng các kênh cá nhân hay không
        self.enc_in = 1  # Số lượng kênh đầu vào (tương ứng với số cột của dữ liệu)

configs = Configs()

# Khởi tạo model
model = Model(configs)

# %%
import torch.optim as optim

# Xác định hàm mất mát và trình tối ưu hóa
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Có thể điều chỉnh lr theo yêu cầu

# Huấn luyện mô hình
num_epochs = 100  # Số lượng epoch
for epoch in range(num_epochs):
    model.train()  # Chuyển sang chế độ huấn luyện
    optimizer.zero_grad()  # Đặt gradient về 0

    # Feedforward
    outputs = model(input_data_train)

    # Tính toán loss
    loss = criterion(outputs, input_data_train)  # So sánh đầu ra với đầu vào

    # Backpropagation
    loss.backward()  # Tính toán gradient
    optimizer.step()  # Cập nhật trọng số

    # In ra loss sau mỗi epoch
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/100], Loss: 95114456.0000
# Epoch [2/100], Loss: 1853978496.0000
# Epoch [3/100], Loss: 170998832.0000
# Epoch [4/100], Loss: 378033216.0000
# Epoch [5/100], Loss: 1016846144.0000
# Epoch [6/100], Loss: 697694272.0000
# Epoch [7/100], Loss: 137524864.0000
# Epoch [8/100], Loss: 40317008.0000
# Epoch [9/100], Loss: 348535168.0000
# Epoch [10/100], Loss: 525508160.0000
# Epoch [11/100], Loss: 364788992.0000
# Epoch [12/100], Loss: 107427384.0000
# Epoch [13/100], Loss: 26343238.0000
# Epoch [14/100], Loss: 140110832.0000
# Epoch [15/100], Loss: 258191232.0000
# Epoch [16/100], Loss: 238459136.0000
# Epoch [17/100], Loss: 123023280.0000
# Epoch [18/100], Loss: 39777920.0000
# Epoch [19/100], Loss: 50067360.0000
# Epoch [20/100], Loss: 107923840.0000
# Epoch [21/100], Loss: 134437424.0000
# Epoch [22/100], Loss: 103886768.0000
# Epoch [23/100], Loss: 53516472.0000
# Epoch [24/100], Loss: 29561536.0000
# Epoch [25/100], Loss: 41897580.0000
# Epoch [26/100], Loss: 64522176.0000
# Epoch [27/100], Loss: 68128040.0000
# Epoch [28/100], Loss: 48596692.0000
# Epoch [29/100], Loss: 25751084.0000
# Epoch [30/100], Loss: 19420156.0000
# Epoch [31/100], Loss: 29507916.0000
# Epoch [32/100], Loss: 38956464.0000
# Epoch [33/100], Loss: 34501132.0000
# Epoch [34/100], Loss: 20724668.0000
# Epoch [35/100], Loss: 12038800.0000
# Epoch [36/100], Loss: 14754757.0000
# Epoch [37/100], Loss: 21280966.0000
# Epoch [38/100], Loss: 21428580.0000
# Epoch [39/100], Loss: 14630267.0000
# Epoch [40/100], Loss: 8493352.0000
# Epoch [41/100], Loss: 8321686.0000
# Epoch [42/100], Loss: 11638881.0000
# Epoch [43/100], Loss: 12703960.0000
# Epoch [44/100], Loss: 9641356.0000
# Epoch [45/100], Loss: 5758501.5000
# Epoch [46/100], Loss: 4848119.0000
# Epoch [47/100], Loss: 6668208.5000
# Epoch [48/100], Loss: 7723720.5000
# Epoch [49/100], Loss: 5994518.0000
# Epoch [50/100], Loss: 3421224.7500
# Epoch [51/100], Loss: 2921999.7500
# Epoch [52/100], Loss: 4267328.0000
# Epoch [53/100], Loss: 4745072.0000
# Epoch [54/100], Loss: 3326965.0000
# Epoch [55/100], Loss: 1897197.3750
# Epoch [56/100], Loss: 2057239.1250
# Epoch [57/100], Loss: 2859666.2500
# Epoch [58/100], Loss: 2682504.7500
# Epoch [59/100], Loss: 1704541.3750
# Epoch [60/100], Loss: 1219829.1250
# Epoch [61/100], Loss: 1521427.5000
# Epoch [62/100], Loss: 1756373.2500
# Epoch [63/100], Loss: 1419696.2500
# Epoch [64/100], Loss: 943547.0000
# Epoch [65/100], Loss: 851272.8750
# Epoch [66/100], Loss: 1027007.1875
# Epoch [67/100], Loss: 1024798.1250
# Epoch [68/100], Loss: 754861.5000
# Epoch [69/100], Loss: 547958.0000
# Epoch [70/100], Loss: 596583.4375
# Epoch [71/100], Loss: 675151.8125
# Epoch [72/100], Loss: 557449.5000
# Epoch [73/100], Loss: 385480.5000
# Epoch [74/100], Loss: 371758.0000
# Epoch [75/100], Loss: 428771.8438
# Epoch [76/100], Loss: 379183.9375
# Epoch [77/100], Loss: 275880.5000
# Epoch [78/100], Loss: 250885.8750
# Epoch [79/100], Loss: 270235.1562
# Epoch [80/100], Loss: 244868.1094
# Epoch [81/100], Loss: 196168.2344
# Epoch [82/100], Loss: 175564.8125
# Epoch [83/100], Loss: 170113.4688
# Epoch [84/100], Loss: 156072.4219
# Epoch [85/100], Loss: 138227.2969
# Epoch [86/100], Loss: 121487.5859
# Epoch [87/100], Loss: 107681.9844
# Epoch [88/100], Loss: 101472.2188
# Epoch [89/100], Loss: 95475.2344
# Epoch [90/100], Loss: 81612.5938
# Epoch [91/100], Loss: 69945.3984
# Epoch [92/100], Loss: 67459.2266
# Epoch [93/100], Loss: 63769.1797
# Epoch [94/100], Loss: 54237.1055
# Epoch [95/100], Loss: 47035.5508
# Epoch [96/100], Loss: 44532.2227
# Epoch [97/100], Loss: 41653.3633
# Epoch [98/100], Loss: 36737.3086
# Epoch [99/100], Loss: 31724.8027
# Epoch [100/100], Loss: 28741.8340

# %%
# Dự báo cho tập test
# # Chuyển sang chế độ đánh giá
model.eval()

# Không cần tính gradient trong quá trình dự báo
with torch.no_grad():
    input_data_future_test = input_data_train.clone()  # Tạo một bản sao của dữ liệu đầu vào để cập nhật dự báo
    predicted_test = []  # Danh sách dự báo cho các ngày tiếp theo
    for i in range(542):  # Dự báo cho tập test
        # Dự báo cho ngày hiện tại
        output = model(input_data_future_test)
        # Lưu dự báo của ngày hiện tại
        predicted_test.append(output[:, -1, :])  # Lấy dự báo cho ngày cuối cùng trong chuỗi thời gian
        # Cập nhật dữ liệu đầu vào cho ngày tiếp theo
        input_data_future_test = torch.cat([input_data_future_test[:, :, 1:], output], dim=2)

    # In ra dự báo cho tập test
    print("Predicted Output for data test:")
    for i in range(542):
        # In ra ngày tương ứng với dự báo
        print(f"Day {i+1}: {first_data_Date + pd.DateOffset(days=i+1)} - Predicted: {predicted_test[i][0]}")
# Out:
# Predicted Output for data test:
# Day 1: 2022-12-09 00:00:00 - Predicted: tensor([26949.7852])
# Day 2: 2022-12-10 00:00:00 - Predicted: tensor([27010.3535])
# Day 3: 2022-12-11 00:00:00 - Predicted: tensor([27070.4180])
# Day 4: 2022-12-12 00:00:00 - Predicted: tensor([27130.6094])
# Day 5: 2022-12-13 00:00:00 - Predicted: tensor([27190.9316])
# Day 6: 2022-12-14 00:00:00 - Predicted: tensor([27251.3848])
# Day 7: 2022-12-15 00:00:00 - Predicted: tensor([27311.9805])
# Day 8: 2022-12-16 00:00:00 - Predicted: tensor([27372.7070])
# Day 9: 2022-12-17 00:00:00 - Predicted: tensor([27433.5625])
# Day 10: 2022-12-18 00:00:00 - Predicted: tensor([27494.5625])
# Day 11: 2022-12-19 00:00:00 - Predicted: tensor([27555.6953])
# Day 12: 2022-12-20 00:00:00 - Predicted: tensor([27616.9629])
# Day 13: 2022-12-21 00:00:00 - Predicted: tensor([27678.3633])
# Day 14: 2022-12-22 00:00:00 - Predicted: tensor([27739.9023])
# Day 15: 2022-12-23 00:00:00 - Predicted: tensor([27801.5801])
# Day 16: 2022-12-24 00:00:00 - Predicted: tensor([27863.3965])
# Day 17: 2022-12-25 00:00:00 - Predicted: tensor([27925.3496])
# Day 18: 2022-12-26 00:00:00 - Predicted: tensor([27987.4375])
# Day 19: 2022-12-27 00:00:00 - Predicted: tensor([28049.6641])
# Day 20: 2022-12-28 00:00:00 - Predicted: tensor([28112.0332])
# Day 21: 2022-12-29 00:00:00 - Predicted: tensor([28174.5371])
# Day 22: 2022-12-30 00:00:00 - Predicted: tensor([28237.1777])
# Day 23: 2022-12-31 00:00:00 - Predicted: tensor([28299.9609])
# Day 24: 2023-01-01 00:00:00 - Predicted: tensor([28362.8867])
# Day 25: 2023-01-02 00:00:00 - Predicted: tensor([28425.9473])
# Day 26: 2023-01-03 00:00:00 - Predicted: tensor([28489.1484])
# Day 27: 2023-01-04 00:00:00 - Predicted: tensor([28552.4922])
# Day 28: 2023-01-05 00:00:00 - Predicted: tensor([28615.9766])
# Day 29: 2023-01-06 00:00:00 - Predicted: tensor([28679.6016])
# Day 30: 2023-01-07 00:00:00 - Predicted: tensor([28743.3711])
# Day 31: 2023-01-08 00:00:00 - Predicted: tensor([28807.2754])
# Day 32: 2023-01-09 00:00:00 - Predicted: tensor([28871.3262])
# Day 33: 2023-01-10 00:00:00 - Predicted: tensor([28935.5176])
# Day 34: 2023-01-11 00:00:00 - Predicted: tensor([28999.8555])
# Day 35: 2023-01-12 00:00:00 - Predicted: tensor([29064.3340])
# Day 36: 2023-01-13 00:00:00 - Predicted: tensor([29128.9551])
# Day 37: 2023-01-14 00:00:00 - Predicted: tensor([29193.7227])
# Day 38: 2023-01-15 00:00:00 - Predicted: tensor([29258.6328])
# Day 39: 2023-01-16 00:00:00 - Predicted: tensor([29323.6855])
# Day 40: 2023-01-17 00:00:00 - Predicted: tensor([29388.8828])
# Day 41: 2023-01-18 00:00:00 - Predicted: tensor([29454.2266])
# Day 42: 2023-01-19 00:00:00 - Predicted: tensor([29519.7148])
# Day 43: 2023-01-20 00:00:00 - Predicted: tensor([29585.3477])
# Day 44: 2023-01-21 00:00:00 - Predicted: tensor([29651.1289])
# Day 45: 2023-01-22 00:00:00 - Predicted: tensor([29717.0527])
# Day 46: 2023-01-23 00:00:00 - Predicted: tensor([29783.1309])
# Day 47: 2023-01-24 00:00:00 - Predicted: tensor([29849.3496])
# Day 48: 2023-01-25 00:00:00 - Predicted: tensor([29915.7168])
# Day 49: 2023-01-26 00:00:00 - Predicted: tensor([29982.2324])
# Day 50: 2023-01-27 00:00:00 - Predicted: tensor([30048.8945])
# Day 51: 2023-01-28 00:00:00 - Predicted: tensor([30115.7051])
# Day 52: 2023-01-29 00:00:00 - Predicted: tensor([30182.6660])
# Day 53: 2023-01-30 00:00:00 - Predicted: tensor([30249.7734])
# Day 54: 2023-01-31 00:00:00 - Predicted: tensor([30317.0312])
# Day 55: 2023-02-01 00:00:00 - Predicted: tensor([30384.4375])
# Day 56: 2023-02-02 00:00:00 - Predicted: tensor([30451.9980])
# Day 57: 2023-02-03 00:00:00 - Predicted: tensor([30519.7031])
# Day 58: 2023-02-04 00:00:00 - Predicted: tensor([30587.5605])
# Day 59: 2023-02-05 00:00:00 - Predicted: tensor([30655.5703])
# Day 60: 2023-02-06 00:00:00 - Predicted: tensor([30723.7305])
# Day 61: 2023-02-07 00:00:00 - Predicted: tensor([30792.0410])
# Day 62: 2023-02-08 00:00:00 - Predicted: tensor([30860.5059])
# Day 63: 2023-02-09 00:00:00 - Predicted: tensor([30929.1152])
# Day 64: 2023-02-10 00:00:00 - Predicted: tensor([30997.8867])
# Day 65: 2023-02-11 00:00:00 - Predicted: tensor([31066.8105])
# Day 66: 2023-02-12 00:00:00 - Predicted: tensor([31135.8848])
# Day 67: 2023-02-13 00:00:00 - Predicted: tensor([31205.1133])
# Day 68: 2023-02-14 00:00:00 - Predicted: tensor([31274.4922])
# Day 69: 2023-02-15 00:00:00 - Predicted: tensor([31344.0254])
# Day 70: 2023-02-16 00:00:00 - Predicted: tensor([31413.7188])
# Day 71: 2023-02-17 00:00:00 - Predicted: tensor([31483.5664])
# Day 72: 2023-02-18 00:00:00 - Predicted: tensor([31553.5625])
# Day 73: 2023-02-19 00:00:00 - Predicted: tensor([31623.7188])
# Day 74: 2023-02-20 00:00:00 - Predicted: tensor([31694.0332])
# Day 75: 2023-02-21 00:00:00 - Predicted: tensor([31764.5039])
# Day 76: 2023-02-22 00:00:00 - Predicted: tensor([31835.1289])
# Day 77: 2023-02-23 00:00:00 - Predicted: tensor([31905.9121])
# Day 78: 2023-02-24 00:00:00 - Predicted: tensor([31976.8535])
# Day 79: 2023-02-25 00:00:00 - Predicted: tensor([32047.9492])
# Day 80: 2023-02-26 00:00:00 - Predicted: tensor([32119.2051])
# Day 81: 2023-02-27 00:00:00 - Predicted: tensor([32190.6191])
# Day 82: 2023-02-28 00:00:00 - Predicted: tensor([32262.1914])
# Day 83: 2023-03-01 00:00:00 - Predicted: tensor([32333.9199])
# Day 84: 2023-03-02 00:00:00 - Predicted: tensor([32405.8164])
# Day 85: 2023-03-03 00:00:00 - Predicted: tensor([32477.8633])
# Day 86: 2023-03-04 00:00:00 - Predicted: tensor([32550.0742])
# Day 87: 2023-03-05 00:00:00 - Predicted: tensor([32622.4473])
# Day 88: 2023-03-06 00:00:00 - Predicted: tensor([32694.9844])
# Day 89: 2023-03-07 00:00:00 - Predicted: tensor([32767.6797])
# Day 90: 2023-03-08 00:00:00 - Predicted: tensor([32840.5352])
# Day 91: 2023-03-09 00:00:00 - Predicted: tensor([32913.5508])
# Day 92: 2023-03-10 00:00:00 - Predicted: tensor([32986.7305])
# Day 93: 2023-03-11 00:00:00 - Predicted: tensor([33060.0742])
# Day 94: 2023-03-12 00:00:00 - Predicted: tensor([33133.5781])
# Day 95: 2023-03-13 00:00:00 - Predicted: tensor([33207.2500])
# Day 96: 2023-03-14 00:00:00 - Predicted: tensor([33281.0859])
# Day 97: 2023-03-15 00:00:00 - Predicted: tensor([33355.0859])
# Day 98: 2023-03-16 00:00:00 - Predicted: tensor([33429.2461])
# Day 99: 2023-03-17 00:00:00 - Predicted: tensor([33503.5664])
# Day 100: 2023-03-18 00:00:00 - Predicted: tensor([33578.0625])
# Day 101: 2023-03-19 00:00:00 - Predicted: tensor([33652.7266])
# Day 102: 2023-03-20 00:00:00 - Predicted: tensor([33727.5430])
# Day 103: 2023-03-21 00:00:00 - Predicted: tensor([33802.5352])
# Day 104: 2023-03-22 00:00:00 - Predicted: tensor([33877.6875])
# Day 105: 2023-03-23 00:00:00 - Predicted: tensor([33953.0156])
# Day 106: 2023-03-24 00:00:00 - Predicted: tensor([34028.5078])
# Day 107: 2023-03-25 00:00:00 - Predicted: tensor([34104.1641])
# Day 108: 2023-03-26 00:00:00 - Predicted: tensor([34179.9961])
# Day 109: 2023-03-27 00:00:00 - Predicted: tensor([34255.9922])
# Day 110: 2023-03-28 00:00:00 - Predicted: tensor([34332.1602])
# Day 111: 2023-03-29 00:00:00 - Predicted: tensor([34408.4883])
# Day 112: 2023-03-30 00:00:00 - Predicted: tensor([34484.9961])
# Day 113: 2023-03-31 00:00:00 - Predicted: tensor([34561.6680])
# Day 114: 2023-04-01 00:00:00 - Predicted: tensor([34638.5117])
# Day 115: 2023-04-02 00:00:00 - Predicted: tensor([34715.5273])
# Day 116: 2023-04-03 00:00:00 - Predicted: tensor([34792.7148])
# Day 117: 2023-04-04 00:00:00 - Predicted: tensor([34870.0742])
# Day 118: 2023-04-05 00:00:00 - Predicted: tensor([34947.6055])
# Day 119: 2023-04-06 00:00:00 - Predicted: tensor([35025.3008])
# Day 120: 2023-04-07 00:00:00 - Predicted: tensor([35103.1797])
# Day 121: 2023-04-08 00:00:00 - Predicted: tensor([35181.2266])
# Day 122: 2023-04-09 00:00:00 - Predicted: tensor([35259.4531])
# Day 123: 2023-04-10 00:00:00 - Predicted: tensor([35337.8438])
# Day 124: 2023-04-11 00:00:00 - Predicted: tensor([35416.4219])
# Day 125: 2023-04-12 00:00:00 - Predicted: tensor([35495.1641])
# Day 126: 2023-04-13 00:00:00 - Predicted: tensor([35574.0859])
# Day 127: 2023-04-14 00:00:00 - Predicted: tensor([35653.1836])
# Day 128: 2023-04-15 00:00:00 - Predicted: tensor([35732.4531])
# Day 129: 2023-04-16 00:00:00 - Predicted: tensor([35811.8984])
# Day 130: 2023-04-17 00:00:00 - Predicted: tensor([35891.5273])
# Day 131: 2023-04-18 00:00:00 - Predicted: tensor([35971.3242])
# Day 132: 2023-04-19 00:00:00 - Predicted: tensor([36051.3047])
# Day 133: 2023-04-20 00:00:00 - Predicted: tensor([36131.4570])
# Day 134: 2023-04-21 00:00:00 - Predicted: tensor([36211.7969])
# Day 135: 2023-04-22 00:00:00 - Predicted: tensor([36292.3086])
# Day 136: 2023-04-23 00:00:00 - Predicted: tensor([36373.])
# Day 137: 2023-04-24 00:00:00 - Predicted: tensor([36453.8789])
# Day 138: 2023-04-25 00:00:00 - Predicted: tensor([36534.9258])
# Day 139: 2023-04-26 00:00:00 - Predicted: tensor([36616.1602])
# Day 140: 2023-04-27 00:00:00 - Predicted: tensor([36697.5703])
# Day 141: 2023-04-28 00:00:00 - Predicted: tensor([36779.1680])
# Day 142: 2023-04-29 00:00:00 - Predicted: tensor([36860.9414])
# Day 143: 2023-04-30 00:00:00 - Predicted: tensor([36942.8984])
# Day 144: 2023-05-01 00:00:00 - Predicted: tensor([37025.0391])
# Day 145: 2023-05-02 00:00:00 - Predicted: tensor([37107.3555])
# Day 146: 2023-05-03 00:00:00 - Predicted: tensor([37189.8633])
# Day 147: 2023-05-04 00:00:00 - Predicted: tensor([37272.5547])
# Day 148: 2023-05-05 00:00:00 - Predicted: tensor([37355.4258])
# Day 149: 2023-05-06 00:00:00 - Predicted: tensor([37438.4844])
# Day 150: 2023-05-07 00:00:00 - Predicted: tensor([37521.7227])
# Day 151: 2023-05-08 00:00:00 - Predicted: tensor([37605.1445])
# Day 152: 2023-05-09 00:00:00 - Predicted: tensor([37688.7578])
# Day 153: 2023-05-10 00:00:00 - Predicted: tensor([37772.5508])
# Day 154: 2023-05-11 00:00:00 - Predicted: tensor([37856.5352])
# Day 155: 2023-05-12 00:00:00 - Predicted: tensor([37940.7070])
# Day 156: 2023-05-13 00:00:00 - Predicted: tensor([38025.0664])
# Day 157: 2023-05-14 00:00:00 - Predicted: tensor([38109.6133])
# Day 158: 2023-05-15 00:00:00 - Predicted: tensor([38194.3516])
# Day 159: 2023-05-16 00:00:00 - Predicted: tensor([38279.2656])
# Day 160: 2023-05-17 00:00:00 - Predicted: tensor([38364.3789])
# Day 161: 2023-05-18 00:00:00 - Predicted: tensor([38449.6797])
# Day 162: 2023-05-19 00:00:00 - Predicted: tensor([38535.1641])
# Day 163: 2023-05-20 00:00:00 - Predicted: tensor([38620.8438])
# Day 164: 2023-05-21 00:00:00 - Predicted: tensor([38706.7148])
# Day 165: 2023-05-22 00:00:00 - Predicted: tensor([38792.7695])
# Day 166: 2023-05-23 00:00:00 - Predicted: tensor([38879.0312])
# Day 167: 2023-05-24 00:00:00 - Predicted: tensor([38965.4648])
# Day 168: 2023-05-25 00:00:00 - Predicted: tensor([39052.1094])
# Day 169: 2023-05-26 00:00:00 - Predicted: tensor([39138.9336])
# Day 170: 2023-05-27 00:00:00 - Predicted: tensor([39225.9570])
# Day 171: 2023-05-28 00:00:00 - Predicted: tensor([39313.1758])
# Day 172: 2023-05-29 00:00:00 - Predicted: tensor([39400.5859])
# Day 173: 2023-05-30 00:00:00 - Predicted: tensor([39488.1836])
# Day 174: 2023-05-31 00:00:00 - Predicted: tensor([39575.9805])
# Day 175: 2023-06-01 00:00:00 - Predicted: tensor([39663.9844])
# Day 176: 2023-06-02 00:00:00 - Predicted: tensor([39752.1641])
# Day 177: 2023-06-03 00:00:00 - Predicted: tensor([39840.5547])
# Day 178: 2023-06-04 00:00:00 - Predicted: tensor([39929.1367])
# Day 179: 2023-06-05 00:00:00 - Predicted: tensor([40017.9141])
# Day 180: 2023-06-06 00:00:00 - Predicted: tensor([40106.8906])
# Day 181: 2023-06-07 00:00:00 - Predicted: tensor([40196.0664])
# Day 182: 2023-06-08 00:00:00 - Predicted: tensor([40285.4375])
# Day 183: 2023-06-09 00:00:00 - Predicted: tensor([40375.0078])
# Day 184: 2023-06-10 00:00:00 - Predicted: tensor([40464.7734])
# Day 185: 2023-06-11 00:00:00 - Predicted: tensor([40554.7422])
# Day 186: 2023-06-12 00:00:00 - Predicted: tensor([40644.9180])
# Day 187: 2023-06-13 00:00:00 - Predicted: tensor([40735.2812])
# Day 188: 2023-06-14 00:00:00 - Predicted: tensor([40825.8594])
# Day 189: 2023-06-15 00:00:00 - Predicted: tensor([40916.6289])
# Day 190: 2023-06-16 00:00:00 - Predicted: tensor([41007.6016])
# Day 191: 2023-06-17 00:00:00 - Predicted: tensor([41098.7773])
# Day 192: 2023-06-18 00:00:00 - Predicted: tensor([41190.1602])
# Day 193: 2023-06-19 00:00:00 - Predicted: tensor([41281.7383])
# Day 194: 2023-06-20 00:00:00 - Predicted: tensor([41373.5273])
# Day 195: 2023-06-21 00:00:00 - Predicted: tensor([41465.5234])
# Day 196: 2023-06-22 00:00:00 - Predicted: tensor([41557.7109])
# Day 197: 2023-06-23 00:00:00 - Predicted: tensor([41650.1133])
# Day 198: 2023-06-24 00:00:00 - Predicted: tensor([41742.7188])
# Day 199: 2023-06-25 00:00:00 - Predicted: tensor([41835.5352])
# Day 200: 2023-06-26 00:00:00 - Predicted: tensor([41928.5469])
# Day 201: 2023-06-27 00:00:00 - Predicted: tensor([42021.7695])
# Day 202: 2023-06-28 00:00:00 - Predicted: tensor([42115.2031])
# Day 203: 2023-06-29 00:00:00 - Predicted: tensor([42208.8477])
# Day 204: 2023-06-30 00:00:00 - Predicted: tensor([42302.6953])
# Day 205: 2023-07-01 00:00:00 - Predicted: tensor([42396.7500])
# Day 206: 2023-07-02 00:00:00 - Predicted: tensor([42491.0117])
# Day 207: 2023-07-03 00:00:00 - Predicted: tensor([42585.4883])
# Day 208: 2023-07-04 00:00:00 - Predicted: tensor([42680.1758])
# Day 209: 2023-07-05 00:00:00 - Predicted: tensor([42775.0664])
# Day 210: 2023-07-06 00:00:00 - Predicted: tensor([42870.1797])
# Day 211: 2023-07-07 00:00:00 - Predicted: tensor([42965.4922])
# Day 212: 2023-07-08 00:00:00 - Predicted: tensor([43061.0234])
# Day 213: 2023-07-09 00:00:00 - Predicted: tensor([43156.7578])
# Day 214: 2023-07-10 00:00:00 - Predicted: tensor([43252.7188])
# Day 215: 2023-07-11 00:00:00 - Predicted: tensor([43348.8906])
# Day 216: 2023-07-12 00:00:00 - Predicted: tensor([43445.2734])
# Day 217: 2023-07-13 00:00:00 - Predicted: tensor([43541.8633])
# Day 218: 2023-07-14 00:00:00 - Predicted: tensor([43638.6758])
# Day 219: 2023-07-15 00:00:00 - Predicted: tensor([43735.7031])
# Day 220: 2023-07-16 00:00:00 - Predicted: tensor([43832.9414])
# Day 221: 2023-07-17 00:00:00 - Predicted: tensor([43930.4062])
# Day 222: 2023-07-18 00:00:00 - Predicted: tensor([44028.0781])
# Day 223: 2023-07-19 00:00:00 - Predicted: tensor([44125.9688])
# Day 224: 2023-07-20 00:00:00 - Predicted: tensor([44224.0859])
# Day 225: 2023-07-21 00:00:00 - Predicted: tensor([44322.4141])
# Day 226: 2023-07-22 00:00:00 - Predicted: tensor([44420.9531])
# Day 227: 2023-07-23 00:00:00 - Predicted: tensor([44519.7148])
# Day 228: 2023-07-24 00:00:00 - Predicted: tensor([44618.7070])
# Day 229: 2023-07-25 00:00:00 - Predicted: tensor([44717.9141])
# Day 230: 2023-07-26 00:00:00 - Predicted: tensor([44817.3438])
# Day 231: 2023-07-27 00:00:00 - Predicted: tensor([44916.9844])
# Day 232: 2023-07-28 00:00:00 - Predicted: tensor([45016.8555])
# Day 233: 2023-07-29 00:00:00 - Predicted: tensor([45116.9492])
# Day 234: 2023-07-30 00:00:00 - Predicted: tensor([45217.2617])
# Day 235: 2023-07-31 00:00:00 - Predicted: tensor([45317.7969])
# Day 236: 2023-08-01 00:00:00 - Predicted: tensor([45418.5547])
# Day 237: 2023-08-02 00:00:00 - Predicted: tensor([45519.5430])
# Day 238: 2023-08-03 00:00:00 - Predicted: tensor([45620.7500])
# Day 239: 2023-08-04 00:00:00 - Predicted: tensor([45722.1836])
# Day 240: 2023-08-05 00:00:00 - Predicted: tensor([45823.8438])
# Day 241: 2023-08-06 00:00:00 - Predicted: tensor([45925.7266])
# Day 242: 2023-08-07 00:00:00 - Predicted: tensor([46027.8398])
# Day 243: 2023-08-08 00:00:00 - Predicted: tensor([46130.1836])
# Day 244: 2023-08-09 00:00:00 - Predicted: tensor([46232.7422])
# Day 245: 2023-08-10 00:00:00 - Predicted: tensor([46335.5352])
# Day 246: 2023-08-11 00:00:00 - Predicted: tensor([46438.5586])
# Day 247: 2023-08-12 00:00:00 - Predicted: tensor([46541.8125])
# Day 248: 2023-08-13 00:00:00 - Predicted: tensor([46645.2969])
# Day 249: 2023-08-14 00:00:00 - Predicted: tensor([46749.])
# Day 250: 2023-08-15 00:00:00 - Predicted: tensor([46852.9453])
# Day 251: 2023-08-16 00:00:00 - Predicted: tensor([46957.1211])
# Day 252: 2023-08-17 00:00:00 - Predicted: tensor([47061.5234])
# Day 253: 2023-08-18 00:00:00 - Predicted: tensor([47166.1602])
# Day 254: 2023-08-19 00:00:00 - Predicted: tensor([47271.0273])
# Day 255: 2023-08-20 00:00:00 - Predicted: tensor([47376.1289])
# Day 256: 2023-08-21 00:00:00 - Predicted: tensor([47481.4727])
# Day 257: 2023-08-22 00:00:00 - Predicted: tensor([47587.0352])
# Day 258: 2023-08-23 00:00:00 - Predicted: tensor([47692.8398])
# Day 259: 2023-08-24 00:00:00 - Predicted: tensor([47798.8867])
# Day 260: 2023-08-25 00:00:00 - Predicted: tensor([47905.1602])
# Day 261: 2023-08-26 00:00:00 - Predicted: tensor([48011.6719])
# Day 262: 2023-08-27 00:00:00 - Predicted: tensor([48118.4219])
# Day 263: 2023-08-28 00:00:00 - Predicted: tensor([48225.4141])
# Day 264: 2023-08-29 00:00:00 - Predicted: tensor([48332.6367])
# Day 265: 2023-08-30 00:00:00 - Predicted: tensor([48440.0977])
# Day 266: 2023-08-31 00:00:00 - Predicted: tensor([48547.8086])
# Day 267: 2023-09-01 00:00:00 - Predicted: tensor([48655.7461])
# Day 268: 2023-09-02 00:00:00 - Predicted: tensor([48763.9258])
# Day 269: 2023-09-03 00:00:00 - Predicted: tensor([48872.3477])
# Day 270: 2023-09-04 00:00:00 - Predicted: tensor([48981.0078])
# Day 271: 2023-09-05 00:00:00 - Predicted: tensor([49089.9102])
# Day 272: 2023-09-06 00:00:00 - Predicted: tensor([49199.0586])
# Day 273: 2023-09-07 00:00:00 - Predicted: tensor([49308.4531])
# Day 274: 2023-09-08 00:00:00 - Predicted: tensor([49418.0820])
# Day 275: 2023-09-09 00:00:00 - Predicted: tensor([49527.9609])
# Day 276: 2023-09-10 00:00:00 - Predicted: tensor([49638.0820])
# Day 277: 2023-09-11 00:00:00 - Predicted: tensor([49748.4492])
# Day 278: 2023-09-12 00:00:00 - Predicted: tensor([49859.0547])
# Day 279: 2023-09-13 00:00:00 - Predicted: tensor([49969.9141])
# Day 280: 2023-09-14 00:00:00 - Predicted: tensor([50081.0195])
# Day 281: 2023-09-15 00:00:00 - Predicted: tensor([50192.3711])
# Day 282: 2023-09-16 00:00:00 - Predicted: tensor([50303.9648])
# Day 283: 2023-09-17 00:00:00 - Predicted: tensor([50415.8164])
# Day 284: 2023-09-18 00:00:00 - Predicted: tensor([50527.9062])
# Day 285: 2023-09-19 00:00:00 - Predicted: tensor([50640.2539])
# Day 286: 2023-09-20 00:00:00 - Predicted: tensor([50752.8477])
# Day 287: 2023-09-21 00:00:00 - Predicted: tensor([50865.6914])
# Day 288: 2023-09-22 00:00:00 - Predicted: tensor([50978.7891])
# Day 289: 2023-09-23 00:00:00 - Predicted: tensor([51092.1289])
# Day 290: 2023-09-24 00:00:00 - Predicted: tensor([51205.7266])
# Day 291: 2023-09-25 00:00:00 - Predicted: tensor([51319.5859])
# Day 292: 2023-09-26 00:00:00 - Predicted: tensor([51433.6875])
# Day 293: 2023-09-27 00:00:00 - Predicted: tensor([51548.0430])
# Day 294: 2023-09-28 00:00:00 - Predicted: tensor([51662.6562])
# Day 295: 2023-09-29 00:00:00 - Predicted: tensor([51777.5195])
# Day 296: 2023-09-30 00:00:00 - Predicted: tensor([51892.6445])
# Day 297: 2023-10-01 00:00:00 - Predicted: tensor([52008.0234])
# Day 298: 2023-10-02 00:00:00 - Predicted: tensor([52123.6641])
# Day 299: 2023-10-03 00:00:00 - Predicted: tensor([52239.5547])
# Day 300: 2023-10-04 00:00:00 - Predicted: tensor([52355.7031])
# Day 301: 2023-10-05 00:00:00 - Predicted: tensor([52472.1094])
# Day 302: 2023-10-06 00:00:00 - Predicted: tensor([52588.7812])
# Day 303: 2023-10-07 00:00:00 - Predicted: tensor([52705.7031])
# Day 304: 2023-10-08 00:00:00 - Predicted: tensor([52822.8906])
# Day 305: 2023-10-09 00:00:00 - Predicted: tensor([52940.3359])
# Day 306: 2023-10-10 00:00:00 - Predicted: tensor([53058.0469])
# Day 307: 2023-10-11 00:00:00 - Predicted: tensor([53176.0117])
# Day 308: 2023-10-12 00:00:00 - Predicted: tensor([53294.2461])
# Day 309: 2023-10-13 00:00:00 - Predicted: tensor([53412.7383])
# Day 310: 2023-10-14 00:00:00 - Predicted: tensor([53531.4961])
# Day 311: 2023-10-15 00:00:00 - Predicted: tensor([53650.5156])
# Day 312: 2023-10-16 00:00:00 - Predicted: tensor([53769.8047])
# Day 313: 2023-10-17 00:00:00 - Predicted: tensor([53889.3633])
# Day 314: 2023-10-18 00:00:00 - Predicted: tensor([54009.1719])
# Day 315: 2023-10-19 00:00:00 - Predicted: tensor([54129.2578])
# Day 316: 2023-10-20 00:00:00 - Predicted: tensor([54249.6172])
# Day 317: 2023-10-21 00:00:00 - Predicted: tensor([54370.2266])
# Day 318: 2023-10-22 00:00:00 - Predicted: tensor([54491.1172])
# Day 319: 2023-10-23 00:00:00 - Predicted: tensor([54612.2734])
# Day 320: 2023-10-24 00:00:00 - Predicted: tensor([54733.6992])
# Day 321: 2023-10-25 00:00:00 - Predicted: tensor([54855.3984])
# Day 322: 2023-10-26 00:00:00 - Predicted: tensor([54977.3594])
# Day 323: 2023-10-27 00:00:00 - Predicted: tensor([55099.5938])
# Day 324: 2023-10-28 00:00:00 - Predicted: tensor([55222.1055])
# Day 325: 2023-10-29 00:00:00 - Predicted: tensor([55344.8867])
# Day 326: 2023-10-30 00:00:00 - Predicted: tensor([55467.9375])
# Day 327: 2023-10-31 00:00:00 - Predicted: tensor([55591.2695])
# Day 328: 2023-11-01 00:00:00 - Predicted: tensor([55714.8711])
# Day 329: 2023-11-02 00:00:00 - Predicted: tensor([55838.7500])
# Day 330: 2023-11-03 00:00:00 - Predicted: tensor([55962.9023])
# Day 331: 2023-11-04 00:00:00 - Predicted: tensor([56087.3242])
# Day 332: 2023-11-05 00:00:00 - Predicted: tensor([56212.0312])
# Day 333: 2023-11-06 00:00:00 - Predicted: tensor([56337.0195])
# Day 334: 2023-11-07 00:00:00 - Predicted: tensor([56462.2734])
# Day 335: 2023-11-08 00:00:00 - Predicted: tensor([56587.8164])
# Day 336: 2023-11-09 00:00:00 - Predicted: tensor([56713.6328])
# Day 337: 2023-11-10 00:00:00 - Predicted: tensor([56839.7266])
# Day 338: 2023-11-11 00:00:00 - Predicted: tensor([56966.1133])
# Day 339: 2023-11-12 00:00:00 - Predicted: tensor([57092.7656])
# Day 340: 2023-11-13 00:00:00 - Predicted: tensor([57219.7031])
# Day 341: 2023-11-14 00:00:00 - Predicted: tensor([57346.9297])
# Day 342: 2023-11-15 00:00:00 - Predicted: tensor([57474.4414])
# Day 343: 2023-11-16 00:00:00 - Predicted: tensor([57602.2227])
# Day 344: 2023-11-17 00:00:00 - Predicted: tensor([57730.2969])
# Day 345: 2023-11-18 00:00:00 - Predicted: tensor([57858.6562])
# Day 346: 2023-11-19 00:00:00 - Predicted: tensor([57987.3047])
# Day 347: 2023-11-20 00:00:00 - Predicted: tensor([58116.2305])
# Day 348: 2023-11-21 00:00:00 - Predicted: tensor([58245.4414])
# Day 349: 2023-11-22 00:00:00 - Predicted: tensor([58374.9414])
# Day 350: 2023-11-23 00:00:00 - Predicted: tensor([58504.7383])
# Day 351: 2023-11-24 00:00:00 - Predicted: tensor([58634.8164])
# Day 352: 2023-11-25 00:00:00 - Predicted: tensor([58765.1875])
# Day 353: 2023-11-26 00:00:00 - Predicted: tensor([58895.8477])
# Day 354: 2023-11-27 00:00:00 - Predicted: tensor([59026.7969])
# Day 355: 2023-11-28 00:00:00 - Predicted: tensor([59158.0312])
# Day 356: 2023-11-29 00:00:00 - Predicted: tensor([59289.5664])
# Day 357: 2023-11-30 00:00:00 - Predicted: tensor([59421.3984])
# Day 358: 2023-12-01 00:00:00 - Predicted: tensor([59553.5195])
# Day 359: 2023-12-02 00:00:00 - Predicted: tensor([59685.9219])
# Day 360: 2023-12-03 00:00:00 - Predicted: tensor([59818.6250])
# Day 361: 2023-12-04 00:00:00 - Predicted: tensor([59951.6328])
# Day 362: 2023-12-05 00:00:00 - Predicted: tensor([60084.9297])
# Day 363: 2023-12-06 00:00:00 - Predicted: tensor([60218.5156])
# Day 364: 2023-12-07 00:00:00 - Predicted: tensor([60352.4141])
# Day 365: 2023-12-08 00:00:00 - Predicted: tensor([60486.5977])
# Day 366: 2023-12-09 00:00:00 - Predicted: tensor([60621.0781])
# Day 367: 2023-12-10 00:00:00 - Predicted: tensor([60755.8750])
# Day 368: 2023-12-11 00:00:00 - Predicted: tensor([60890.9492])
# Day 369: 2023-12-12 00:00:00 - Predicted: tensor([61026.3359])
# Day 370: 2023-12-13 00:00:00 - Predicted: tensor([61162.0234])
# Day 371: 2023-12-14 00:00:00 - Predicted: tensor([61298.0117])
# Day 372: 2023-12-15 00:00:00 - Predicted: tensor([61434.3047])
# Day 373: 2023-12-16 00:00:00 - Predicted: tensor([61570.8984])
# Day 374: 2023-12-17 00:00:00 - Predicted: tensor([61707.8008])
# Day 375: 2023-12-18 00:00:00 - Predicted: tensor([61844.9961])
# Day 376: 2023-12-19 00:00:00 - Predicted: tensor([61982.5078])
# Day 377: 2023-12-20 00:00:00 - Predicted: tensor([62120.3164])
# Day 378: 2023-12-21 00:00:00 - Predicted: tensor([62258.4414])
# Day 379: 2023-12-22 00:00:00 - Predicted: tensor([62396.8633])
# Day 380: 2023-12-23 00:00:00 - Predicted: tensor([62535.6055])
# Day 381: 2023-12-24 00:00:00 - Predicted: tensor([62674.6289])
# Day 382: 2023-12-25 00:00:00 - Predicted: tensor([62813.9805])
# Day 383: 2023-12-26 00:00:00 - Predicted: tensor([62953.6523])
# Day 384: 2023-12-27 00:00:00 - Predicted: tensor([63093.6211])
# Day 385: 2023-12-28 00:00:00 - Predicted: tensor([63233.9062])
# Day 386: 2023-12-29 00:00:00 - Predicted: tensor([63374.4961])
# Day 387: 2023-12-30 00:00:00 - Predicted: tensor([63515.4102])
# Day 388: 2023-12-31 00:00:00 - Predicted: tensor([63656.6328])
# Day 389: 2024-01-01 00:00:00 - Predicted: tensor([63798.1562])
# Day 390: 2024-01-02 00:00:00 - Predicted: tensor([63940.0078])
# Day 391: 2024-01-03 00:00:00 - Predicted: tensor([64082.1680])
# Day 392: 2024-01-04 00:00:00 - Predicted: tensor([64224.6484])
# Day 393: 2024-01-05 00:00:00 - Predicted: tensor([64367.4492])
# Day 394: 2024-01-06 00:00:00 - Predicted: tensor([64510.5625])
# Day 395: 2024-01-07 00:00:00 - Predicted: tensor([64654.])
# Day 396: 2024-01-08 00:00:00 - Predicted: tensor([64797.7500])
# Day 397: 2024-01-09 00:00:00 - Predicted: tensor([64941.8203])
# Day 398: 2024-01-10 00:00:00 - Predicted: tensor([65086.2148])
# Day 399: 2024-01-11 00:00:00 - Predicted: tensor([65230.9297])
# Day 400: 2024-01-12 00:00:00 - Predicted: tensor([65375.9648])
# Day 401: 2024-01-13 00:00:00 - Predicted: tensor([65521.3242])
# Day 402: 2024-01-14 00:00:00 - Predicted: tensor([65667.])
# Day 403: 2024-01-15 00:00:00 - Predicted: tensor([65813.])
# Day 404: 2024-01-16 00:00:00 - Predicted: tensor([65959.3359])
# Day 405: 2024-01-17 00:00:00 - Predicted: tensor([66106.])
# Day 406: 2024-01-18 00:00:00 - Predicted: tensor([66252.9609])
# Day 407: 2024-01-19 00:00:00 - Predicted: tensor([66400.2812])
# Day 408: 2024-01-20 00:00:00 - Predicted: tensor([66547.9141])
# Day 409: 2024-01-21 00:00:00 - Predicted: tensor([66695.8828])
# Day 410: 2024-01-22 00:00:00 - Predicted: tensor([66844.1719])
# Day 411: 2024-01-23 00:00:00 - Predicted: tensor([66992.7812])
# Day 412: 2024-01-24 00:00:00 - Predicted: tensor([67141.7422])
# Day 413: 2024-01-25 00:00:00 - Predicted: tensor([67291.0234])
# Day 414: 2024-01-26 00:00:00 - Predicted: tensor([67440.6328])
# Day 415: 2024-01-27 00:00:00 - Predicted: tensor([67590.5781])
# Day 416: 2024-01-28 00:00:00 - Predicted: tensor([67740.8594])
# Day 417: 2024-01-29 00:00:00 - Predicted: tensor([67891.4844])
# Day 418: 2024-01-30 00:00:00 - Predicted: tensor([68042.4375])
# Day 419: 2024-01-31 00:00:00 - Predicted: tensor([68193.7188])
# Day 420: 2024-02-01 00:00:00 - Predicted: tensor([68345.3438])
# Day 421: 2024-02-02 00:00:00 - Predicted: tensor([68497.3047])
# Day 422: 2024-02-03 00:00:00 - Predicted: tensor([68649.6016])
# Day 423: 2024-02-04 00:00:00 - Predicted: tensor([68802.2266])
# Day 424: 2024-02-05 00:00:00 - Predicted: tensor([68955.2031])
# Day 425: 2024-02-06 00:00:00 - Predicted: tensor([69108.5234])
# Day 426: 2024-02-07 00:00:00 - Predicted: tensor([69262.1875])
# Day 427: 2024-02-08 00:00:00 - Predicted: tensor([69416.1719])
# Day 428: 2024-02-09 00:00:00 - Predicted: tensor([69570.5156])
# Day 429: 2024-02-10 00:00:00 - Predicted: tensor([69725.2031])
# Day 430: 2024-02-11 00:00:00 - Predicted: tensor([69880.2344])
# Day 431: 2024-02-12 00:00:00 - Predicted: tensor([70035.5938])
# Day 432: 2024-02-13 00:00:00 - Predicted: tensor([70191.3203])
# Day 433: 2024-02-14 00:00:00 - Predicted: tensor([70347.3828])
# Day 434: 2024-02-15 00:00:00 - Predicted: tensor([70503.7969])
# Day 435: 2024-02-16 00:00:00 - Predicted: tensor([70660.5469])
# Day 436: 2024-02-17 00:00:00 - Predicted: tensor([70817.6641])
# Day 437: 2024-02-18 00:00:00 - Predicted: tensor([70975.1094])
# Day 438: 2024-02-19 00:00:00 - Predicted: tensor([71132.9219])
# Day 439: 2024-02-20 00:00:00 - Predicted: tensor([71291.0859])
# Day 440: 2024-02-21 00:00:00 - Predicted: tensor([71449.5938])
# Day 441: 2024-02-22 00:00:00 - Predicted: tensor([71608.4453])
# Day 442: 2024-02-23 00:00:00 - Predicted: tensor([71767.6641])
# Day 443: 2024-02-24 00:00:00 - Predicted: tensor([71927.2344])
# Day 444: 2024-02-25 00:00:00 - Predicted: tensor([72087.1562])
# Day 445: 2024-02-26 00:00:00 - Predicted: tensor([72247.4375])
# Day 446: 2024-02-27 00:00:00 - Predicted: tensor([72408.0859])
# Day 447: 2024-02-28 00:00:00 - Predicted: tensor([72569.0625])
# Day 448: 2024-02-29 00:00:00 - Predicted: tensor([72730.4141])
# Day 449: 2024-03-01 00:00:00 - Predicted: tensor([72892.1250])
# Day 450: 2024-03-02 00:00:00 - Predicted: tensor([73054.1875])
# Day 451: 2024-03-03 00:00:00 - Predicted: tensor([73216.6250])
# Day 452: 2024-03-04 00:00:00 - Predicted: tensor([73379.4141])
# Day 453: 2024-03-05 00:00:00 - Predicted: tensor([73542.5625])
# Day 454: 2024-03-06 00:00:00 - Predicted: tensor([73706.0781])
# Day 455: 2024-03-07 00:00:00 - Predicted: tensor([73869.9688])
# Day 456: 2024-03-08 00:00:00 - Predicted: tensor([74034.2031])
# Day 457: 2024-03-09 00:00:00 - Predicted: tensor([74198.8125])
# Day 458: 2024-03-10 00:00:00 - Predicted: tensor([74363.7812])
# Day 459: 2024-03-11 00:00:00 - Predicted: tensor([74529.1250])
# Day 460: 2024-03-12 00:00:00 - Predicted: tensor([74694.8203])
# Day 461: 2024-03-13 00:00:00 - Predicted: tensor([74860.9062])
# Day 462: 2024-03-14 00:00:00 - Predicted: tensor([75027.3516])
# Day 463: 2024-03-15 00:00:00 - Predicted: tensor([75194.1719])
# Day 464: 2024-03-16 00:00:00 - Predicted: tensor([75361.3594])
# Day 465: 2024-03-17 00:00:00 - Predicted: tensor([75528.9141])
# Day 466: 2024-03-18 00:00:00 - Predicted: tensor([75696.8516])
# Day 467: 2024-03-19 00:00:00 - Predicted: tensor([75865.1484])
# Day 468: 2024-03-20 00:00:00 - Predicted: tensor([76033.8281])
# Day 469: 2024-03-21 00:00:00 - Predicted: tensor([76202.8750])
# Day 470: 2024-03-22 00:00:00 - Predicted: tensor([76372.3203])
# Day 471: 2024-03-23 00:00:00 - Predicted: tensor([76542.1250])
# Day 472: 2024-03-24 00:00:00 - Predicted: tensor([76712.3047])
# Day 473: 2024-03-25 00:00:00 - Predicted: tensor([76882.8750])
# Day 474: 2024-03-26 00:00:00 - Predicted: tensor([77053.8125])
# Day 475: 2024-03-27 00:00:00 - Predicted: tensor([77225.1406])
# Day 476: 2024-03-28 00:00:00 - Predicted: tensor([77396.8359])
# Day 477: 2024-03-29 00:00:00 - Predicted: tensor([77568.9141])
# Day 478: 2024-03-30 00:00:00 - Predicted: tensor([77741.3906])
# Day 479: 2024-03-31 00:00:00 - Predicted: tensor([77914.2344])
# Day 480: 2024-04-01 00:00:00 - Predicted: tensor([78087.4688])
# Day 481: 2024-04-02 00:00:00 - Predicted: tensor([78261.1016])
# Day 482: 2024-04-03 00:00:00 - Predicted: tensor([78435.1016])
# Day 483: 2024-04-04 00:00:00 - Predicted: tensor([78609.4922])
# Day 484: 2024-04-05 00:00:00 - Predicted: tensor([78784.2656])
# Day 485: 2024-04-06 00:00:00 - Predicted: tensor([78959.4375])
# Day 486: 2024-04-07 00:00:00 - Predicted: tensor([79135.])
# Day 487: 2024-04-08 00:00:00 - Predicted: tensor([79310.9531])
# Day 488: 2024-04-09 00:00:00 - Predicted: tensor([79487.2969])
# Day 489: 2024-04-10 00:00:00 - Predicted: tensor([79664.0234])
# Day 490: 2024-04-11 00:00:00 - Predicted: tensor([79841.1641])
# Day 491: 2024-04-12 00:00:00 - Predicted: tensor([80018.6641])
# Day 492: 2024-04-13 00:00:00 - Predicted: tensor([80196.5781])
# Day 493: 2024-04-14 00:00:00 - Predicted: tensor([80374.8984])
# Day 494: 2024-04-15 00:00:00 - Predicted: tensor([80553.6094])
# Day 495: 2024-04-16 00:00:00 - Predicted: tensor([80732.6953])
# Day 496: 2024-04-17 00:00:00 - Predicted: tensor([80912.2031])
# Day 497: 2024-04-18 00:00:00 - Predicted: tensor([81092.1016])
# Day 498: 2024-04-19 00:00:00 - Predicted: tensor([81272.3984])
# Day 499: 2024-04-20 00:00:00 - Predicted: tensor([81453.1172])
# Day 500: 2024-04-21 00:00:00 - Predicted: tensor([81634.2109])
# Day 501: 2024-04-22 00:00:00 - Predicted: tensor([81815.7031])
# Day 502: 2024-04-23 00:00:00 - Predicted: tensor([81997.6172])
# Day 503: 2024-04-24 00:00:00 - Predicted: tensor([82179.9375])
# Day 504: 2024-04-25 00:00:00 - Predicted: tensor([82362.6641])
# Day 505: 2024-04-26 00:00:00 - Predicted: tensor([82545.7812])
# Day 506: 2024-04-27 00:00:00 - Predicted: tensor([82729.3125])
# Day 507: 2024-04-28 00:00:00 - Predicted: tensor([82913.2656])
# Day 508: 2024-04-29 00:00:00 - Predicted: tensor([83097.6094])
# Day 509: 2024-04-30 00:00:00 - Predicted: tensor([83282.3594])
# Day 510: 2024-05-01 00:00:00 - Predicted: tensor([83467.5391])
# Day 511: 2024-05-02 00:00:00 - Predicted: tensor([83653.1328])
# Day 512: 2024-05-03 00:00:00 - Predicted: tensor([83839.1172])
# Day 513: 2024-05-04 00:00:00 - Predicted: tensor([84025.5234])
# Day 514: 2024-05-05 00:00:00 - Predicted: tensor([84212.3516])
# Day 515: 2024-05-06 00:00:00 - Predicted: tensor([84399.5938])
# Day 516: 2024-05-07 00:00:00 - Predicted: tensor([84587.2578])
# Day 517: 2024-05-08 00:00:00 - Predicted: tensor([84775.3203])
# Day 518: 2024-05-09 00:00:00 - Predicted: tensor([84963.7969])
# Day 519: 2024-05-10 00:00:00 - Predicted: tensor([85152.7031])
# Day 520: 2024-05-11 00:00:00 - Predicted: tensor([85342.0391])
# Day 521: 2024-05-12 00:00:00 - Predicted: tensor([85531.7969])
# Day 522: 2024-05-13 00:00:00 - Predicted: tensor([85721.9531])
# Day 523: 2024-05-14 00:00:00 - Predicted: tensor([85912.5625])
# Day 524: 2024-05-15 00:00:00 - Predicted: tensor([86103.5703])
# Day 525: 2024-05-16 00:00:00 - Predicted: tensor([86295.0156])
# Day 526: 2024-05-17 00:00:00 - Predicted: tensor([86486.8828])
# Day 527: 2024-05-18 00:00:00 - Predicted: tensor([86679.1875])
# Day 528: 2024-05-19 00:00:00 - Predicted: tensor([86871.8984])
# Day 529: 2024-05-20 00:00:00 - Predicted: tensor([87065.0469])
# Day 530: 2024-05-21 00:00:00 - Predicted: tensor([87258.6406])
# Day 531: 2024-05-22 00:00:00 - Predicted: tensor([87452.6484])
# Day 532: 2024-05-23 00:00:00 - Predicted: tensor([87647.0938])
# Day 533: 2024-05-24 00:00:00 - Predicted: tensor([87841.9766])
# Day 534: 2024-05-25 00:00:00 - Predicted: tensor([88037.2656])
# Day 535: 2024-05-26 00:00:00 - Predicted: tensor([88233.0156])
# Day 536: 2024-05-27 00:00:00 - Predicted: tensor([88429.1875])
# Day 537: 2024-05-28 00:00:00 - Predicted: tensor([88625.8047])
# Day 538: 2024-05-29 00:00:00 - Predicted: tensor([88822.8594])
# Day 539: 2024-05-30 00:00:00 - Predicted: tensor([89020.3516])
# Day 540: 2024-05-31 00:00:00 - Predicted: tensor([89218.2812])
# Day 541: 2024-06-01 00:00:00 - Predicted: tensor([89416.6406])
# Day 542: 2024-06-02 00:00:00 - Predicted: tensor([89615.4609])

# %%
# Khởi tạo cấu hình cho model
class Configs:
    def __init__(self):
        self.seq_len = 20  # Độ dài chuỗi thời gian đầu vào(tập kiểm tra)
        self.pred_len = 20  # Độ dài dự đoán
        self.individual = False  # Có sử dụng các kênh cá nhân hay không
        self.enc_in = 1  # Số lượng kênh đầu vào (tương ứng với số cột của dữ liệu)

configs = Configs()

# Khởi tạo model
model = Model(configs)

# %%
import torch.optim as optim

# Xác định hàm mất mát và trình tối ưu hóa
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Có thể điều chỉnh lr theo yêu cầu

# Huấn luyện mô hình
num_epochs = 100  # Số lượng epoch
for epoch in range(num_epochs):
    model.train()  # Chuyển sang chế độ huấn luyện
    optimizer.zero_grad()  # Đặt gradient về 0

    # Feedforward
    outputs = model(input_data_20day)

    # Tính toán loss
    loss = criterion(outputs, input_data_20day)  # So sánh đầu ra với đầu vào

    # Backpropagation
    loss.backward()  # Tính toán gradient
    optimizer.step()  # Cập nhật trọng số

    # In ra loss sau mỗi epoch
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/100], Loss: 153248.5938
# Epoch [2/100], Loss: 212416.3438
# Epoch [3/100], Loss: 112013.0859
# Epoch [4/100], Loss: 94400.2656
# Epoch [5/100], Loss: 117655.3359
# Epoch [6/100], Loss: 85039.3125
# Epoch [7/100], Loss: 46735.1133
# Epoch [8/100], Loss: 43385.3203
# Epoch [9/100], Loss: 63352.5312
# Epoch [10/100], Loss: 64779.9141
# Epoch [11/100], Loss: 42402.7695
# Epoch [12/100], Loss: 22742.1738
# Epoch [13/100], Loss: 23243.5742
# Epoch [14/100], Loss: 34815.3750
# Epoch [15/100], Loss: 37583.1562
# Epoch [16/100], Loss: 27102.6191
# Epoch [17/100], Loss: 15509.6426
# Epoch [18/100], Loss: 13270.1660
# Epoch [19/100], Loss: 18031.7988
# Epoch [20/100], Loss: 20632.4062
# Epoch [21/100], Loss: 17116.1543
# Epoch [22/100], Loss: 11578.8330
# Epoch [23/100], Loss: 9080.5684
# Epoch [24/100], Loss: 9861.4375
# Epoch [25/100], Loss: 10798.4727
# Epoch [26/100], Loss: 9927.2627
# Epoch [27/100], Loss: 8014.0312
# Epoch [28/100], Loss: 6556.7891
# Epoch [29/100], Loss: 5991.2085
# Epoch [30/100], Loss: 5812.9404
# Epoch [31/100], Loss: 5534.2119
# Epoch [32/100], Loss: 5045.6709
# Epoch [33/100], Loss: 4433.1133
# Epoch [34/100], Loss: 3853.0044
# Epoch [35/100], Loss: 3414.9751
# Epoch [36/100], Loss: 3131.7114
# Epoch [37/100], Loss: 2946.9968
# Epoch [38/100], Loss: 2785.9907
# Epoch [39/100], Loss: 2544.5359
# Epoch [40/100], Loss: 2153.6455
# Epoch [41/100], Loss: 1761.3381
# Epoch [42/100], Loss: 1638.6804
# Epoch [43/100], Loss: 1755.7366
# Epoch [44/100], Loss: 1709.2164
# Epoch [45/100], Loss: 1308.2888
# Epoch [46/100], Loss: 933.6869
# Epoch [47/100], Loss: 973.2614
# Epoch [48/100], Loss: 1180.8475
# Epoch [49/100], Loss: 1065.8340
# Epoch [50/100], Loss: 692.3209
# Epoch [51/100], Loss: 538.1205
# Epoch [52/100], Loss: 687.0945
# Epoch [53/100], Loss: 748.3819
# Epoch [54/100], Loss: 556.0392
# Epoch [55/100], Loss: 383.6464
# Epoch [56/100], Loss: 406.8357
# Epoch [57/100], Loss: 453.4709
# Epoch [58/100], Loss: 384.6896
# Epoch [59/100], Loss: 303.2043
# Epoch [60/100], Loss: 288.9971
# Epoch [61/100], Loss: 271.6841
# Epoch [62/100], Loss: 226.6598
# Epoch [63/100], Loss: 216.7297
# Epoch [64/100], Loss: 224.7836
# Epoch [65/100], Loss: 181.5964
# Epoch [66/100], Loss: 126.5019
# Epoch [67/100], Loss: 136.6618
# Epoch [68/100], Loss: 165.5787
# Epoch [69/100], Loss: 132.1135
# Epoch [70/100], Loss: 77.9561
# Epoch [71/100], Loss: 81.2001
# Epoch [72/100], Loss: 110.2672
# Epoch [73/100], Loss: 95.7315
# Epoch [74/100], Loss: 56.4503
# Epoch [75/100], Loss: 49.2748
# Epoch [76/100], Loss: 67.2013
# Epoch [77/100], Loss: 66.5984
# Epoch [78/100], Loss: 44.1755
# Epoch [79/100], Loss: 31.4633
# Epoch [80/100], Loss: 39.1373
# Epoch [81/100], Loss: 45.0466
# Epoch [82/100], Loss: 33.6161
# Epoch [83/100], Loss: 20.5607
# Epoch [84/100], Loss: 23.4702
# Epoch [85/100], Loss: 30.2537
# Epoch [86/100], Loss: 23.5197
# Epoch [87/100], Loss: 13.5739
# Epoch [88/100], Loss: 15.6364
# Epoch [89/100], Loss: 20.0232
# Epoch [90/100], Loss: 14.9037
# Epoch [91/100], Loss: 9.4619
# Epoch [92/100], Loss: 11.4853
# Epoch [93/100], Loss: 12.6102
# Epoch [94/100], Loss: 8.8633
# Epoch [95/100], Loss: 7.1837
# Epoch [96/100], Loss: 8.4500
# Epoch [97/100], Loss: 7.4467
# Epoch [98/100], Loss: 5.3873
# Epoch [99/100], Loss: 5.6135
# Epoch [100/100], Loss: 5.8282

# %%
# Dự báo cho 90 ngày kế tiếp
# # Chuyển sang chế độ đánh giá
model.eval()

# Không cần tính gradient trong quá trình dự báo
with torch.no_grad():
    input_data_future = input_data_20day.clone()  # Tạo một bản sao của dữ liệu đầu vào để cập nhật dự báo
    predicted = []  # Danh sách dự báo cho các ngày tiếp theo
    for i in range(90):  # Dự báo cho 90 ngày tiếp theo
        # Dự báo cho ngày hiện tại
        output = model(input_data_future)
        # Lưu dự báo của ngày hiện tại
        predicted.append(output[:, -1, :])  # Lấy dự báo cho ngày cuối cùng trong chuỗi thời gian
        # Cập nhật dữ liệu đầu vào cho ngày tiếp theo
        input_data_future = torch.cat([input_data_future[:, :, 1:], output], dim=2)

    # In ra dự báo cho 90 ngày tiếp theo
    print("Predicted Output for the next 90 days:")
    for i in range(90):
        # In ra ngày tương ứng với dự báo
        print(f"Day {i+1}: {last_date + pd.DateOffset(days=i+1)} - Predicted: {predicted[i][0]}")
# Out:
# Predicted Output for the next 90 days:
# Day 1: 2024-06-02 00:00:00 - Predicted: tensor([35998.6797])
# Day 2: 2024-06-03 00:00:00 - Predicted: tensor([35998.7383])
# Day 3: 2024-06-04 00:00:00 - Predicted: tensor([35998.7969])
# Day 4: 2024-06-05 00:00:00 - Predicted: tensor([35998.8516])
# Day 5: 2024-06-06 00:00:00 - Predicted: tensor([35998.9102])
# Day 6: 2024-06-07 00:00:00 - Predicted: tensor([35998.9648])
# Day 7: 2024-06-08 00:00:00 - Predicted: tensor([35999.0195])
# Day 8: 2024-06-09 00:00:00 - Predicted: tensor([35999.0820])
# Day 9: 2024-06-10 00:00:00 - Predicted: tensor([35999.1289])
# Day 10: 2024-06-11 00:00:00 - Predicted: tensor([35999.1914])
# Day 11: 2024-06-12 00:00:00 - Predicted: tensor([35999.2422])
# Day 12: 2024-06-13 00:00:00 - Predicted: tensor([35999.3008])
# Day 13: 2024-06-14 00:00:00 - Predicted: tensor([35999.3594])
# Day 14: 2024-06-15 00:00:00 - Predicted: tensor([35999.4141])
# Day 15: 2024-06-16 00:00:00 - Predicted: tensor([35999.4688])
# Day 16: 2024-06-17 00:00:00 - Predicted: tensor([35999.5234])
# Day 17: 2024-06-18 00:00:00 - Predicted: tensor([35999.5820])
# Day 18: 2024-06-19 00:00:00 - Predicted: tensor([35999.6406])
# Day 19: 2024-06-20 00:00:00 - Predicted: tensor([35999.6992])
# Day 20: 2024-06-21 00:00:00 - Predicted: tensor([35999.7500])
# Day 21: 2024-06-22 00:00:00 - Predicted: tensor([35999.8086])
# Day 22: 2024-06-23 00:00:00 - Predicted: tensor([35999.8633])
# Day 23: 2024-06-24 00:00:00 - Predicted: tensor([35999.9219])
# Day 24: 2024-06-25 00:00:00 - Predicted: tensor([35999.9766])
# Day 25: 2024-06-26 00:00:00 - Predicted: tensor([36000.0352])
# Day 26: 2024-06-27 00:00:00 - Predicted: tensor([36000.0898])
# Day 27: 2024-06-28 00:00:00 - Predicted: tensor([36000.1445])
# Day 28: 2024-06-29 00:00:00 - Predicted: tensor([36000.2031])
# Day 29: 2024-06-30 00:00:00 - Predicted: tensor([36000.2578])
# Day 30: 2024-07-01 00:00:00 - Predicted: tensor([36000.3164])
# Day 31: 2024-07-02 00:00:00 - Predicted: tensor([36000.3711])
# Day 32: 2024-07-03 00:00:00 - Predicted: tensor([36000.4258])
# Day 33: 2024-07-04 00:00:00 - Predicted: tensor([36000.4844])
# Day 34: 2024-07-05 00:00:00 - Predicted: tensor([36000.5430])
# Day 35: 2024-07-06 00:00:00 - Predicted: tensor([36000.5977])
# Day 36: 2024-07-07 00:00:00 - Predicted: tensor([36000.6523])
# Day 37: 2024-07-08 00:00:00 - Predicted: tensor([36000.7070])
# Day 38: 2024-07-09 00:00:00 - Predicted: tensor([36000.7695])
# Day 39: 2024-07-10 00:00:00 - Predicted: tensor([36000.8203])
# Day 40: 2024-07-11 00:00:00 - Predicted: tensor([36000.8750])
# Day 41: 2024-07-12 00:00:00 - Predicted: tensor([36000.9336])
# Day 42: 2024-07-13 00:00:00 - Predicted: tensor([36000.9922])
# Day 43: 2024-07-14 00:00:00 - Predicted: tensor([36001.0469])
# Day 44: 2024-07-15 00:00:00 - Predicted: tensor([36001.1016])
# Day 45: 2024-07-16 00:00:00 - Predicted: tensor([36001.1602])
# Day 46: 2024-07-17 00:00:00 - Predicted: tensor([36001.2148])
# Day 47: 2024-07-18 00:00:00 - Predicted: tensor([36001.2695])
# Day 48: 2024-07-19 00:00:00 - Predicted: tensor([36001.3281])
# Day 49: 2024-07-20 00:00:00 - Predicted: tensor([36001.3867])
# Day 50: 2024-07-21 00:00:00 - Predicted: tensor([36001.4375])
# Day 51: 2024-07-22 00:00:00 - Predicted: tensor([36001.4961])
# Day 52: 2024-07-23 00:00:00 - Predicted: tensor([36001.5547])
# Day 53: 2024-07-24 00:00:00 - Predicted: tensor([36001.6094])
# Day 54: 2024-07-25 00:00:00 - Predicted: tensor([36001.6641])
# Day 55: 2024-07-26 00:00:00 - Predicted: tensor([36001.7266])
# Day 56: 2024-07-27 00:00:00 - Predicted: tensor([36001.7773])
# Day 57: 2024-07-28 00:00:00 - Predicted: tensor([36001.8320])
# Day 58: 2024-07-29 00:00:00 - Predicted: tensor([36001.8906])
# Day 59: 2024-07-30 00:00:00 - Predicted: tensor([36001.9492])
# Day 60: 2024-07-31 00:00:00 - Predicted: tensor([36002.0039])
# Day 61: 2024-08-01 00:00:00 - Predicted: tensor([36002.0625])
# Day 62: 2024-08-02 00:00:00 - Predicted: tensor([36002.1133])
# Day 63: 2024-08-03 00:00:00 - Predicted: tensor([36002.1719])
# Day 64: 2024-08-04 00:00:00 - Predicted: tensor([36002.2305])
# Day 65: 2024-08-05 00:00:00 - Predicted: tensor([36002.2852])
# Day 66: 2024-08-06 00:00:00 - Predicted: tensor([36002.3398])
# Day 67: 2024-08-07 00:00:00 - Predicted: tensor([36002.3984])
# Day 68: 2024-08-08 00:00:00 - Predicted: tensor([36002.4531])
# Day 69: 2024-08-09 00:00:00 - Predicted: tensor([36002.5117])
# Day 70: 2024-08-10 00:00:00 - Predicted: tensor([36002.5664])
# Day 71: 2024-08-11 00:00:00 - Predicted: tensor([36002.6250])
# Day 72: 2024-08-12 00:00:00 - Predicted: tensor([36002.6797])
# Day 73: 2024-08-13 00:00:00 - Predicted: tensor([36002.7344])
# Day 74: 2024-08-14 00:00:00 - Predicted: tensor([36002.7930])
# Day 75: 2024-08-15 00:00:00 - Predicted: tensor([36002.8477])
# Day 76: 2024-08-16 00:00:00 - Predicted: tensor([36002.9062])
# Day 77: 2024-08-17 00:00:00 - Predicted: tensor([36002.9609])
# Day 78: 2024-08-18 00:00:00 - Predicted: tensor([36003.0195])
# Day 79: 2024-08-19 00:00:00 - Predicted: tensor([36003.0742])
# Day 80: 2024-08-20 00:00:00 - Predicted: tensor([36003.1289])
# Day 81: 2024-08-21 00:00:00 - Predicted: tensor([36003.1914])
# Day 82: 2024-08-22 00:00:00 - Predicted: tensor([36003.2422])
# Day 83: 2024-08-23 00:00:00 - Predicted: tensor([36003.3008])
# Day 84: 2024-08-24 00:00:00 - Predicted: tensor([36003.3555])
# Day 85: 2024-08-25 00:00:00 - Predicted: tensor([36003.4141])
# Day 86: 2024-08-26 00:00:00 - Predicted: tensor([36003.4688])
# Day 87: 2024-08-27 00:00:00 - Predicted: tensor([36003.5234])
# Day 88: 2024-08-28 00:00:00 - Predicted: tensor([36003.5820])
# Day 89: 2024-08-29 00:00:00 - Predicted: tensor([36003.6367])
# Day 90: 2024-08-30 00:00:00 - Predicted: tensor([36003.6914])

# %%
# Chuyển dữ liệu từ Series pandas thành numpy array để vẽ biểu đồ
predicted_values_test = [pred[0].numpy() for pred in predicted_test]
# Chuyển dữ liệu dự báo từ tensor về numpy array
predicted_values = [pred[0].numpy() for pred in predicted]
# Tạo mảng chứa ngày của train_data_price
train_dates = df['Date'].values[:len(train_data_price)]
# Tạo mảng chứa ngày của test_data_price
test_dates = df['Date'].values[len(train_data_price):len(train_data_price)+len(test_data_price)]
# Tạo mảng chứa ngày dự đoán
predicted_dates = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=len(predicted_values))

split_size = len(predicted_values) // 3

predicted_values_30day = predicted_values[:split_size]
predicted_values_60day = predicted_values[split_size:2*split_size]
predicted_values_90day = predicted_values[2*split_size:]
# Tính toán các khoảng thời gian cho mỗi phần
predicted_dates_30day = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=split_size)
predicted_dates_60day = pd.date_range(start=predicted_dates_30day[-1] + pd.DateOffset(days=1), periods=split_size)
predicted_dates_90day = pd.date_range(start=predicted_dates_60day[-1] + pd.DateOffset(days=1), periods=split_size)

# %%
import matplotlib.pyplot as plt


# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(train_dates, train_data_price, label='Training Data')
plt.plot(test_dates, test_data_price, label='Actual Data')
plt.plot(test_dates, predicted_values_test, label='Predicted')
plt.plot(predicted_dates_30day, predicted_values_30day, label='Predicted 30 Day', color='red')
plt.plot(predicted_dates_60day, predicted_values_60day, label='Predicted 60 Day', color='green')
plt.plot(predicted_dates_90day, predicted_values_90day, label='Predicted 90 Day', color='blue')
plt.title('DLinear - KDH Stock Price - 8:2')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt


# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(test_dates, test_data_price, label='Actual Data')
plt.plot(predicted_dates_30day, predicted_values_30day, label='Predicted 30 Day', color='red')
plt.plot(predicted_dates_60day, predicted_values_60day, label='Predicted 60 Day', color='green')
plt.plot(predicted_dates_90day, predicted_values_90day, label='Predicted 90 Day', color='blue')

plt.title('DLinear - KDH Stock Price - 8:2')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
outputs_test = np.array(predicted_values_test)
outputs_test = outputs_test.flatten()

# %%
# Mean Absolute Error (MAE) và Mean Absolute Percentage Error (MAPE)
mae_test = np.mean(np.abs(test_data_price - outputs_test))
mape_test = np.mean(np.abs((test_data_price - outputs_test) / test_data_price)) * 100
rmse_test = np.sqrt(np.mean((test_data_price - outputs_test) ** 2))

print("MAE:", mae_test)
print("MAPE:", mape_test)
print("RMSE:", rmse_test)
# Out:
# MAE: 22393.21180739737
# MAPE: 71.07905049536782
# RMSE: 26634.010633243724
