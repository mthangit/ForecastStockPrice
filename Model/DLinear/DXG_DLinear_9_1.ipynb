# %%
from re import X
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        # padding on the both ends of time series
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x


class series_decomp(nn.Module):
    """
    Series decomposition block
    """
    def __init__(self, kernel_size):
        super(series_decomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class Model(nn.Module):
    """
    DLinear
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len

        # Decompsition Kernel Size
        kernel_size = 25
        self.decompsition = series_decomp(kernel_size)
        self.individual = configs.individual
        self.channels = configs.enc_in

        if self.individual:
            self.Linear_Seasonal = nn.ModuleList()
            self.Linear_Trend = nn.ModuleList()
            self.Linear_Decoder = nn.ModuleList()
            for i in range(self.channels):
                self.Linear_Seasonal.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Seasonal[i].weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))
                self.Linear_Trend.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Trend[i].weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))
                self.Linear_Decoder.append(nn.Linear(self.seq_len,self.pred_len))
        else:
            self.Linear_Seasonal = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Trend = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Decoder = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Seasonal.weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))
            self.Linear_Trend.weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))

    def forward(self, x):
        # x: [Batch, Input length, Channel]
        seasonal_init, trend_init = self.decompsition(x)
        seasonal_init, trend_init = seasonal_init.permute(0,2,1), trend_init.permute(0,2,1)
        if self.individual:
            seasonal_output = torch.zeros([seasonal_init.size(0),seasonal_init.size(1),self.pred_len],dtype=seasonal_init.dtype).to(seasonal_init.device)
            trend_output = torch.zeros([trend_init.size(0),trend_init.size(1),self.pred_len],dtype=trend_init.dtype).to(trend_init.device)
            for i in range(self.channels):
                seasonal_output[:,i,:] = self.Linear_Seasonal[i](seasonal_init[:,i,:])
                trend_output[:,i,:] = self.Linear_Trend[i](trend_init[:,i,:])
        else:
            seasonal_output = self.Linear_Seasonal(seasonal_init)
            trend_output = self.Linear_Trend(trend_init)

        x = seasonal_output + trend_output
        return x.permute(0,2,1) # to [Batch, Output length, Channel]

# %%
import pandas as pd
import torch
from datetime import datetime, timedelta
# Đọc dữ liệu từ file CSV
df = pd.read_csv('DXG-Historical-Data.csv')

# %%
# # Chuyển dữ liệu thời gian
# df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')
# # Đảo ngược lại dữ liệu
# df = df.iloc[::-1].reset_index(drop=True)

# %%
# # Loại bỏ dấu phẩy từ cột "Price"
# df['Price'] = df['Price'].str.replace(',', '').astype(float)
# # Loại bỏ dấu phẩy từ cột "Open"
# df['Open'] = df['Open'].str.replace(',', '').astype(float)
# # Loại bỏ dấu phẩy từ cột "High"
# df['High'] = df['High'].str.replace(',', '').astype(float)
# # Loại bỏ dấu phẩy từ cột "Low"
# df['Low'] = df['Low'].str.replace(',', '').astype(float)

# %%
df
# Out:
#       Unnamed: 0        Date     Price
# 0              0  2017-01-03   6066.50
# 1              1  2017-01-04   6166.40
# 2              2  2017-01-05   6091.50
# 3              3  2017-01-06   6141.40
# 4              4  2017-01-07   6116.45
# ...          ...         ...       ...
# 2702        2702  2024-05-28  16800.00
# 2703        2703  2024-05-29  16850.00
# 2704        2704  2024-05-30  16850.00
# 2705        2705  2024-05-31  16800.00
# 2706        2706  2024-06-01  16770.00
#
# [2707 rows x 3 columns]

# %%
# Lấy ngày cuối cùng của dữ liệu
df['Date'] = pd.to_datetime(df['Date'])
last_date = df['Date'].max()

# %%
# Lấy dữ liệu Date cần phân tích để dự bảo DL trên tập test
time_series_Date = df['Date']

# Phân chia dữ liệu thành tập huấn luyện và tập kiểm tra - để lấy date
train_data_Date = time_series_Date[:int(0.8 * len(time_series_Date))]
test_data_Date = time_series_Date[int(0.8 * len(time_series_Date)):]
first_data_Date = test_data_Date.min()
print(first_data_Date)
# Out:
# 2022-12-08 00:00:00

# %%
# Lấy dữ liệu cần phân tích
time_series_price = df['Price']

# Phân chia dữ liệu thành tập huấn luyện và tập kiểm tra
train_data_price = time_series_price[:int(0.9 * len(time_series_price))]
test_data_price = time_series_price[int(0.9 * len(time_series_price)):]

# Chọn các cột dữ liệu số
# numeric_columns = ['Price', 'Open', 'High', 'Low']
numeric_columns = ['Price']

# Chuyển các giá trị số thành tensor
numeric_data = df[numeric_columns].values.astype(np.float32)

# Mở rộng chiều để phù hợp với đầu vào của mô hình
numeric_data = np.expand_dims(numeric_data, axis=0)

# Chia dữ liệu thành tensor
input_data_train = torch.tensor(numeric_data[:, :len(train_data_price), :])
input_data_test = torch.tensor(numeric_data[:, len(train_data_price):, :])
# Lấy dữ liệu 20 ngày gần nhất
recent_20_prices = time_series_price[-20:]

# Chuyển đổi dữ liệu 20 ngày gần nhất thành numpy array và mở rộng chiều
recent_20_prices_array = recent_20_prices.values.astype(np.float32)
recent_20_prices_array = np.expand_dims(recent_20_prices_array, axis=0)
recent_20_prices_array = np.expand_dims(recent_20_prices_array, axis=-1)

# Chuyển đổi thành tensor
input_data_20day = torch.tensor(recent_20_prices_array)

# In ra để kiểm tra kích thước của các tensor
print("Kích thước tập huấn luyện:", input_data_train.shape)
print("Kích thước tập kiểm tra:", input_data_test.shape)
# Out:
# Kích thước tập huấn luyện: torch.Size([1, 2436, 1])
# Kích thước tập kiểm tra: torch.Size([1, 271, 1])

# %%
# Khởi tạo cấu hình cho model
class Configs:
    def __init__(self):
        self.seq_len = 2436  # Độ dài chuỗi thời gian đầu vào(tập kiểm tra)
        self.pred_len = 2436  # Độ dài dự đoán
        self.individual = False  # Có sử dụng các kênh cá nhân hay không
        self.enc_in = 1  # Số lượng kênh đầu vào (tương ứng với số cột của dữ liệu)

configs = Configs()

# Khởi tạo model
model = Model(configs)

# %%
import torch.optim as optim

# Xác định hàm mất mát và trình tối ưu hóa
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Có thể điều chỉnh lr theo yêu cầu

# Huấn luyện mô hình
num_epochs = 100  # Số lượng epoch
for epoch in range(num_epochs):
    model.train()  # Chuyển sang chế độ huấn luyện
    optimizer.zero_grad()  # Đặt gradient về 
# Epoch [74/100], Loss: 306683.9062
# Epoch [75/100], Loss: 269367.9375
# Epoch [76/100], Loss: 236295.2500
# Epoch [77/100], Loss: 218204.8281
# Epoch [78/100], Loss: 208898.0312
# Epoch [79/100], Loss: 187597.8125
# Epoch [80/100], Loss: 156654.2188
# Epoch [81/100], Loss: 139525.8906
# Epoch [82/100], Loss: 137324.2031
# Epoch [83/100], Loss: 128288.4766
# Epoch [84/100], Loss: 107540.8672
# Epoch [85/100], Loss: 91471.5781
# Epoch [86/100], Loss: 87626.3516
# Epoch [87/100], Loss: 85557.0938
# Epoch [88/100], Loss: 75200.4531
# Epoch [89/100], Loss: 61228.3672
# Epoch [90/100], Loss: 55224.9844
# Epoch [91/100], Loss: 56434.5859
# Epoch [92/100], Loss: 52251.8828
# Epoch [93/100], Loss: 41088.3906
# Epoch [94/100], Loss: 35366.0273
# Epoch [95/100], Loss: 37238.7812
# Epoch [96/100], Loss: 35295.5781
# Epoch [97/100], Loss: 27590.7949
# Epoch [98/100], Loss: 23506.3828
# Epoch [99/100], Loss: 24365.4434
# Epoch [100/100], Loss: 23154.8379

# %%
# Dự báo cho tập test
# # Chuyển sang chế độ đánh giá
model.eval()

# Không cần tính gradient trong quá trình dự báo
with torch.no_grad():
    input_data_future_test = input_data_train.clone()  # Tạo một bản sao của dữ liệu đầu vào để cập nhật dự báo
    predicted_test = []  # Danh sách dự báo cho các ngày tiếp theo
    for i in range(271):  # Dự báo cho tập test
        # Dự báo cho ngày hiện tại
        output = model(input_data_future_test)
        # Lưu dự báo của ngày hiện tại
        predicted_test.append(output[:, -1, :])  # Lấy dự báo cho ngày cuối cùng trong chuỗi thời gian
        # Cập nhật dữ liệu đầu vào cho ngày tiếp theo
        input_data_future_test = torch.cat([input_data_future_test[:, :, 1:], output], dim=2)

    # In ra dự báo cho tập test
    print("Predicted Output for data test:")
    for i in range(271):
        # In ra ngày tương ứng với dự báo
        print(f"Day  Predicted: {predicted_test[i][0]}")
# Out:
# Predicted Output for data test:
# Day  Predicted: tensor([21278.5508])
# Day  Predicted: tensor([21275.9375])
# Day  Predicted: tensor([21271.1777])
# Day  Predicted: tensor([21266.3496])
# Day  Predicted: tensor([21261.5137])
# Day  Predicted: tensor([21256.6855])
# Day  Predicted: tensor([21251.8555])
# Day  Predicted: tensor([21247.0234])
# Day  Predicted: tensor([21242.1973])
# Day  Predicted: tensor([21237.3672])
# Day  Predicted: tensor([21232.5430])
# Day  Predicted: tensor([21227.7227])
# Day  Predicted: tensor([21222.8965])
# Day  Predicted: tensor([21218.0742])
# Day  Predicted: tensor([21213.2500])
# Day  Predicted: tensor([21208.4297])
# Day  Predicted: tensor([21203.6074])
# Day  Predicted: tensor([21198.7949])
# Day  Predicted: tensor([21193.9727])
# Day  Predicted: tensor([21189.1562])
# Day  Predicted: tensor([21184.3438])
# Day  Predicted: tensor([21179.5293])
# Day  Predicted: tensor([21174.7148])
# Day  Predicted: tensor([21169.9023])
# Day  Predicted: tensor([21165.0918])
# Day  Predicted: tensor([21160.2832])
# Day  Predicted: tensor([21155.4766])
# Day  Predicted: tensor([21150.6680])
# Day  Predicted: tensor([21145.8613])
# Day  Predicted: tensor([21141.0566])
# Day  Predicted: tensor([21136.2520])
# Day  Predicted: tensor([21131.4492])
# Day  Predicted: tensor([21126.6445])
# Day  Predicted: tensor([21121.8438])
# Day  Predicted: tensor([21117.0430])
# Day  Predicted: tensor([21112.2441])
# Day  Predicted: tensor([21107.4492])
# Day  Predicted: tensor([21102.6543])
# Day  Predicted: tensor([21097.8574])
# Day  Predicted: tensor([21093.0625])
# Day  Predicted: tensor([21088.2695])
# Day  Predicted: tensor([21083.4766])
# Day  Predicted: tensor([21078.6836])
# Day  Predicted: tensor([21073.8926])
# Day  Predicted: tensor([21069.1074])
# Day  Predicted: tensor([21064.3203])
# Day  Predicted: tensor([21059.5312])
# Day  Predicted: tensor([21054.7461])
# Day  Predicted: tensor([21049.9629])
# Day  Predicted: tensor([21045.1758])
# Day  Predicted: tensor([21040.3965])
# Day  Predicted: tensor([21035.6133])
# Day  Predicted: tensor([21030.8359])
# Day  Predicted: tensor([21026.0527])
# Day  Predicted: tensor([21021.2773])
# Day  Predicted: tensor([21016.5020])
# Day  Predicted: tensor([21011.7246])
# Day  Predicted: tensor([21006.9492])
# Day  Predicted: tensor([21002.1758])
# Day  Predicted: tensor([20997.4004])
# Day  Predicted: tensor([20992.6309])
# Day  Predicted: tensor([20987.8613])
# Day  Predicted: tensor([20983.0898])
# Day  Predicted: tensor([20978.3242])
# Day  Predicted: tensor([20973.5547])
# Day  Predicted: tensor([20968.7891])
# Day  Predicted: tensor([20964.0234])
# Day  Predicted: tensor([20959.2598])
# Day  Predicted: tensor([20954.4980])
# Day  Predicted: tensor([20949.7305])
# Day  Predicted: tensor([20944.9727])
# Day  Predicted: tensor([20940.2168])
# Day  Predicted: tensor([20935.4570])
# Day  Predicted: tensor([20930.6992])
# Day  Predicted: tensor([20925.9434])
# Day  Predicted: tensor([20921.1855])
# Day  Predicted: tensor([20916.4297])
# Day  Predicted: tensor([20911.6797])
# Day  Predicted: tensor([20906.9238])
# Day  Predicted: tensor([20902.1758])
# Day  Predicted: tensor([20897.4238])
# Day  Predicted: tensor([20892.6797])
# Day  Predicted: tensor([20887.9277])
# Day  Predicted: tensor([20883.1816])
# Day  Predicted: tensor([20878.4395])
# Day  Predicted: tensor([20873.6914])
# Day  Predicted: tensor([20868.9473])
# Day  Predicted: tensor([20864.2070])
# Day  Predicted: tensor([20859.4668])
# Day  Predicted: tensor([20854.7266])
# Day  Predicted: tensor([20849.9844])
# Day  Predicted: tensor([20845.2480])
# Day  Predicted: tensor([20840.5098])
# Day  Predicted: tensor([20835.7754])
# Day  Predicted: tensor([20831.0410])
# Day  Predicted: tensor([20826.3047])
# Day  Predicted: tensor([20821.5742])
# Day  Predicted: tensor([20816.8438])
# Day  Predicted: tensor([20812.1094])
# Day  Predicted: tensor([20807.3848])
# Day  Predicted: tensor([20802.6523])
# Day  Predicted: tensor([20797.9258])
# Day  Predicted: tensor([20793.1992])
# Day  Predicted: tensor([20788.4746])
# Day  Predicted: tensor([20783.7520])
# Day  Predicted: tensor([20779.0254])
# Day  Predicted: tensor([20774.3066])
# Day  Predicted: tensor([20769.5840])
# Day  Predicted: tensor([20764.8633])
# Day  Predicted: tensor([20760.1445])
# Day  Predicted: tensor([20755.4277])
# Day  Predicted: tensor([20750.7109])
# Day  Predicted: tensor([20745.9980])
# Day  Predicted: tensor([20741.2812])
# Day  Predicted: tensor([20736.5703])
# Day  Predicted: tensor([20731.8555])
# Day  Predicted: tensor([20727.1465])
# Day  Predicted: tensor([20722.4336])
# Day  Predicted: tensor([20717.7246])
# Day  Predicted: tensor([20713.0176])
# Day  Predicted: tensor([20708.3066])
# Day  Predicted: tensor([20703.6035])
# Day  Predicted: tensor([20698.9023])
# Day  Predicted: tensor([20694.1973])
# Day  Predicted: tensor([20689.4961])
# Day  Predicted: tensor([20684.7910])
# Day  Predicted: tensor([20680.0918])
# Day  Predicted: tensor([20675.3906])
# Day  Predicted: tensor([20670.6934])
# Day  Predicted: tensor([20666.])
# Day  Predicted: tensor([20661.3027])
# Day  Predicted: tensor([20656.6035])
# Day  Predicted: tensor([20651.9121])
# Day  Predicted: tensor([20647.2188])
# Day  Predicted: tensor([20642.5254])
# Day  Predicted: tensor([20637.8379])
# Day  Predicted: tensor([20633.1465])
# Day  Predicted: tensor([20628.4570])
# Day  Predicted: tensor([20623.7695])
# Day  Predicted: tensor([20619.0840])
# Day  Predicted: tensor([20614.3965])
# Day  Predicted: tensor([20609.7109])
# Day  Predicted: tensor([20605.0293])
# Day  Predicted: tensor([20600.3457])
# Day  Predicted: tensor([20595.6680])
# Day  Predicted: tensor([20590.9863])
# Day  Predicted: tensor([20586.3066])
# Day  Predicted: tensor([20581.6270])
# Day  Predicted: tensor([20576.9512])
# Day  Predicted: tensor([20572.2734])
# Day  Predicted: tensor([20567.5996])
# Day  Predicted: tensor([20562.9258])
# Day  Predicted: tensor([20558.2520])
# Day  Predicted: tensor([20553.5801])
# Day  Predicted: tensor([20548.9121])
# Day  Predicted: tensor([20544.2402])
# Day  Predicted: tensor([20539.5723])
# Day  Predicted: tensor([20534.9043])
# Day  Predicted: tensor([20530.2402])
# Day  Predicted: tensor([20525.5742])
# Day  Predicted: tensor([20520.9102])
# Day  Predicted: tensor([20516.2461])
# Day  Predicted: tensor([20511.5781])
# Day  Predicted: tensor([20506.9238])
# Day  Predicted: tensor([20502.2578])
# Day  Predicted: tensor([20497.5996])
# Day  Predicted: tensor([20492.9434])
# Day  Predicted: tensor([20488.2852])
# Day  Predicted: tensor([20483.6309])
# Day  Predicted: tensor([20478.9766])
# Day  Predicted: tensor([20474.3223])
# Day  Predicted: tensor([20469.6699])
# Day  Predicted: tensor([20465.0176])
# Day  Predicted: tensor([20460.3691])
# Day  Predicted: tensor([20455.7168])
# Day  Predicted: tensor([20451.0703])
# Day  Predicted: tensor([20446.4219])
# Day  Predicted: tensor([20441.7773])
# Day  Predicted: tensor([20437.1289])
# Day  Predicted: tensor([20432.4844])
# Day  Predicted: tensor([20427.8438])
# Day  Predicted: tensor([20423.2012])
# Day  Predicted: tensor([20418.5605])
# Day  Predicted: tensor([20413.9199])
# Day  Predicted: tensor([20409.2812])
# Day  Predicted: tensor([20404.6387])
# Day  Predicted: tensor([20400.0059])
# Day  Predicted: tensor([20395.3672])
# Day  Predicted: tensor([20390.7344])
# Day  Predicted: tensor([20386.1016])
# Day  Predicted: tensor([20381.4688])
# Day  Predicted: tensor([20376.8340])
# Day  Predicted: tensor([20372.2090])
# Day  Predicted: tensor([20367.5762])
# Day  Predicted: tensor([20362.9512])
# Day  Predicted: tensor([20358.3223])
# Day  Predicted: tensor([20353.6953])
# Day  Predicted: tensor([20349.0703])
# Day  Predicted: tensor([20344.4453])
# Day  Predicted: tensor([20339.8242])
# Day  Predicted: tensor([20335.2012])
# Day  Predicted: tensor([20330.5801])
# Day  Predicted: tensor([20325.9590])
# Day  Predicted: tensor([20321.3379])
# Day  Predicted: tensor([20316.7207])
# Day  Predicted: tensor([20312.1055])
# Day  Predicted: tensor([20307.4883])
# Day  Predicted: tensor([20302.8750])
# Day  Predicted: tensor([20298.2598])
# Day  Predicted: tensor([20293.6484])
# Day  Predicted: tensor([20289.0371])
# Day  Predicted: tensor([20284.4258])
# Day  Predicted: tensor([20279.8184])
# Day  Predicted: tensor([20275.2070])
# Day  Predicted: tensor([20270.6035])
# Day  Predicted: tensor([20265.9941])
# Day  Predicted: tensor([20261.3848])
# Day  Predicted: tensor([20256.7852])
# Day  Predicted: tensor([20252.1836])
# Day  Predicted: tensor([20247.5781])
# Day  Predicted: tensor([20242.9785])
# Day  Predicted: tensor([20238.3789])
# Day  Predicted: tensor([20233.7773])
# Day  Predicted: tensor([20229.1797])
# Day  Predicted: tensor([20224.5859])
# Day  Predicted: tensor([20219.9844])
# Day  Predicted: tensor([20215.3926])
# Day  Predicted: tensor([20210.8008])
# Day  Predicted: tensor([20206.2051])
# Day  Predicted: tensor([20201.6152])
# Day  Predicted: tensor([20197.0234])
# Day  Predicted: tensor([20192.4355])
# Day  Predicted: tensor([20187.8457])
# Day  Predicted: tensor([20183.2559])
# Day  Predicted: tensor([20178.6699])
# Day  Predicted: tensor([20174.0859])
# Day  Predicted: tensor([20169.5000])
# Day  Predicted: tensor([20164.9180])
# Day  Predicted: tensor([20160.3340])
# Day  Predicted: tensor([20155.7539])
# Day  Predicted: tensor([20151.1738])
# Day  Predicted: tensor([20146.5938])
# Day  Predicted: tensor([20142.0156])
# Day  Predicted: tensor([20137.4395])
# Day  Predicted: tensor([20132.8652])
# Day  Predicted: tensor([20128.2891])
# Day  Predicted: tensor([20123.7168])
# Day  Predicted: tensor([20119.1367])
# Day  Predicted: tensor([20114.5703])
# Day  Predicted: tensor([20109.9961])
# Day  Predicted: tensor([20105.4238])
# Day  Predicted: tensor([20100.8535])
# Day  Predicted: tensor([20096.2910])
# Day  Predicted: tensor([20091.7227])
# Day  Predicted: tensor([20087.1582])
# Day  Predicted: tensor([20082.5918])
# Day  Predicted: tensor([20078.0293])
# Day  Predicted: tensor([20073.4707])
# Day  Predicted: tensor([20068.9082])
# Day  Predicted: tensor([20064.3457])
# Day  Predicted: tensor([20059.7871])
# Day  Predicted: tensor([20055.2285])
# Day  Predicted: tensor([20050.6680])
# Day  Predicted: tensor([20046.1152])
# Day  Predicted: tensor([20041.5586])
# Day  Predicted: tensor([20037.0039])
# Day  Predicted: tensor([20032.4492])
# Day  Predicted: tensor([20027.8965])
# Day  Predicted: tensor([20023.3457])
# Day  Predicted: tensor([20018.7949])
# Day  Predicted: tensor([20014.2480])

# %%
# Khởi tạo cấu hình cho model
class Configs:
    def __init__(self):
        self.seq_len = 20  # Độ dài chuỗi thời gian đầu vào(tập kiểm tra)
        self.pred_len = 20  # Độ dài dự đoán
        self.individual = False  # Có sử dụng các kênh cá nhân hay không
        self.enc_in = 1  # Số lượng kênh đầu vào (tương ứng với số cột của dữ liệu)

configs = Configs()

# Khởi tạo model
model = Model(configs)

# %%
import torch.optim as optim

# Xác định hàm mất mát và trình tối ưu hóa
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Có thể điều chỉnh lr theo yêu cầu

# Huấn luyện mô hình
num_epochs = 100  # Số lượng epoch
for epoch in range(num_epochs):
    model.train()  # Chuyển sang chế độ huấn luyện
    optimizer.zero_grad()  # Đặt gradient về 0

    # Feedforward
    outputs = model(input_data_20day)

    # Tính toán loss
    loss = criterion(outputs, input_data_20day)  # So sánh đầu ra với đầu vào

    # Backpropagation
    loss.backward()  # Tính toán gradient
    optimizer.step()  # Cập nhật trọng số

    # In ra loss sau mỗi epoch
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/100], Loss:
# Epoch [86/100], Loss: 4.6006
# Epoch [87/100], Loss: 4.3090
# Epoch [88/100], Loss: 4.1252
# Epoch [89/100], Loss: 4.6744
# Epoch [90/100], Loss: 4.2292
# Epoch [91/100], Loss: 2.3869
# Epoch [92/100], Loss: 2.1579
# Epoch [93/100], Loss: 3.4197
# Epoch [94/100], Loss: 2.8784
# Epoch [95/100], Loss: 1.3335
# Epoch [96/100], Loss: 1.6646
# Epoch [97/100], Loss: 2.4889
# Epoch [98/100], Loss: 1.6141
# Epoch [99/100], Loss: 0.7346
# Epoch [100/100], Loss: 1.3248

# %%
# Dự báo cho 90 ngày kế tiếp
# # Chuyển sang chế độ đánh giá
model.eval()

# Không cần tính gradient trong quá trình dự báo
with torch.no_grad():
    input_data_future = input_data_20day.clone()  # Tạo một bản sao của dữ liệu đầu vào để cập nhật dự báo
    predicted = []  # Danh sách dự báo cho các ngày tiếp theo
    for i in range(90):  # Dự báo cho 90 ngày tiếp theo
        # Dự báo cho ngày hiện tại
        output = model(input_data_future)
        # Lưu dự báo của ngày hiện tại
        predicted.append(output[:, -1, :])  # Lấy dự báo cho ngày cuối cùng trong chuỗi thời gian
        # Cập nhật dữ liệu đầu vào cho ngày tiếp theo
        input_data_future = torch.cat([input_data_future[:, :, 1:], output], dim=2)

    # In ra dự báo cho 90 ngày tiếp theo
    print("Predicted Output for the next 90 days:")
    for i in range(90):
        # In ra ngày tương ứng với dự báo
        print(f"Day  Predicted: {predicted[i][0]}")
# Out:
# Predicted Output for the next 90 days:
# Day  Predicted: tensor([16771.4570])
# Day  Predicted: tensor([16771.0938])
# Day  Predicted: tensor([16770.7422])
# Day  Predicted: tensor([16770.3906])
# Day  Predicted: tensor([16770.0371])
# Day  Predicted: tensor([16769.6875])
# Day  Predicted: tensor([16769.3359])
# Day  Predicted: tensor([16768.9844])
# Day  Predicted: tensor([16768.6289])
# Day  Predicted: tensor([16768.2793])
# Day  Predicted: tensor([16767.9258])
# Day  Predicted: tensor([16767.5762])
# Day  Predicted: tensor([16767.2266])
# Day  Predicted: tensor([16766.8730])
# Day  Predicted: tensor([16766.5234])
# Day  Predicted: tensor([16766.1719])
# Day  Predicted: tensor([16765.8184])
# Day  Predicted: tensor([16765.4668])
# Day  Predicted: tensor([16765.1152])
# Day  Predicted: tensor([16764.7656])
# Day  Predicted: tensor([16764.4121])
# Day  Predicted: tensor([16764.0625])
# Day  Predicted: tensor([16763.7109])
# Day  Predicted: tensor([16763.3613])
# Day  Predicted: tensor([16763.0059])
# Day  Predicted: tensor([16762.6562])
# Day  Predicted: tensor([16762.3027])
# Day  Predicted: tensor([16761.9531])
# Day  Predicted: tensor([16761.6016])
# Day  Predicted: tensor([16761.2480])
# Day  Predicted: tensor([16760.8984])
# Day  Predicted: tensor([16760.5469])
# Day  Predicted: tensor([16760.1953])
# Day  Predicted: tensor([16759.8418])
# Day  Predicted: tensor([16759.4922])
# Day  Predicted: tensor([16759.1406])
# Day  Predicted: tensor([16758.7891])
# Day  Predicted: tensor([16758.4375])
# Day  Predicted: tensor([16758.0859])
# Day  Predicted: tensor([16757.7344])
# Day  Predicted: tensor([16757.3828])
# Day  Predicted: tensor([16757.0312])
# Day  Predicted: tensor([16756.6797])
# Day  Predicted: tensor([16756.3281])
# Day  Predicted: tensor([16755.9766])
# Day  Predicted: tensor([16755.6270])
# Day  Predicted: tensor([16755.2734])
# Day  Predicted: tensor([16754.9238])
# Day  Predicted: tensor([16754.5703])
# Day  Predicted: tensor([16754.2207])
# Day  Predicted: tensor([16753.8691])
# Day  Predicted: tensor([16753.5176])
# Day  Predicted: tensor([16753.1660])
# Day  Predicted: tensor([16752.8145])
# Day  Predicted: tensor([16752.4629])
# Day  Predicted: tensor([16752.1113])
# Day  Predicted: tensor([16751.7617])
# Day  Predicted: tensor([16751.4082])
# Day  Predicted: tensor([16751.0586])
# Day  Predicted: tensor([16750.7090])
# Day  Predicted: tensor([16750.3555])
# Day  Predicted: tensor([16750.0059])
# Day  Predicted: tensor([16749.6523])
# Day  Predicted: tensor([16749.3008])
# Day  Predicted: tensor([16748.9512])
# Day  Predicted: tensor([16748.5996])
# Day  Predicted: tensor([16748.2461])
# Day  Predicted: tensor([16747.8965])
# Day  Predicted: tensor([16747.5449])
# Day  Predicted: tensor([16747.1934])
# Day  Predicted: tensor([16746.8438])
# Day  Predicted: tensor([16746.4922])
# Day  Predicted: tensor([16746.1387])
# Day  Predicted: tensor([16745.7891])
# Day  Predicted: tensor([16745.4375])
# Day  Predicted: tensor([16745.0859])
# Day  Predicted: tensor([16744.7363])
# Day  Predicted: tensor([16744.3828])
# Day  Predicted: tensor([16744.0332])
# Day  Predicted: tensor([16743.6816])
# Day  Predicted: tensor([16743.3320])
# Day  Predicted: tensor([16742.9785])
# Day  Predicted: tensor([16742.6289])
# Day  Predicted: tensor([16742.2793])
# Day  Predicted: tensor([16741.9297])
# Day  Predicted: tensor([16741.5762])
# Day  Predicted: tensor([16741.2266])
# Day  Predicted: tensor([16740.8770])
# Day  Predicted: tensor([16740.5234])
# Day  Predicted: tensor([16740.1719])

# %%
# Chuyển dữ liệu từ Series pandas thành numpy array để vẽ biểu đồ
predicted_values_test = [pred[0].numpy() for pred in predicted_test]
# Chuyển dữ liệu dự báo từ tensor về numpy array
predicted_values = [pred[0].numpy() for pred in predicted]
# Tạo mảng chứa ngày của train_data_price
train_dates = df['Date'].values[:len(train_data_price)]
# Tạo mảng chứa ngày của test_data_price
test_dates = df['Date'].values[len(train_data_price):len(train_data_price)+len(test_data_price)]
# Tạo mảng chứa ngày dự đoán
predicted_dates = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=len(predicted_values))

split_size = len(predicted_values) // 3

predicted_values_30day = predicted_values[:split_size]
predicted_values_60day = predicted_values[split_size:2*split_size]
predicted_values_90day = predicted_values[2*split_size:]
# Tính toán các khoảng thời gian cho mỗi phần
predicted_dates_30day = pd.date_range(start=last_date + pd.DateOffset(days=1), periods=split_size)
predicted_dates_60day = pd.date_range(start=predicted_dates_30day[-1] + pd.DateOffset(days=1), periods=split_size)
predicted_dates_90day = pd.date_range(start=predicted_dates_60day[-1] + pd.DateOffset(days=1), periods=split_size)

# %%
import matplotlib.pyplot as plt

# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(train_dates, train_data_price, label='Training Data')
plt.plot(test_dates, test_data_price, label='Actual Data')
plt.plot(test_dates, predicted_values_test, label='Predicted')
plt.plot(predicted_dates_30day, predicted_values_30day, label='Predicted 30 Day', color='red')
plt.plot(predicted_dates_60day, predicted_values_60day, label='Predicted 60 Day', color='green')
plt.plot(predicted_dates_90day, predicted_values_90day, label='Predicted 90 Day', color='blue')
plt.title('DLinear - DXG Stock Price - 9:1')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt


# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(test_dates, test_data_price, label='Actual Data')
plt.plot(predicted_dates_30day, predicted_values_30day, label='Predicted 30 Day', color='red')
plt.plot(predicted_dates_60day, predicted_values_60day, label='Predicted 60 Day', color='green')
plt.plot(predicted_dates_90day, predicted_values_90day, label='Predicted 90 Day', color='blue')

plt.title('DLinear - DXG Stock Price - 9:1')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
outputs_test = np.array(predicted_values_test)
outputs_test = outputs_test.flatten()

# %%
# Mean Absolute Error (MAE) và Mean Absolute Percentage Error (MAPE)
mae_test = np.mean(np.abs(test_data_price - outputs_test))
mape_test = np.mean(np.abs((test_data_price - outputs_test) / test_data_price)) * 100
rmse_test = np.sqrt(np.mean((test_data_price - outputs_test) ** 2))

print("MAE:", mae_test)
print("MAPE:", mape_test)
print("RMSE:", rmse_test)
# Out:
# MAE: 2328.9474107280134
# MAPE: 13.3720216610079
# RMSE: 2706.9244497571785
